# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Warmup Project Exercise

# %% [markdown]
# ## Simple War Game
#
# Before we launch in to the OOP Milestone 2 Project, let's walk through together on using OOP for a more robust and complex application, such as a game. We will use Python OOP to simulate a simplified version of the game war. Two players will each start off with half the deck, then they each remove a card, compare which card has the highest value, and the player with the higher card wins both cards. In the event of a time

# %% [markdown]
# ## Single Card Class
#
# ### Creating a Card Class with outside variables
#
# Here we will use some outside variables that we know don't change regardless of the situation, such as a deck of cards. Regardless of what round,match, or game we're playing, we'll still need the same deck of cards.

# %%
import random 
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

class Card():
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank
        self.value = values[self.rank]

    def __str__(self):
        return self.rank + " of "+self.suit

# %%
print(Card("Hearts", "Two"))
# Out:
# Two of Hearts

# %%
print(two_hearts)
# Out:
# Two of Hearts

# %%
suits
# Out:
# ('Hearts', 'Diamonds', 'Spades', 'Clubs')

# %%
ranks
# Out:
# ('Two',
#  'Three',
#  'Four',
#  'Five',
#  'Six',
#  'Seven',
#  'Eight',
#  'Nine',
#  'Ten',
#  'Jack',
#  'Queen',
#  'King',
#  'Ace')

# %%
two_hearts = Card(suits[0],ranks[0])

# %% [markdown]
# ## Deck Class
#
# ### Using a class within another class
#
# We just created a single card, but how can we create an entire Deck of cards? Let's explore doing this with a class that utilizes the Card class.

# %% [markdown]
# A Deck will be made up of multiple Cards. Which mean's we will actually use the Card class within the \_\_init__ of the Deck class.

# %%
class Deck:
    
    def __init__(self):
        self.all_cards = [ Card(suit=suit, rank=rank) for rank in ranks for suit in suits]
                
    def shuffle(self):
        random.shuffle(self.all_cards)

    def has_cards(self):
        return len(self.all_cards) >0
    
    def card_count(self):
        return len(self.all_cards)  
    
    def deal_one(self):
        
        if self.has_cards():
            return self.all_cards.pop(0)
        else:
            print("no more cards to deal")
    def __str__(self):
        return [card for card in self.all_cards]

# %% [markdown]
# ### Create a Deck

# %%
my_deck = Deck()

# %%
len(my_deck.all_cards)
# Out:
# 52

# %%
my_deck.all_cards[0]

# %%
print(my_deck.all_cards[0])
# Out:
# Two of Hearts

# %%
my_deck.shuffle()

# %%
print(my_deck.all_cards[0])
# Out:
# Nine of Hearts

# %%
my_card = my_deck.deal_one()

# %%
print(my_card)
# Out:
# Nine of Hearts

# %%
len(my_deck.all_cards)
# Out:
# 51

# %% [markdown]
# # Player Class
#
# Let's create a Player Class, a player should be able to hold instances of Cards, they should also be able to remove and add them from their hand. We want the Player class to be flexible enough to add one card, or many cards so we'll use a simple if check to keep it all in the same method.

# %% [markdown]
# We'll keep this all in mind as we create the methods for the Player class.
#
# ### Player Class

# %%
class Player:
    
    def __init__(self,name):
        self.name = name
        # A new player has no cards
        self.all_cards = [] 
        
    def remove_one(self):
        if self.has_cards():
            return self.all_cards.pop(0)
        else:
            print(f"{self.name} has run out of cards")
    
    def add_cards(self,new_cards):
        self.all_cards.extend( new_cards if isinstance(new_cards, list) else [new_cards])
    
    def card_count(self):
        return len(self.all_cards)
    
    def has_cards(self):
        return len(self.all_cards) > 0   
    
    
    
    def __str__(self):
        
        cards = "card" if self.card_count() == 1 else "cards"
        
        return f"{self.name} has {len(self.all_cards)} {cards}"

# %%
jose = Player("Jose")

# %%
jose

# %%
print(jose)
# Out:
# Jose has 0 cards

# %%
two_hearts

# %%
jose.add_cards(two_hearts)

# %%
print(jose)
# Out:
# Jose has 1 card

# %%
jose.add_cards([two_hearts,two_hearts,two_hearts])

# %%
print(jose)
# Out:
# Jose has 4 cards

# %% [markdown]
# ## War Game Logic

# %%
#War game
class Game():
    def __init__(self,player1Name, player2Name):
        self.player1 = Player(player1Name)
        self.player2 = Player(player2Name)
        self.deck = Deck()
        self.deck.shuffle()
        
    def split_deck(self):
        for card in self.deck.allcards:
            self.player1.add_cards(self.deck.deal_one())
            self.player2.add_cards(self.deck.deal_one())
        return self.player1.card_count() == self.player2.card_count()
        
    def winner(self):
        '''determine winning player'''
        win=None
        if not self.player2.has_cards():
            win = self.player1
        elif not self.player1.has_cards():
            win = self.player2
        return win

    def play_round(self):
        '''play a round'''
        if not (self.players_have_cards):
            print(f'{self.player1} has no cards.')
            print(f'{self.player2} has no cards.')            
            return          

        
        player1_card = self.player1.remove_one()
        player2_card = self.player2.remove_one()
        self.cards_to_be_won.extend([player1_card,player2_card])
        
        if(player1_card.value>player2_card.value):
            print(f"{self.player1.name} won round {self.game_round} with {len(self.cards_to_be_won)} cards")            
            self.player1.add_cards(self.cards_to_be_won)
            self.cards_to_be_won.clear()            
            self.game_round +=1
            self.tie_count = 0
            return self.player1

        elif(player2_card.value>player1_card.value):
            print(f"{self.player2.name} won round {self.game_round} with {len(self.cards_to_be_won)} cards")                
            self.player2.add_cards(self.cards_to_be_won)
            self.cards_to_be_won.clear()
            self.game_round +=1
            self.tie_count = 0
            return self.player2
            
        else:
            self.tie_count += 1            
            self.game_round +=1              
            print(f"round {self.game_round}, tie {self.tie_count} :{player1_card}, {player2_card}")
            self.players_have_cards = self.player2.has_cards() and self.player1.has_cards()
            self.play_round()
        
            
    def play(self):
        print(self.winner())
        #while len(self.deck.all_cards)>0:
         #   if(self.winner(self.player1,self.player2)==None):
          #      self.play_round()
        #len(self.player1.all_cards) > 0 
        print(f"cards: player 1 has cards: {self.player2.card_count()} and player 2 has cards: { self.player2.card_count()}")
        self.split_deck()
        self.players_have_cards = self.split_deck()
        self.no_winner = (self.winner()==None)
        self.game_round = 0
        
        while (self.players_have_cards and self.no_winner):
            print(f"Level 1 cards @ round {self.game_round}: player 1 has cards: {self.player2.card_count()} and player 2 has cards: { self.player2.card_count()}")            
            self.cards_to_be_won = []  
            self.tie_count = 0              
            self.play_round()
            
            self.no_winner = (self.winner()==None)               
            self.players_have_cards = self.player2.has_cards() and self.player1.has_cards()
                #players_have_cards = (self.player2.has_cards() and self.player1.has_cards())
                #no_winner = (self.winner()==None)               
        if(self.player1.all_cards == 0):
            print(f" winner was {self.player2} with {self.player2.card_count()} cards ")
        elif(self.player2.all_cards == 0):
            print(f" winner was {self.player1} with {self.player1.card_count()} cards ")
        else:
            print(f"game ended with {self.player1.name} with {self.player1.card_count()} cards and {self.player2.name} with {self.player2.card_count()} cards")
            print(f"{self.deck}")
            
    
    def __str__(self):
        details = f"{self.deck.card_count()} cards left.\nPlayer 1 has {self.player1.all_cards[0]}\nPlayer 2 has {self.player2.all_cards[0]}"
        return details

# %%
game = Game("one", "two")

# %%
print(game)
# Out:
# 50 cards left.
# Player 1 has Two of Spades
# Player 2 has Five of Hearts

# %%
game.play()
# Out:
# None
# cards: player 1 has cards: 1 and player 2 has cards: 1
# Level 1 cards @ round 0: player 1 has cards: 1 and player 2 has cards: 1
# two won round 0 with 2 cards
# Level 1 cards @ round 1: player 1 has cards: 3 and player 2 has cards: 3
# two won round 1 with 2 cards
# Level 1 cards @ round 2: player 1 has cards: 5 and player 2 has cards: 5
# one won round 2 with 2 cards
# Level 1 cards @ round 3: player 1 has cards: 5 and player 2 has cards: 5
# one won round 3 with 2 cards
# Level 1 cards @ round 4: player 1 has cards: 5 and player 2 has cards: 5
# two won round 4 with 2 cards
# Level 1 cards @ round 5: player 1 has cards: 7 and player 2 has cards: 7
# two won round 5 with 2 cards
# Level 1 cards @ round 6: player 1 has cards: 9 and player 2 has cards: 9
# two won round 6 with 2 cards
# Level 1 cards @ round 7: player 1 has cards: 11 and player 2 has cards: 11
# one won round 7 with 2 cards
# Level 1 cards @ round 8: player 1 has cards: 11 and player 2 has cards: 11
# two won round 8 with 2 cards
# Level 1 cards @ round 9: player 1 has cards: 13 and player 2 has cards: 13
# one won round 9 with 2 cards
# Level 1 cards @ round 10: player 1 has cards: 13 and player 2 has cards: 13
# one won round 10 with 2 cards
# Level 1 cards @ round 11: player 1 has cards: 13 and player 2 has cards: 13
# one won round 11 with 2 cards
# Level 1 cards @ round 12: player 1 has cards: 13 and player 2 has cards: 13
# round 13, tie 1 :Ace of Diamonds, Ace of Hearts
# one won round 13 with 4 cards
# Level 1 cards @ round 14: player 1 has cards: 13 and player 2 has cards: 13
# one won round 14 with 2 cards
# Level 1 cards @ round 15: player 1 has cards: 13 and player 2 has cards: 13
# one won round 15 with 2 cards
# Level 1 cards @ round 16: player 1 has cards: 13 and player 2 has cards: 13
# two won round 16 with 2 cards
# Level 1 cards @ round 17: player 1 has cards: 15 and player 2 has cards: 15
# one won round 17 with 2 cards
# Level 1 cards @ round 18: player 1 has cards: 15 and player 2 has cards: 15
# two won round 18 with 2 cards
# Level 1 cards @ round 19: player 1 has cards: 17 and player 2 has cards: 17
# one won round 19 with 2 cards
# Level 1 cards @ round 20: player 1 has cards: 17 and player 2 has cards: 17
# one won round 20 with 2 cards
# Level 1 cards @ round 21: player 1 has cards: 17 and player 2 has cards: 17
# two won round 21 with 2 cards
# Level 1 cards @ round 22: player 1 has cards: 19 and player 2 has cards: 19
# one won round 22 with 2 cards
# Level 1 cards @ round 23: player 1 has cards: 19 and player 2 has cards: 19
# two won round 23 with 2 cards
# Level 1 cards @ round 24: player 1 has cards: 21 and player 2 has cards: 21
# one won round 24 with 2 cards
# Level 1 cards @ round 25: player 1 has cards: 21 and player 2 has cards: 21
# two won round 25 with 2 cards
# Level 1 cards @ round 26: player 1 has cards: 22 and player 2 has cards: 22
# one won round 26 with 2 cards
# Level 1 cards @ round 27: player 1 has cards: 21 and player 2 has cards: 21
# one won round 27 with 2 cards
# Level 1 cards @ round 28: player 1 has cards: 20 and player 2 has cards: 20
# one won round 28 with 2 cards
# Level 1 cards @ round 29: player 1 has cards: 19 and player 2 has cards: 19
# one won round 29 with 2 cards
# Level 1 cards @ round 30: player 1 has cards: 18 and player 2 has cards: 18
# two won round 30 with 2 cards
# Level 1 cards @ round 31: player 1 has cards: 19 and player 2 has cards: 19
# one won round 31 with 2 cards
# Level 1 cards @ round 32: player 1 has cards: 18 and player 2 has cards: 18
# two won round 32 with 2 cards
# Level 1 cards @ round 33: player 1 has cards: 19 and player 2 has cards: 19
# one won round 33 with 2 cards
# Level 1 cards @ round 34: player 1 has cards: 18 and player 2 has cards: 18
# round 35, tie 1 :Three of Spades, Three of Clubs
# one won round 35 with 4 cards
# Level 1 cards @ round 36: player 1 has cards: 16 and player 2 has cards: 16
# two won round 36 with 2 cards
# Level 1 cards @ round 37: player 1 has cards: 17 and player 2 has cards: 17
# one won round 37 with 2 cards
# Level 1 cards @ round 38: player 1 has cards: 16 and player 2 has cards: 16
# two won round 38 with 2 cards
# Level 1 cards @ round 39: player 1 has cards: 17 and player 2 has cards: 17
# one won round 39 with 2 cards
# Level 1 cards @ round 40: player 1 has cards: 16 and player 2 has cards: 16
# two won round 40 with 2 cards
# Level 1 cards @ round 41: player 1 has cards: 17 and player 2 has cards: 17
# round 42, tie 1 :Five of Diamonds, Five of Spades
# one won round 42 with 4 cards
# Level 1 cards @ round 43: player 1 has cards: 15 and player 2 has cards: 15
# two won round 43 with 2 cards
# Level 1 cards @ round 44: player 1 has cards: 16 and player 2 has cards: 16
# two won round 44 with 2 cards
# Level 1 cards @ round 45: player 1 has cards: 17 and player 2 has cards: 17
# one won round 45 with 2 cards
# Level 1 cards @ round 46: player 1 has cards: 16 and player 2 has cards: 16
# one won round 46 with 2 cards
# Level 1 cards @ round 47: player 1 has cards: 15 and player 2 has cards: 15
# two won round 47 with 2 cards
# Level 1 cards @ round 48: player 1 has cards: 16 and player 2 has cards: 16
# one won round 48 with 2 cards
# Level 1 cards @ round 49: player 1 has cards: 15 and player 2 has cards: 15
# two won round 49 with 2 cards
# Level 1 cards @ round 50: player 1 has cards: 16 and player 2 has cards: 16
# one won round 50 with 2 cards
# Level 1 cards @ round 51: player 1 has cards: 15 and player 2 has cards: 15
# round 52, tie 1 :Queen of Spades, Queen of Clubs
# one won round 52 with 4 cards
# Level 1 cards @ round 53: player 1 has cards: 13 and player 2 has cards: 13
# one won round 53 with 2 cards
# Level 1 cards @ round 54: player 1 has cards: 12 and player 2 has cards: 12
# one won round 54 with 2 cards
# Level 1 cards @ round 55: player 1 has cards: 11 and player 2 has cards: 11
# two won round 55 with 2 cards
# Level 1 cards @ round 56: player 1 has cards: 12 and player 2 has cards: 12
# round 57, tie 1 :Nine of Clubs, Nine of Spades
# two won round 57 with 4 cards
# Level 1 cards @ round 58: player 1 has cards: 14 and player 2 has cards: 14
# one won round 58 with 2 cards
# Level 1 cards @ round 59: player 1 has cards: 13 and player 2 has cards: 13
# two won round 59 with 2 cards
# Level 1 cards @ round 60: player 1 has cards: 14 and player 2 has cards: 14
# one won round 60 with 2 cards
# Level 1 cards @ round 61: player 1 has cards: 13 and player 2 has cards: 13
# two won round 61 with 2 cards
# Level 1 cards @ round 62: player 1 has cards: 14 and player 2 has cards: 14
# one won round 62 with 2 cards
# Level 1 cards @ round 63: player 1 has cards: 13 and player 2 has cards: 13
# two won round 63 with 2 cards
# Level 1 cards @ round 64: player 1 has cards: 14 and player 2 has cards: 14
# one won round 64 with 2 cards
# Level 1 cards @ round 65: player 1 has cards: 13 and player 2 has cards: 13
# one won round 65 with 2 cards
# Level 1 cards @ round 66: player 1 has cards: 12 and player 2 has cards: 12
# one won round 66 with 2 cards
# Level 1 cards @ round 67: player 1 has cards: 11 and player 2 has cards: 11
# two won round 67 with 2 cards
# Level 1 cards @ round 68: player 1 has cards: 12 and player 2 has cards: 12
# two won round 68 with 2 cards
# Level 1 cards @ round 69: player 1 has cards: 13 and player 2 has cards: 13
# two won round 69 with 2 cards
# Level 1 cards @ round 70: player 1 has cards: 14 and player 2 has cards: 14
# one won round 70 with 2 cards
# Level 1 cards @ round 71: player 1 has cards: 13 and player 2 has cards: 13
# two won round 71 with 2 cards
# Level 1 cards @ round 72: player 1 has cards: 14 and player 2 has cards: 14
# one won round 72 with 2 cards
# Level 1 cards @ round 73: player 1 has cards: 13 and player 2 has cards: 13
# two won round 73 with 2 cards
# Level 1 cards @ round 74: player 1 has cards: 14 and player 2 has cards: 14
# one won round 74 with 2 cards
# Level 1 cards @ round 75: player 1 has cards: 13 and player 2 has cards: 13
# two won round 75 with 2 cards
# Level 1 cards @ round 76: player 1 has cards: 14 and player 2 has cards: 14
# one won round 76 with 2 cards
# Level 1 cards @ round 77: player 1 has cards: 13 and player 2 has cards: 13
# two won round 77 with 2 cards
# Level 1 cards @ round 78: player 1 has cards: 14 and player 2 has cards: 14
# one won round 78 with 2 cards
# Level 1 cards @ round 79: player 1 has cards: 13 and player 2 has cards: 13
# one won round 79 with 2 cards
# Level 1 cards @ round 80: player 1 has cards: 12 and player 2 has cards: 12
# one won round 80 with 2 cards
# Level 1 cards @ round 81: player 1 has cards: 11 and player 2 has cards: 11
# two won round 81 with 2 cards
# Level 1 cards @ round 82: player 1 has cards: 12 and player 2 has cards: 12
# one won round 82 with 2 cards
# Level 1 cards @ round 83: player 1 has cards: 11 and player 2 has cards: 11
# two won round 83 with 2 cards
# Level 1 cards @ round 84: player 1 has cards: 12 and player 2 has cards: 12
# one won round 84 with 2 cards
# Level 1 cards @ round 85: player 1 has cards: 11 and player 2 has cards: 11
# two won round 85 with 2 cards
# Level 1 cards @ round 86: player 1 has cards: 12 and player 2 has cards: 12
# one won round 86 with 2 cards
# Level 1 cards @ round 87: player 1 has cards: 11 and player 2 has cards: 11
# one won round 87 with 2 cards
# Level 1 cards @ round 88: player 1 has cards: 10 and player 2 has cards: 10
# one won round 88 with 2 cards
# Level 1 cards @ round 89: player 1 has cards: 9 and player 2 has cards: 9
# two won round 89 with 2 cards
# Level 1 cards @ round 90: player 1 has cards: 10 and player 2 has cards: 10
# one won round 90 with 2 cards
# Level 1 cards @ round 91: player 1 has cards: 9 and player 2 has cards: 9
# two won round 91 with 2 cards
# Level 1 cards @ round 92: player 1 has cards: 10 and player 2 has cards: 10
# one won round 92 with 2 cards
# Level 1 cards @ round 93: player 1 has cards: 9 and player 2 has cards: 9
# two won round 93 with 2 cards
# Level 1 cards @ round 94: player 1 has cards: 10 and player 2 has cards: 10
# one won round 94 with 2 cards
# Level 1 cards @ round 95: player 1 has cards: 9 and player 2 has cards: 9
# two won round 95 with 2 cards
# Level 1 cards @ round 96: player 1 has cards: 10 and player 2 has cards: 10
# one won round 96 with 2 cards
# Level 1 cards @ round 97: player 1 has cards: 9 and player 2 has cards: 9
# two won round 97 with 2 cards
# Level 1 cards @ round 98: player 1 has cards: 10 and player 2 has cards: 10
# one won round 98 with 2 cards
# Level 1 cards @ round 99: player 1 has cards: 9 and player 2 has cards: 9
# two won round 99 with 2 cards
# Level 1 cards @ round 100: player 1 has cards: 10 and player 2 has cards: 10
# one won round 100 with 2 cards
# Level 1 cards @ round 101: player 1 has cards: 9 and player 2 has cards: 9
# two won round 101 with 2 cards
# Level 1 cards @ round 102: player 1 has cards: 10 and player 2 has cards: 10
# round 103, tie 1 :Seven of Spades, Seven of Hearts
# two won round 103 with 4 cards
# Level 1 cards @ round 104: player 1 has cards: 12 and player 2 has cards: 12
# one won round 104 with 2 cards
# Level 1 cards @ round 105: player 1 has cards: 11 and player 2 has cards: 11
# two won round 105 with 2 cards
# Level 1 cards @ round 106: player 1 has cards: 12 and player 2 has cards: 12
# two won round 106 with 2 cards
# Level 1 cards @ round 107: player 1 has cards: 13 and player 2 has cards: 13
# two won round 107 with 2 cards
# Level 1 cards @ round 108: player 1 has cards: 14 and player 2 has cards: 14
# one won round 108 with 2 cards
# Level 1 cards @ round 109: player 1 has cards: 13 and player 2 has cards: 13
# two won round 109 with 2 cards
# Level 1 cards @ round 110: player 1 has cards: 14 and player 2 has cards: 14
# one won round 110 with 2 cards
# Level 1 cards @ round 111: player 1 has cards: 13 and player 2 has cards: 13
# two won round 111 with 2 cards
# Level 1 cards @ round 112: player 1 has cards: 14 and player 2 has cards: 14
# one won round 112 with 2 cards
# Level 1 cards @ round 113: player 1 has cards: 13 and player 2 has cards: 13
# one won round 113 with 2 cards
# Level 1 cards @ round 114: player 1 has cards: 12 and player 2 has cards: 12
# one won round 114 with 2 cards
# Level 1 cards @ round 115: player 1 has cards: 11 and player 2 has cards: 11
# two won round 115 with 2 cards
# Level 1 cards @ round 116: player 1 has cards: 12 and player 2 has cards: 12
# one won round 116 with 2 cards
# Level 1 cards @ round 117: player 1 has cards: 11 and player 2 has cards: 11
# two won round 117 with 2 cards
# Level 1 cards @ round 118: player 1 has cards: 12 and player 2 has cards: 12
# one won round 118 with 2 cards
# Level 1 cards @ round 119: player 1 has cards: 11 and player 2 has cards: 11
# one won round 119 with 2 cards
# Level 1 cards @ round 120: player 1 has cards: 10 and player 2 has cards: 10
# one won round 120 with 2 cards
# Level 1 cards @ round 121: player 1 has cards: 9 and player 2 has cards: 9
# two won round 121 with 2 cards
# Level 1 cards @ round 122: player 1 has cards: 10 and player 2 has cards: 10
# one won round 122 with 2 cards
# Level 1 cards @ round 123: player 1 has cards: 9 and player 2 has cards: 9
# two won round 123 with 2 cards
# Level 1 cards @ round 124: player 1 has cards: 10 and player 2 has cards: 10
# one won round 124 with 2 cards
# Level 1 cards @ round 125: player 1 has cards: 9 and player 2 has cards: 9
# one won round 125 with 2 cards
# Level 1 cards @ round 126: player 1 has cards: 8 and player 2 has cards: 8
# one won round 126 with 2 cards
# Level 1 cards @ round 127: player 1 has cards: 7 and player 2 has cards: 7
# two won round 127 with 2 cards
# Level 1 cards @ round 128: player 1 has cards: 8 and player 2 has cards: 8
# one won round 128 with 2 cards
# Level 1 cards @ round 129: player 1 has cards: 7 and player 2 has cards: 7
# one won round 129 with 2 cards
# Level 1 cards @ round 130: player 1 has cards: 6 and player 2 has cards: 6
# one won round 130 with 2 cards
# Level 1 cards @ round 131: player 1 has cards: 5 and player 2 has cards: 5
# two won round 131 with 2 cards
# Level 1 cards @ round 132: player 1 has cards: 6 and player 2 has cards: 6
# one won round 132 with 2 cards
# Level 1 cards @ round 133: player 1 has cards: 5 and player 2 has cards: 5
# two won round 133 with 2 cards
# Level 1 cards @ round 134: player 1 has cards: 6 and player 2 has cards: 6
# one won round 134 with 2 cards
# Level 1 cards @ round 135: player 1 has cards: 5 and player 2 has cards: 5
# two won round 135 with 2 cards
# Level 1 cards @ round 136: player 1 has cards: 6 and player 2 has cards: 6
# one won round 136 with 2 cards
# Level 1 cards @ round 137: player 1 has cards: 5 and player 2 has cards: 5
# two won round 137 with 2 cards
# Level 1 cards @ round 138: player 1 has cards: 6 and player 2 has cards: 6
# one won round 138 with 2 cards
# Level 1 cards @ round 139: player 1 has cards: 5 and player 2 has cards: 5
# two won round 139 with 2 cards
# Level 1 cards @ round 140: player 1 has cards: 6 and player 2 has cards: 6
# one won round 140 with 2 cards
# Level 1 cards @ round 141: player 1 has cards: 5 and player 2 has cards: 5
# one won round 141 with 2 cards
# Level 1 cards @ round 142: player 1 has cards: 4 and player 2 has cards: 4
# one won round 142 with 2 cards
# Level 1 cards @ round 143: player 1 has cards: 3 and player 2 has cards: 3
# two won round 143 with 2 cards
# Level 1 cards @ round 144: player 1 has cards: 4 and player 2 has cards: 4
# one won round 144 with 2 cards
# Level 1 cards @ round 145: player 1 has cards: 3 and player 2 has cards: 3
# two won round 145 with 2 cards
# Level 1 cards @ round 146: player 1 has cards: 4 and player 2 has cards: 4
# one won round 146 with 2 cards
# Level 1 cards @ round 147: player 1 has cards: 3 and player 2 has cards: 3
# two won round 147 with 2 cards
# Level 1 cards @ round 148: player 1 has cards: 4 and player 2 has cards: 4
# one won round 148 with 2 cards
# Level 1 cards @ round 149: player 1 has cards: 3 and player 2 has cards: 3
# two won round 149 with 2 cards
# Level 1 cards @ round 150: player 1 has cards: 4 and player 2 has cards: 4
# one won round 150 with 2 cards
# Level 1 cards @ round 151: player 1 has cards: 3 and player 2 has cards: 3
# two won round 151 with 2 cards
# Level 1 cards @ round 152: player 1 has cards: 4 and player 2 has cards: 4
# one won round 152 with 2 cards
# Level 1 cards @ round 153: player 1 has cards: 3 and player 2 has cards: 3
# two won round 153 with 2 cards
# Level 1 cards @ round 154: player 1 has cards: 4 and player 2 has cards: 4
# two won round 154 with 2 cards
# Level 1 cards @ round 155: player 1 has cards: 5 and player 2 has cards: 5
# two won round 155 with 2 cards
# Level 1 cards @ round 156: player 1 has cards: 6 and player 2 has cards: 6
# one won round 156 with 2 cards
# Level 1 cards @ round 157: player 1 has cards: 5 and player 2 has cards: 5
# two won round 157 with 2 cards
# Level 1 cards @ round 158: player 1 has cards: 6 and player 2 has cards: 6
# one won round 158 with 2 cards
# Level 1 cards @ round 159: player 1 has cards: 5 and player 2 has cards: 5
# round 160, tie 1 :Seven of Clubs, Seven of Spades
# one won round 160 with 4 cards
# Level 1 cards @ round 161: player 1 has cards: 3 and player 2 has cards: 3
# two won round 161 with 2 cards
# Level 1 cards @ round 162: player 1 has cards: 4 and player 2 has cards: 4
# one won round 162 with 2 cards
# Level 1 cards @ round 163: player 1 has cards: 3 and player 2 has cards: 3
# two won round 163 with 2 cards
# Level 1 cards @ round 164: player 1 has cards: 4 and player 2 has cards: 4
# one won round 164 with 2 cards
# Level 1 cards @ round 165: player 1 has cards: 3 and player 2 has cards: 3
# two won round 165 with 2 cards
# Level 1 cards @ round 166: player 1 has cards: 4 and player 2 has cards: 4
# one won round 166 with 2 cards
# Level 1 cards @ round 167: player 1 has cards: 3 and player 2 has cards: 3
# two won round 167 with 2 cards
# Level 1 cards @ round 168: player 1 has cards: 4 and player 2 has cards: 4
# one won round 168 with 2 cards
# Level 1 cards @ round 169: player 1 has cards: 3 and player 2 has cards: 3
# two won round 169 with 2 cards
# Level 1 cards @ round 170: player 1 has cards: 4 and player 2 has cards: 4
# one won round 170 with 2 cards
# Level 1 cards @ round 171: player 1 has cards: 3 and player 2 has cards: 3
# two won round 171 with 2 cards
# Level 1 cards @ round 172: player 1 has cards: 4 and player 2 has cards: 4
# one won round 172 with 2 cards
# Level 1 cards @ round 173: player 1 has cards: 3 and player 2 has cards: 3
# two won round 173 with 2 cards
# Level 1 cards @ round 174: player 1 has cards: 4 and player 2 has cards: 4
# one won round 174 with 2 cards
# Level 1 cards @ round 175: player 1 has cards: 3 and player 2 has cards: 3
# two won round 175 with 2 cards
# Level 1 cards @ round 176: player 1 has cards: 4 and player 2 has cards: 4
# one won round 176 with 2 cards
# Level 1 cards @ round 177: player 1 has cards: 3 and player 2 has cards: 3
# two won round 177 with 2 cards
# Level 1 cards @ round 178: player 1 has cards: 4 and player 2 has cards: 4
# two won round 178 with 2 cards
# Level 1 cards @ round 179: player 1 has cards: 5 and player 2 has cards: 5
# two won round 179 with 2 cards
# Level 1 cards @ round 180: player 1 has cards: 6 and player 2 has cards: 6
# one won round 180 with 2 cards
# Level 1 cards @ round 181: player 1 has cards: 5 and player 2 has cards: 5
# two won round 181 with 2 cards
# Level 1 cards @ round 182: player 1 has cards: 6 and player 2 has cards: 6
# round 183, tie 1 :Eight of Spades, Eight of Hearts
# two won round 183 with 4 cards
# Level 1 cards @ round 184: player 1 has cards: 8 and player 2 has cards: 8
# one won round 184 with 2 cards
# Level 1 cards @ round 185: player 1 has cards: 7 and player 2 has cards: 7
# two won round 185 with 2 cards
# Level 1 cards @ round 186: player 1 has cards: 8 and player 2 has cards: 8
# one won round 186 with 2 cards
# Level 1 cards @ round 187: player 1 has cards: 7 and player 2 has cards: 7
# two won round 187 with 2 cards
# Level 1 cards @ round 188: player 1 has cards: 8 and player 2 has cards: 8
# one won round 188 with 2 cards
# Level 1 cards @ round 189: player 1 has cards: 7 and player 2 has cards: 7
# one won round 189 with 2 cards
# Level 1 cards @ round 190: player 1 has cards: 6 and player 2 has cards: 6
# one won round 190 with 2 cards
# Level 1 cards @ round 191: player 1 has cards: 5 and player 2 has cards: 5
# two won round 191 with 2 cards
# Level 1 cards @ round 192: player 1 has cards: 6 and player 2 has cards: 6
# one won round 192 with 2 cards
# Level 1 cards @ round 193: player 1 has cards: 5 and player 2 has cards: 5
# two won round 193 with 2 cards
# Level 1 cards @ round 194: player 1 has cards: 6 and player 2 has cards: 6
# one won round 194 with 2 cards
# Level 1 cards @ round 195: player 1 has cards: 5 and player 2 has cards: 5
# two won round 195 with 2 cards
# Level 1 cards @ round 196: player 1 has cards: 6 and player 2 has cards: 6
# one won round 196 with 2 cards
# Level 1 cards @ round 197: player 1 has cards: 5 and player 2 has cards: 5
# two won round 197 with 2 cards
# Level 1 cards @ round 198: player 1 has cards: 6 and player 2 has cards: 6
# one won round 198 with 2 cards
# Level 1 cards @ round 199: player 1 has cards: 5 and player 2 has cards: 5
# two won round 199 with 2 cards
# Level 1 cards @ round 200: player 1 has cards: 6 and player 2 has cards: 6
# one won round 200 with 2 cards
# Level 1 cards @ round 201: player 1 has cards: 5 and player 2 has cards: 5
# two won round 201 with 2 cards
# Level 1 cards @ round 202: player 1 has cards: 6 and player 2 has cards: 6
# one won round 202 with 2 cards
# Level 1 cards @ round 203: player 1 has cards: 5 and player 2 has cards: 5
# two won round 203 with 2 cards
# Level 1 cards @ round 204: player 1 has cards: 6 and player 2 has cards: 6
# one won round 204 with 2 cards
# Level 1 cards @ round 205: player 1 has cards: 5 and player 2 has cards: 5
# two won round 205 with 2 cards
# Level 1 cards @ round 206: player 1 has cards: 6 and player 2 has cards: 6
# one won round 206 with 2 cards
# Level 1 cards @ round 207: player 1 has cards: 5 and player 2 has cards: 5
# two won round 207 with 2 cards
# Level 1 cards @ round 208: player 1 has cards: 6 and player 2 has cards: 6
# one won round 208 with 2 cards
# Level 1 cards @ round 209: player 1 has cards: 5 and player 2 has cards: 5
# two won round 209 with 2 cards
# Level 1 cards @ round 210: player 1 has cards: 6 and player 2 has cards: 6
# one won round 210 with 2 cards
# Level 1 cards @ round 211: player 1 has cards: 5 and player 2 has cards: 5
# two won round 211 with 2 cards
# Level 1 cards @ round 212: player 1 has cards: 6 and player 2 has cards: 6
# one won round 212 with 2 cards
# Level 1 cards @ round 213: player 1 has cards: 5 and player 2 has cards: 5
# two won round 213 with 2 cards
# Level 1 cards @ round 214: player 1 has cards: 6 and player 2 has cards: 6
# one won round 214 with 2 cards
# Level 1 cards @ round 215: player 1 has cards: 5 and player 2 has cards: 5
# two won round 215 with 2 cards
# Level 1 cards @ round 216: player 1 has cards: 6 and player 2 has cards: 6
# one won round 216 with 2 cards
# Level 1 cards @ round 217: player 1 has cards: 5 and player 2 has cards: 5
# two won round 217 with 2 cards
# Level 1 cards @ round 218: player 1 has cards: 6 and player 2 has cards: 6
# one won round 218 with 2 cards
# Level 1 cards @ round 219: player 1 has cards: 5 and player 2 has cards: 5
# two won round 219 with 2 cards
# Level 1 cards @ round 220: player 1 has cards: 6 and player 2 has cards: 6
# one won round 220 with 2 cards
# Level 1 cards @ round 221: player 1 has cards: 5 and player 2 has cards: 5
# one won round 221 with 2 cards
# Level 1 cards @ round 222: player 1 has cards: 4 and player 2 has cards: 4
# one won round 222 with 2 cards
# Level 1 cards @ round 223: player 1 has cards: 3 and player 2 has cards: 3
# two won round 223 with 2 cards
# Level 1 cards @ round 224: player 1 has cards: 4 and player 2 has cards: 4
# one won round 224 with 2 cards
# Level 1 cards @ round 225: player 1 has cards: 3 and player 2 has cards: 3
# two won round 225 with 2 cards
# Level 1 cards @ round 226: player 1 has cards: 4 and player 2 has cards: 4
# one won round 226 with 2 cards
# Level 1 cards @ round 227: player 1 has cards: 3 and player 2 has cards: 3
# two won round 227 with 2 cards
# Level 1 cards @ round 228: player 1 has cards: 4 and player 2 has cards: 4
# one won round 228 with 2 cards
# Level 1 cards @ round 229: player 1 has cards: 3 and player 2 has cards: 3
# two won round 229 with 2 cards
# Level 1 cards @ round 230: player 1 has cards: 4 and player 2 has cards: 4
# one won round 230 with 2 cards
# Level 1 cards @ round 231: player 1 has cards: 3 and player 2 has cards: 3
# two won round 231 with 2 cards
# Level 1 cards @ round 232: player 1 has cards: 4 and player 2 has cards: 4
# one won round 232 with 2 cards
# Level 1 cards @ round 233: player 1 has cards: 3 and player 2 has cards: 3
# two won round 233 with 2 cards
# Level 1 cards @ round 234: player 1 has cards: 4 and player 2 has cards: 4
# one won round 234 with 2 cards
# Level 1 cards @ round 235: player 1 has cards: 3 and player 2 has cards: 3
# two won round 235 with 2 cards
# Level 1 cards @ round 236: player 1 has cards: 4 and player 2 has cards: 4
# one won round 236 with 2 cards
# Level 1 cards @ round 237: player 1 has cards: 3 and player 2 has cards: 3
# two won round 237 with 2 cards
# Level 1 cards @ round 238: player 1 has cards: 4 and player 2 has cards: 4
# two won round 238 with 2 cards
# Level 1 cards @ round 239: player 1 has cards: 5 and player 2 has cards: 5
# two won round 239 with 2 cards
# Level 1 cards @ round 240: player 1 has cards: 6 and player 2 has cards: 6
# one won round 240 with 2 cards
# Level 1 cards @ round 241: player 1 has cards: 5 and player 2 has cards: 5
# two won round 241 with 2 cards
# Level 1 cards @ round 242: player 1 has cards: 6 and player 2 has cards: 6
# one won round 242 with 2 cards
# Level 1 cards @ round 243: player 1 has cards: 5 and player 2 has cards: 5
# two won round 243 with 2 cards
# Level 1 cards @ round 244: player 1 has cards: 6 and player 2 has cards: 6
# one won round 244 with 2 cards
# Level 1 cards @ round 245: player 1 has cards: 5 and player 2 has cards: 5
# two won round 245 with 2 cards
# Level 1 cards @ round 246: player 1 has cards: 6 and player 2 has cards: 6
# one won round 246 with 2 cards
# Level 1 cards @ round 247: player 1 has cards: 5 and player 2 has cards: 5
# two won round 247 with 2 cards
# Level 1 cards @ round 248: player 1 has cards: 6 and player 2 has cards: 6
# one won round 248 with 2 cards
# Level 1 cards @ round 249: player 1 has cards: 5 and player 2 has cards: 5
# two won round 249 with 2 cards
# Level 1 cards @ round 250: player 1 has cards: 6 and player 2 has cards: 6
# one won round 250 with 2 cards
# Level 1 cards @ round 251: player 1 has cards: 5 and player 2 has cards: 5
# two won round 251 with 2 cards
# Level 1 cards @ round 252: player 1 has cards: 6 and player 2 has cards: 6
# one won round 252 with 2 cards
# Level 1 cards @ round 253: player 1 has cards: 5 and player 2 has cards: 5
# two won round 253 with 2 cards
# Level 1 cards @ round 254: player 1 has cards: 6 and player 2 has cards: 6
# one won round 254 with 2 cards
# Level 1 cards @ round 255: player 1 has cards: 5 and player 2 has cards: 5
# two won round 255 with 2 cards
# Level 1 cards @ round 256: player 1 has cards: 6 and player 2 has cards: 6
# one won round 256 with 2 cards
# Level 1 cards @ round 257: player 1 has cards: 5 and player 2 has cards: 5
# two won round 257 with 2 cards
# Level 1 cards @ round 258: player 1 has cards: 6 and player 2 has cards: 6
# one won round 258 with 2 cards
# Level 1 cards @ round 259: player 1 has cards: 5 and player 2 has cards: 5
# two won round 259 with 2 cards
# Level 1 cards @ round 260: player 1 has cards: 6 and player 2 has cards: 6
# one won round 260 with 2 cards
# Level 1 cards @ round 261: player 1 has cards: 5 and player 2 has cards: 5
# two won round 261 with 2 cards
# Level 1 cards @ round 262: player 1 has cards: 6 and player 2 has cards: 6
# one won round 262 with 2 cards
# Level 1 cards @ round 263: player 1 has cards: 5 and player 2 has cards: 5
# two won round 263 with 2 cards
# Level 1 cards @ round 264: player 1 has cards: 6 and player 2 has cards: 6
# one won round 264 with 2 cards
# Level 1 cards @ round 265: player 1 has cards: 5 and player 2 has cards: 5
# two won round 265 with 2 cards
# Level 1 cards @ round 266: player 1 has cards: 6 and player 2 has cards: 6
# one won round 266 with 2 cards
# Level 1 cards @ round 267: player 1 has cards: 5 and player 2 has cards: 5
# two won round 267 with 2 cards
# Level 1 cards @ round 268: player 1 has cards: 6 and player 2 has cards: 6
# one won round 268 with 2 cards
# Level 1 cards @ round 269: player 1 has cards: 5 and player 2 has cards: 5
# two won round 269 with 2 cards
# Level 1 cards @ round 270: player 1 has cards: 6 and player 2 has cards: 6
# one won round 270 with 2 cards
# Level 1 cards @ round 271: player 1 has cards: 5 and player 2 has cards: 5
# two won round 271 with 2 cards
# Level 1 cards @ round 272: player 1 has cards: 6 and player 2 has cards: 6
# one won round 272 with 2 cards
# Level 1 cards @ round 273: player 1 has cards: 5 and player 2 has cards: 5
# two won round 273 with 2 cards
# Level 1 cards @ round 274: player 1 has cards: 6 and player 2 has cards: 6
# two won round 274 with 2 cards
# Level 1 cards @ round 275: player 1 has cards: 7 and player 2 has cards: 7
# two won round 275 with 2 cards
# Level 1 cards @ round 276: player 1 has cards: 8 and player 2 has cards: 8
# one won round 276 with 2 cards
# Level 1 cards @ round 277: player 1 has cards: 7 and player 2 has cards: 7
# two won round 277 with 2 cards
# Level 1 cards @ round 278: player 1 has cards: 8 and player 2 has cards: 8
# one won round 278 with 2 cards
# Level 1 cards @ round 279: player 1 has cards: 7 and player 2 has cards: 7
# two won round 279 with 2 cards
# Level 1 cards @ round 280: player 1 has cards: 8 and player 2 has cards: 8
# one won round 280 with 2 cards
# Level 1 cards @ round 281: player 1 has cards: 7 and player 2 has cards: 7
# two won round 281 with 2 cards
# Level 1 cards @ round 282: player 1 has cards: 8 and player 2 has cards: 8
# one won round 282 with 2 cards
# Level 1 cards @ round 283: player 1 has cards: 7 and player 2 has cards: 7
# two won round 283 with 2 cards
# Level 1 cards @ round 284: player 1 has cards: 8 and player 2 has cards: 8
# one won round 284 with 2 cards
# Level 1 cards @ round 285: player 1 has cards: 7 and player 2 has cards: 7
# two won round 285 with 2 cards
# Level 1 cards @ round 286: player 1 has cards: 8 and player 2 has cards: 8
# one won round 286 with 2 cards
# Level 1 cards @ round 287: player 1 has cards: 7 and player 2 has cards: 7
# two won round 287 with 2 cards
# Level 1 cards @ round 288: player 1 has cards: 8 and player 2 has cards: 8
# one won round 288 with 2 cards
# Level 1 cards @ round 289: player 1 has cards: 7 and player 2 has cards: 7
# two won round 289 with 2 cards
# Level 1 cards @ round 290: player 1 has cards: 8 and player 2 has cards: 8
# one won round 290 with 2 cards
# Level 1 cards @ round 291: player 1 has cards: 7 and player 2 has cards: 7
# two won round 291 with 2 cards
# Level 1 cards @ round 292: player 1 has cards: 8 and player 2 has cards: 8
# one won round 292 with 2 cards
# Level 1 cards @ round 293: player 1 has cards: 7 and player 2 has cards: 7
# two won round 293 with 2 cards
# Level 1 cards @ round 294: player 1 has cards: 8 and player 2 has cards: 8
# one won round 294 with 2 cards
# Level 1 cards @ round 295: player 1 has cards: 7 and player 2 has cards: 7
# two won round 295 with 2 cards
# Level 1 cards @ round 296: player 1 has cards: 8 and player 2 has cards: 8
# one won round 296 with 2 cards
# Level 1 cards @ round 297: player 1 has cards: 7 and player 2 has cards: 7
# two won round 297 with 2 cards
# Level 1 cards @ round 298: player 1 has cards: 8 and player 2 has cards: 8
# one won round 298 with 2 cards
# Level 1 cards @ round 299: player 1 has cards: 7 and player 2 has cards: 7
# two won round 299 with 2 cards
# Level 1 cards @ round 300: player 1 has cards: 8 and player 2 has cards: 8
# one won round 300 with 2 cards
# Level 1 cards @ round 301: player 1 has cards: 7 and player 2 has cards: 7
# two won round 301 with 2 cards
# Level 1 cards @ round 302: player 1 has cards: 8 and player 2 has cards: 8
# one won round 302 with 2 cards
# Level 1 cards @ round 303: player 1 has cards: 7 and player 2 has cards: 7
# two won round 303 with 2 cards
# Level 1 cards @ round 304: player 1 has cards: 8 and player 2 has cards: 8
# one won round 304 with 2 cards
# Level 1 cards @ round 305: player 1 has cards: 7 and player 2 has cards: 7
# two won round 305 with 2 cards
# Level 1 cards @ round 306: player 1 has cards: 8 and player 2 has cards: 8
# one won round 306 with 2 cards
# Level 1 cards @ round 307: player 1 has cards: 7 and player 2 has cards: 7
# two won round 307 with 2 cards
# Level 1 cards @ round 308: player 1 has cards: 8 and player 2 has cards: 8
# one won round 308 with 2 cards
# Level 1 cards @ round 309: player 1 has cards: 7 and player 2 has cards: 7
# two won round 309 with 2 cards
# Level 1 cards @ round 310: player 1 has cards: 8 and player 2 has cards: 8
# one won round 310 with 2 cards
# Level 1 cards @ round 311: player 1 has cards: 7 and player 2 has cards: 7
# two won round 311 with 2 cards
# Level 1 cards @ round 312: player 1 has cards: 8 and player 2 has cards: 8
# one won round 312 with 2 cards
# Level 1 cards @ round 313: player 1 has cards: 7 and player 2 has cards: 7
# two won round 313 with 2 cards
# Level 1 cards @ round 314: player 1 has cards: 8 and player 2 has cards: 8
# one won round 314 with 2 cards
# Level 1 cards @ round 315: player 1 has cards: 7 and player 2 has cards: 7
# two won round 315 with 2 cards
# Level 1 cards @ round 316: player 1 has cards: 8 and player 2 has cards: 8
# one won round 316 with 2 cards
# Level 1 cards @ round 317: player 1 has cards: 7 and player 2 has cards: 7
# two won round 317 with 2 cards
# Level 1 cards @ round 318: player 1 has cards: 8 and player 2 has cards: 8
# one won round 318 with 2 cards
# Level 1 cards @ round 319: player 1 has cards: 7 and player 2 has cards: 7
# two won round 319 with 2 cards
# Level 1 cards @ round 320: player 1 has cards: 8 and player 2 has cards: 8
# one won round 320 with 2 cards
# Level 1 cards @ round 321: player 1 has cards: 7 and player 2 has cards: 7
# two won round 321 with 2 cards
# Level 1 cards @ round 322: player 1 has cards: 8 and player 2 has cards: 8
# one won round 322 with 2 cards
# Level 1 cards @ round 323: player 1 has cards: 7 and player 2 has cards: 7
# two won round 323 with 2 cards
# Level 1 cards @ round 324: player 1 has cards: 8 and player 2 has cards: 8
# one won round 324 with 2 cards
# Level 1 cards @ round 325: player 1 has cards: 7 and player 2 has cards: 7
# two won round 325 with 2 cards
# Level 1 cards @ round 326: player 1 has cards: 8 and player 2 has cards: 8
# one won round 326 with 2 cards
# Level 1 cards @ round 327: player 1 has cards: 7 and player 2 has cards: 7
# two won round 327 with 2 cards
# Level 1 cards @ round 328: player 1 has cards: 8 and player 2 has cards: 8
# one won round 328 with 2 cards
# Level 1 cards @ round 329: player 1 has cards: 7 and player 2 has cards: 7
# two won round 329 with 2 cards
# Level 1 cards @ round 330: player 1 has cards: 8 and player 2 has cards: 8
# one won round 330 with 2 cards
# Level 1 cards @ round 331: player 1 has cards: 7 and player 2 has cards: 7
# two won round 331 with 2 cards
# Level 1 cards @ round 332: player 1 has cards: 8 and player 2 has cards: 8
# one won round 332 with 2 cards
# Level 1 cards @ round 333: player 1 has cards: 7 and player 2 has cards: 7
# two won round 333 with 2 cards
# Level 1 cards @ round 334: player 1 has cards: 8 and player 2 has cards: 8
# one won round 334 with 2 cards
# Level 1 cards @ round 335: player 1 has cards: 7 and player 2 has cards: 7
# two won round 335 with 2 cards
# Level 1 cards @ round 336: player 1 has cards: 8 and player 2 has cards: 8
# one won round 336 with 2 cards
# Level 1 cards @ round 337: player 1 has cards: 7 and player 2 has cards: 7
# two won round 337 with 2 cards
# Level 1 cards @ round 338: player 1 has cards: 8 and player 2 has cards: 8
# one won round 338 with 2 cards
# Level 1 cards @ round 339: player 1 has cards: 7 and player 2 has cards: 7
# two won round 339 with 2 cards
# Level 1 cards @ round 340: player 1 has cards: 8 and player 2 has cards: 8
# one won round 340 with 2 cards
# Level 1 cards @ round 341: player 1 has cards: 7 and player 2 has cards: 7
# two won round 341 with 2 cards
# Level 1 cards @ round 342: player 1 has cards: 8 and player 2 has cards: 8
# one won round 342 with 2 cards
# Level 1 cards @ round 343: player 1 has cards: 7 and player 2 has cards: 7
# two won round 343 with 2 cards
# Level 1 cards @ round 344: player 1 has cards: 8 and player 2 has cards: 8
# one won round 344 with 2 cards
# Level 1 cards @ round 345: player 1 has cards: 7 and player 2 has cards: 7
# two won round 345 with 2 cards
# Level 1 cards @ round 346: player 1 has cards: 8 and player 2 has cards: 8
# one won round 346 with 2 cards
# Level 1 cards @ round 347: player 1 has cards: 7 and player 2 has cards: 7
# two won round 347 with 2 cards
# Level 1 cards @ round 348: player 1 has cards: 8 and player 2 has cards: 8
# one won round 348 with 2 cards
# Level 1 cards @ round 349: player 1 has cards: 7 and player 2 has cards: 7
# two won round 349 with 2 cards
# Level 1 cards @ round 350: player 1 has cards: 8 and player 2 has cards: 8
# one won round 350 with 2 cards
# Level 1 cards @ round 351: player 1 has cards: 7 and player 2 has cards: 7
# two won round 351 with 2 cards
# Level 1 cards @ round 352: player 1 has cards: 8 and player 2 has cards: 8
# one won round 352 with 2 cards
# Level 1 cards @ round 353: player 1 has cards: 7 and player 2 has cards: 7
# two won round 353 with 2 cards
# Level 1 cards @ round 354: player 1 has cards: 8 and player 2 has cards: 8
# one won round 354 with 2 cards
# Level 1 cards @ round 355: player 1 has cards: 7 and player 2 has cards: 7
# two won round 355 with 2 cards
# Level 1 cards @ round 356: player 1 has cards: 8 and player 2 has cards: 8
# one won round 356 with 2 cards
# Level 1 cards @ round 357: player 1 has cards: 7 and player 2 has cards: 7
# two won round 357 with 2 cards
# Level 1 cards @ round 358: player 1 has cards: 8 and player 2 has cards: 8
# one won round 358 with 2 cards
# Level 1 cards @ round 359: player 1 has cards: 7 and player 2 has cards: 7
# two won round 359 with 2 cards
# Level 1 cards @ round 360: player 1 has cards: 8 and player 2 has cards: 8
# one won round 360 with 2 cards
# Level 1 cards @ round 361: player 1 has cards: 7 and player 2 has cards: 7
# two won round 361 with 2 cards
# Level 1 cards @ round 362: player 1 has cards: 8 and player 2 has cards: 8
# one won round 362 with 2 cards
# Level 1 cards @ round 363: player 1 has cards: 7 and player 2 has cards: 7
# two won round 363 with 2 cards
# Level 1 cards @ round 364: player 1 has cards: 8 and player 2 has cards: 8
# one won round 364 with 2 cards
# Level 1 cards @ round 365: player 1 has cards: 7 and player 2 has cards: 7
# two won round 365 with 2 cards
# Level 1 cards @ round 366: player 1 has cards: 8 and player 2 has cards: 8
# one won round 366 with 2 cards
# Level 1 cards @ round 367: player 1 has cards: 7 and player 2 has cards: 7
# two won round 367 with 2 cards
# Level 1 cards @ round 368: player 1 has cards: 8 and player 2 has cards: 8
# one won round 368 with 2 cards
# Level 1 cards @ round 369: player 1 has cards: 7 and player 2 has cards: 7
# two won round 369 with 2 cards
# Level 1 cards @ round 370: player 1 has cards: 8 and player 2 has cards: 8
# one won round 370 with 2 cards
# Level 1 cards @ round 371: player 1 has cards: 7 and player 2 has cards: 7
# two won round 371 with 2 cards
# Level 1 cards @ round 372: player 1 has cards: 8 and player 2 has cards: 8
# one won round 372 with 2 cards
# Level 1 cards @ round 373: player 1 has cards: 7 and player 2 has cards: 7
# two won round 373 with 2 cards
# Level 1 cards @ round 374: player 1 has cards: 8 and player 2 has cards: 8
# one won round 374 with 2 cards
# Level 1 cards @ round 375: player 1 has cards: 7 and player 2 has cards: 7
# two won round 375 with 2 cards
# Level 1 cards @ round 376: player 1 has cards: 8 and player 2 has cards: 8
# one won round 376 with 2 cards
# Level 1 cards @ round 377: player 1 has cards: 7 and player 2 has cards: 7
# two won round 377 with 2 cards
# Level 1 cards @ round 378: player 1 has cards: 8 and player 2 has cards: 8
# one won round 378 with 2 cards
# Level 1 cards @ round 379: player 1 has cards: 7 and player 2 has cards: 7
# two won round 379 with 2 cards
# Level 1 cards @ round 380: player 1 has cards: 8 and player 2 has cards: 8
# one won round 380 with 2 cards
# Level 1 cards @ round 381: player 1 has cards: 7 and player 2 has cards: 7
# two won round 381 with 2 cards
# Level 1 cards @ round 382: player 1 has cards: 8 and player 2 has cards: 8
# one won round 382 with 2 cards
# Level 1 cards @ round 383: player 1 has cards: 7 and player 2 has cards: 7
# two won round 383 with 2 cards
# Level 1 cards @ round 384: player 1 has cards: 8 and player 2 has cards: 8
# one won round 384 with 2 cards
# Level 1 cards @ round 385: player 1 has cards: 7 and player 2 has cards: 7
# two won round 385 with 2 cards
# Level 1 cards @ round 386: player 1 has cards: 8 and player 2 has cards: 8
# one won round 386 with 2 cards
# Level 1 cards @ round 387: player 1 has cards: 7 and player 2 has cards: 7
# two won round 387 with 2 cards
# Level 1 cards @ round 388: player 1 has cards: 8 and player 2 has cards: 8
# one won round 388 with 2 cards
# Level 1 cards @ round 389: player 1 has cards: 7 and player 2 has cards: 7
# two won round 389 with 2 cards
# Level 1 cards @ round 390: player 1 has cards: 8 and player 2 has cards: 8
# one won round 390 with 2 cards
# Level 1 cards @ round 391: player 1 has cards: 7 and player 2 has cards: 7
# two won round 391 with 2 cards
# Level 1 cards @ round 392: player 1 has cards: 8 and player 2 has cards: 8
# one won round 392 with 2 cards
# Level 1 cards @ round 393: player 1 has cards: 7 and player 2 has cards: 7
# two won round 393 with 2 cards
# Level 1 cards @ round 394: player 1 has cards: 8 and player 2 has cards: 8
# one won round 394 with 2 cards
# Level 1 cards @ round 395: player 1 has cards: 7 and player 2 has cards: 7
# two won round 395 with 2 cards
# Level 1 cards @ round 396: player 1 has cards: 8 and player 2 has cards: 8
# one won round 396 with 2 cards
# Level 1 cards @ round 397: player 1 has cards: 7 and player 2 has cards: 7
# two won round 397 with 2 cards
# Level 1 cards @ round 398: player 1 has cards: 8 and player 2 has cards: 8
# one won round 398 with 2 cards
# Level 1 cards @ round 399: player 1 has cards: 7 and player 2 has cards: 7
# two won round 399 with 2 cards
# Level 1 cards @ round 400: player 1 has cards: 8 and player 2 has cards: 8
# one won round 400 with 2 cards
# Level 1 cards @ round 401: player 1 has cards: 7 and player 2 has cards: 7
# two won round 401 with 2 cards
# Level 1 cards @ round 402: player 1 has cards: 8 and player 2 has cards: 8
# one won round 402 with 2 cards
# Level 1 cards @ round 403: player 1 has cards: 7 and player 2 has cards: 7
# two won round 403 with 2 cards
# Level 1 cards @ round 404: player 1 has cards: 8 and player 2 has cards: 8
# one won round 404 with 2 cards
# Level 1 cards @ round 405: player 1 has cards: 7 and player 2 has cards: 7
# two won round 405 with 2 cards
# Level 1 cards @ round 406: player 1 has cards: 8 and player 2 has cards: 8
# one won round 406 with 2 cards
# Level 1 cards @ round 407: player 1 has cards: 7 and player 2 has cards: 7
# two won round 407 with 2 cards
# Level 1 cards @ round 408: player 1 has cards: 8 and player 2 has cards: 8
# one won round 408 with 2 cards
# Level 1 cards @ round 409: player 1 has cards: 7 and player 2 has cards: 7
# two won round 409 with 2 cards
# Level 1 cards @ round 410: player 1 has cards: 8 and player 2 has cards: 8
# one won round 410 with 2 cards
# Level 1 cards @ round 411: player 1 has cards: 7 and player 2 has cards: 7
# two won round 411 with 2 cards
# Level 1 cards @ round 412: player 1 has cards: 8 and player 2 has cards: 8
# one won round 412 with 2 cards
# Level 1 cards @ round 413: player 1 has cards: 7 and player 2 has cards: 7
# two won round 413 with 2 cards
# Level 1 cards @ round 414: player 1 has cards: 8 and player 2 has cards: 8
# one won round 414 with 2 cards
# Level 1 cards @ round 415: player 1 has cards: 7 and player 2 has cards: 7
# two won round 415 with 2 cards
# Level 1 cards @ round 416: player 1 has cards: 8 and player 2 has cards: 8
# one won round 416 with 2 cards
# Level 1 cards @ round 417: player 1 has cards: 7 and player 2 has cards: 7
# two won round 417 with 2 cards
# Level 1 cards @ round 418: player 1 has cards: 8 and player 2 has cards: 8
# one won round 418 with 2 cards
# Level 1 cards @ round 419: player 1 has cards: 7 and player 2 has cards: 7
# two won round 419 with 2 cards
# Level 1 cards @ round 420: player 1 has cards: 8 and player 2 has cards: 8
# one won round 420 with 2 cards
# Level 1 cards @ round 421: player 1 has cards: 7 and player 2 has cards: 7
# two won round 421 with 2 cards
# Level 1 cards @ round 422: player 1 has cards: 8 and player 2 has cards: 8
# one won round 422 with 2 cards
# Level 1 cards @ round 423: player 1 has cards: 7 and player 2 has cards: 7
# two won round 423 with 2 cards
# Level 1 cards @ round 424: player 1 has cards: 8 and player 2 has cards: 8
# one won round 424 with 2 cards
# Level 1 cards @ round 425: player 1 has cards: 7 and player 2 has cards: 7
# two won round 425 with 2 cards
# Level 1 cards @ round 426: player 1 has cards: 8 and player 2 has cards: 8
# one won round 426 with 2 cards
# Level 1 cards @ round 427: player 1 has cards: 7 and player 2 has cards: 7
# two won round 427 with 2 cards
# Level 1 cards @ round 428: player 1 has cards: 8 and player 2 has cards: 8
# one won round 428 with 2 cards
# Level 1 cards @ round 429: player 1 has cards: 7 and player 2 has cards: 7
# two won round 429 with 2 cards
# Level 1 cards @ round 430: player 1 has cards: 8 and player 2 has cards: 8
# one won round 430 with 2 cards
# Level 1 cards @ round 431: player 1 has cards: 7 and player 2 has cards: 7
# two won round 431 with 2 cards
# Level 1 cards @ round 432: player 1 has cards: 8 and player 2 has cards: 8
# one won round 432 with 2 cards
# Level 1 cards @ round 433: player 1 has cards: 7 and player 2 has cards: 7
# two won round 433 with 2 cards
# Level 1 cards @ round 434: player 1 has cards: 8 and player 2 has cards: 8
# one won round 434 with 2 cards
# Level 1 cards @ round 435: player 1 has cards: 7 and player 2 has cards: 7
# two won round 435 with 2 cards
# Level 1 cards @ round 436: player 1 has cards: 8 and player 2 has cards: 8
# one won round 436 with 2 cards
# Level 1 cards @ round 437: player 1 has cards: 7 and player 2 has cards: 7
# two won round 437 with 2 cards
# Level 1 cards @ round 438: player 1 has cards: 8 and player 2 has cards: 8
# one won round 438 with 2 cards
# Level 1 cards @ round 439: player 1 has cards: 7 and player 2 has cards: 7
# two won round 439 with 2 cards
# Level 1 cards @ round 440: player 1 has cards: 8 and player 2 has cards: 8
# one won round 440 with 2 cards
# Level 1 cards @ round 441: player 1 has cards: 7 and player 2 has cards: 7
# two won round 441 with 2 cards
# Level 1 cards @ round 442: player 1 has cards: 8 and player 2 has cards: 8
# one won round 442 with 2 cards
# Level 1 cards @ round 443: player 1 has cards: 7 and player 2 has cards: 7
# two won round 443 with 2 cards
# Level 1 cards @ round 444: player 1 has cards: 8 and player 2 has cards: 8
# one won round 444 with 2 cards
# Level 1 cards @ round 445: player 1 has cards: 7 and player 2 has cards: 7
# two won round 445 with 2 cards
# Level 1 cards @ round 446: player 1 has cards: 8 and player 2 has cards: 8
# one won round 446 with 2 cards
# Level 1 cards @ round 447: player 1 has cards: 7 and player 2 has cards: 7
# two won round 447 with 2 cards
# Level 1 cards @ round 448: player 1 has cards: 8 and player 2 has cards: 8
# one won round 448 with 2 cards
# Level 1 cards @ round 449: player 1 has cards: 7 and player 2 has cards: 7
# two won round 449 with 2 cards
# Level 1 cards @ round 450: player 1 has cards: 8 and player 2 has cards: 8
# one won round 450 with 2 cards
# Level 1 cards @ round 451: player 1 has cards: 7 and player 2 has cards: 7
# two won round 451 with 2 cards
# Level 1 cards @ round 452: player 1 has cards: 8 and player 2 has cards: 8
# one won round 452 with 2 cards
# Level 1 cards @ round 453: player 1 has cards: 7 and player 2 has cards: 7
# two won round 453 with 2 cards
# Level 1 cards @ round 454: player 1 has cards: 8 and player 2 has cards: 8
# one won round 454 with 2 cards
# Level 1 cards @ round 455: player 1 has cards: 7 and player 2 has cards: 7
# two won round 455 with 2 cards
# ...
# one won round 10386 with 2 cards
# Level 1 cards @ round 10387: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10387 with 2 cards
# Level 1 cards @ round 10388: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10388 with 2 cards
# Level 1 cards @ round 10389: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10389 with 2 cards
# Level 1 cards @ round 10390: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10390 with 2 cards
# Level 1 cards @ round 10391: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10391 with 2 cards
# Level 1 cards @ round 10392: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10392 with 2 cards
# Level 1 cards @ round 10393: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10393 with 2 cards
# Level 1 cards @ round 10394: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10394 with 2 cards
# Level 1 cards @ round 10395: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10395 with 2 cards
# Level 1 cards @ round 10396: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10396 with 2 cards
# Level 1 cards @ round 10397: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10397 with 2 cards
# Level 1 cards @ round 10398: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10398 with 2 cards
# Level 1 cards @ round 10399: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10399 with 2 cards
# Level 1 cards @ round 10400: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10400 with 2 cards
# Level 1 cards @ round 10401: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10401 with 2 cards
# Level 1 cards @ round 10402: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10402 with 2 cards
# Level 1 cards @ round 10403: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10403 with 2 cards
# Level 1 cards @ round 10404: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10404 with 2 cards
# Level 1 cards @ round 10405: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10405 with 2 cards
# Level 1 cards @ round 10406: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10406 with 2 cards
# Level 1 cards @ round 10407: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10407 with 2 cards
# Level 1 cards @ round 10408: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10408 with 2 cards
# Level 1 cards @ round 10409: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10409 with 2 cards
# Level 1 cards @ round 10410: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10410 with 2 cards
# Level 1 cards @ round 10411: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10411 with 2 cards
# Level 1 cards @ round 10412: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10412 with 2 cards
# Level 1 cards @ round 10413: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10413 with 2 cards
# Level 1 cards @ round 10414: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10414 with 2 cards
# Level 1 cards @ round 10415: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10415 with 2 cards
# Level 1 cards @ round 10416: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10416 with 2 cards
# Level 1 cards @ round 10417: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10417 with 2 cards
# Level 1 cards @ round 10418: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10418 with 2 cards
# Level 1 cards @ round 10419: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10419 with 2 cards
# Level 1 cards @ round 10420: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10420 with 2 cards
# Level 1 cards @ round 10421: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10421 with 2 cards
# Level 1 cards @ round 10422: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10422 with 2 cards
# Level 1 cards @ round 10423: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10423 with 2 cards
# Level 1 cards @ round 10424: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10424 with 2 cards
# Level 1 cards @ round 10425: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10425 with 2 cards
# Level 1 cards @ round 10426: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10426 with 2 cards
# Level 1 cards @ round 10427: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10427 with 2 cards
# Level 1 cards @ round 10428: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10428 with 2 cards
# Level 1 cards @ round 10429: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10429 with 2 cards
# Level 1 cards @ round 10430: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10430 with 2 cards
# Level 1 cards @ round 10431: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10431 with 2 cards
# Level 1 cards @ round 10432: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10432 with 2 cards
# Level 1 cards @ round 10433: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10433 with 2 cards
# Level 1 cards @ round 10434: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10434 with 2 cards
# Level 1 cards @ round 10435: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10435 with 2 cards
# Level 1 cards @ round 10436: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10436 with 2 cards
# Level 1 cards @ round 10437: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10437 with 2 cards
# Level 1 cards @ round 10438: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10438 with 2 cards
# Level 1 cards @ round 10439: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10439 with 2 cards
# Level 1 cards @ round 10440: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10440 with 2 cards
# Level 1 cards @ round 10441: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10441 with 2 cards
# Level 1 cards @ round 10442: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10442 with 2 cards
# Level 1 cards @ round 10443: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10443 with 2 cards
# Level 1 cards @ round 10444: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10444 with 2 cards
# Level 1 cards @ round 10445: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10445 with 2 cards
# Level 1 cards @ round 10446: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10446 with 2 cards
# Level 1 cards @ round 10447: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10447 with 2 cards
# Level 1 cards @ round 10448: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10448 with 2 cards
# Level 1 cards @ round 10449: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10449 with 2 cards
# Level 1 cards @ round 10450: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10450 with 2 cards
# Level 1 cards @ round 10451: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10451 with 2 cards
# Level 1 cards @ round 10452: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10452 with 2 cards
# Level 1 cards @ round 10453: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10453 with 2 cards
# Level 1 cards @ round 10454: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10454 with 2 cards
# Level 1 cards @ round 10455: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10455 with 2 cards
# Level 1 cards @ round 10456: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10456 with 2 cards
# Level 1 cards @ round 10457: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10457 with 2 cards
# Level 1 cards @ round 10458: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10458 with 2 cards
# Level 1 cards @ round 10459: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10459 with 2 cards
# Level 1 cards @ round 10460: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10460 with 2 cards
# Level 1 cards @ round 10461: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10461 with 2 cards
# Level 1 cards @ round 10462: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10462 with 2 cards
# Level 1 cards @ round 10463: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10463 with 2 cards
# Level 1 cards @ round 10464: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10464 with 2 cards
# Level 1 cards @ round 10465: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10465 with 2 cards
# Level 1 cards @ round 10466: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10466 with 2 cards
# Level 1 cards @ round 10467: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10467 with 2 cards
# Level 1 cards @ round 10468: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10468 with 2 cards
# Level 1 cards @ round 10469: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10469 with 2 cards
# Level 1 cards @ round 10470: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10470 with 2 cards
# Level 1 cards @ round 10471: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10471 with 2 cards
# Level 1 cards @ round 10472: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10472 with 2 cards
# Level 1 cards @ round 10473: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10473 with 2 cards
# Level 1 cards @ round 10474: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10474 with 2 cards
# Level 1 cards @ round 10475: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10475 with 2 cards
# Level 1 cards @ round 10476: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10476 with 2 cards
# Level 1 cards @ round 10477: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10477 with 2 cards
# Level 1 cards @ round 10478: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10478 with 2 cards
# Level 1 cards @ round 10479: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10479 with 2 cards
# Level 1 cards @ round 10480: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10480 with 2 cards
# Level 1 cards @ round 10481: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10481 with 2 cards
# Level 1 cards @ round 10482: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10482 with 2 cards
# Level 1 cards @ round 10483: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10483 with 2 cards
# Level 1 cards @ round 10484: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10484 with 2 cards
# Level 1 cards @ round 10485: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10485 with 2 cards
# Level 1 cards @ round 10486: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10486 with 2 cards
# Level 1 cards @ round 10487: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10487 with 2 cards
# Level 1 cards @ round 10488: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10488 with 2 cards
# Level 1 cards @ round 10489: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10489 with 2 cards
# Level 1 cards @ round 10490: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10490 with 2 cards
# Level 1 cards @ round 10491: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10491 with 2 cards
# Level 1 cards @ round 10492: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10492 with 2 cards
# Level 1 cards @ round 10493: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10493 with 2 cards
# Level 1 cards @ round 10494: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10494 with 2 cards
# Level 1 cards @ round 10495: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10495 with 2 cards
# Level 1 cards @ round 10496: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10496 with 2 cards
# Level 1 cards @ round 10497: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10497 with 2 cards
# Level 1 cards @ round 10498: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10498 with 2 cards
# Level 1 cards @ round 10499: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10499 with 2 cards
# Level 1 cards @ round 10500: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10500 with 2 cards
# Level 1 cards @ round 10501: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10501 with 2 cards
# Level 1 cards @ round 10502: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10502 with 2 cards
# Level 1 cards @ round 10503: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10503 with 2 cards
# Level 1 cards @ round 10504: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10504 with 2 cards
# Level 1 cards @ round 10505: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10505 with 2 cards
# Level 1 cards @ round 10506: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10506 with 2 cards
# Level 1 cards @ round 10507: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10507 with 2 cards
# Level 1 cards @ round 10508: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10508 with 2 cards
# Level 1 cards @ round 10509: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10509 with 2 cards
# Level 1 cards @ round 10510: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10510 with 2 cards
# Level 1 cards @ round 10511: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10511 with 2 cards
# Level 1 cards @ round 10512: player 1 has cards: 6 and player 2 has cards: 6
# one won round 10512 with 2 cards
# Level 1 cards @ round 10513: player 1 has cards: 5 and player 2 has cards: 5
# two won round 10513 with 2 cards
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-f1e8ab410818> in <module>()
# ----> 1 game.play()
#
# <ipython-input-36-ed62c1fbb8d2> in play(self)
#      73             self.cards_to_be_won = []
#      74             self.tie_count = 0
# ---> 75             self.play_round()
#      76                 #players_have_cards = (self.player2.has_cards() and self.player1.has_cards())
#      77                 #no_winner = (self.winner()==None)
#
# <ipython-input-36-ed62c1fbb8d2> in play_round(self)
#      43
#      44         elif(player2_card.value>player1_card.value):
# ---> 45             print(f"{self.player2.name} won round {self.game_round} with {len(self.cards_to_be_won)} cards")
#      46             self.player2.add_cards(self.cards_to_be_won)
#      47             self.cards_to_be_won.clear()
#
# /anaconda3/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     374             is_child = (not self._is_master_process())
#     375             # only touch the buffer in the IO thread to avoid races
# --> 376             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     377             if is_child:
#     378                 # newlines imply flush in subprocesses
#
# /anaconda3/lib/python3.6/site-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /anaconda3/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
player_one = Player("One")

# %%
player_two = Player("Two")

# %% [markdown]
# ## Setup New Game

# %%
new_deck = Deck()

# %%
new_deck.shuffle()

# %% [markdown]
# ### Split the Deck between players

# %%
len(new_deck.all_cards)/2
# Out:
# 26.0

# %%
for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())

# %%
len(new_deck.all_cards)
# Out:
# 0

# %%
len(player_one.all_cards)
# Out:
# 26

# %%
len(player_two.all_cards)
# Out:
# 26

# %% [markdown]
# ## Play the Game

# %%
import pdb

# %%
game_on = True

# %%
round_num = 0
while game_on:
    
    round_num += 1
    print(f"Round {round_num}")
    
    # Check to see if a player is out of cards:
    if len(player_one.all_cards) == 0:
        print("Player One out of cards! Game Over")
        print("Player Two Wins!")
        game_on = False
        break
        
    if len(player_two.all_cards) == 0:
        print("Player Two out of cards! Game Over")
        print("Player One Wins!")
        game_on = False
        break
    
    # Otherwise, the game is still on!
    
    # Start a new round and reset current cards "on the table"
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
    
    at_war = True

    while at_war:


        if player_one_cards[-1].value > player_two_cards[-1].value:

            # Player One gets the cards
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            
            
            # No Longer at "war" , time for next round
            at_war = False
        
        # Player Two Has higher Card
        elif player_one_cards[-1].value < player_two_cards[-1].value:

            # Player Two gets the cards
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            
            # No Longer at "war" , time for next round
            at_war = False

        else:
            print('WAR!')
            # This occurs when the cards are equal.
            # We'll grab another card each and continue the current war.
            
            # First check to see if player has enough cards
            
            # Check to see if a player is out of cards:
            if len(player_one.all_cards) < 5:
                print("Player One unable to play war! Game Over at War")
                print("Player Two Wins! Player One Loses!")
                game_on = False
                break

            elif len(player_two.all_cards) < 5:
                print("Player Two unable to play war! Game Over at War")
                print("Player One Wins! Player One Loses!")
                game_on = False
                break
            # Otherwise, we're still at war, so we'll add the next cards
            else:
                for num in range(5):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# Round 10
# Round 11
# Round 12
# Round 13
# Round 14
# Round 15
# Round 16
# Round 17
# Round 18
# Round 19
# Round 20
# Round 21
# Round 22
# Round 23
# Round 24
# Round 25
# Round 26
# Round 27
# Player One out of cards! Game Over

# %%
x = False

# %%
print(not x)
# Out:
# True

# %% [markdown]
# ## Game Setup in One Cell

# %%
player_one = Player("One")
player_two = Player("Two")

new_deck = Deck()
new_deck.shuffle()

for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())
    
game_on = True

# %%
round_num = 0
while game_on:
    
    round_num += 1
    print(f"Round {round_num}")
    
    # Check to see if a player is out of cards:
    if len(player_one.all_cards) == 0:
        print("Player One out of cards! Game Over")
        print("Player Two Wins!")
        game_on = False
        break
        
    if len(player_two.all_cards) == 0:
        print("Player Two out of cards! Game Over")
        print("Player One Wins!")
        game_on = False
        break
    
    # Otherwise, the game is still on!
    
    # Start a new round and reset current cards "on the table"
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
    
    at_war = True

    while at_war:


        if player_one_cards[-1].value > player_two_cards[-1].value:

            # Player One gets the cards
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            
            
            # No Longer at "war" , time for next round
            at_war = False
        
        # Player Two Has higher Card
        elif player_one_cards[-1].value < player_two_cards[-1].value:

            # Player Two gets the cards
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            
            # No Longer at "war" , time for next round
            at_war = False

        else:
            print('WAR!')
            # This occurs when the cards are equal.
            # We'll grab another card each and continue the current war.
            
            # First check to see if player has enough cards
            
            # Check to see if a player is out of cards:
            if len(player_one.all_cards) < 5:
                print("Player One unable to play war! Game Over at War")
                print("Player Two Wins! Player One Loses!")
                game_on = False
                break

            elif len(player_two.all_cards) < 5:
                print("Player Two unable to play war! Game Over at War")
                print("Player One Wins! Player One Loses!")
                game_on = False
                break
            # Otherwise, we're still at war, so we'll add the next cards
            else:
                for num in range(5):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Round 1
# Round 2
# WAR!
# Round 3
# WAR!
# WAR!
# Round 4
# WAR!
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# Round 10
# Round 11
# Round 12
# Round 13
# WAR!
# Round 14
# Round 15
# WAR!
# Round 16
# Round 17
# Round 18
# Round 19
# Round 20
# Round 21
# Round 22
# Round 23
# Round 24
# Round 25
# Round 26
# Round 27
# Round 28
# Round 29
# WAR!
# Round 30
# Round 31
# Round 32
# WAR!
# Round 33
# Round 34
# Round 35
# Round 36
# Round 37
# Round 38
# Round 39
# Round 40
# Round 41
# Round 42
# WAR!
# WAR!
# Round 43
# Round 44
# Round 45
# Round 46
# Round 47
# Round 48
# Round 49
# Round 50
# Round 51
# Round 52
# Round 53
# Round 54
# Round 55
# Round 56
# Round 57
# Round 58
# Round 59
# Round 60
# Round 61
# Round 62
# Round 63
# Round 64
# Round 65
# Round 66
# Round 67
# Round 68
# Round 69
# Round 70
# Round 71
# Round 72
# Round 73
# Round 74
# Round 75
# Round 76
# Round 77
# Round 78
# Round 79
# Round 80
# Round 81
# Round 82
# Round 83
# Round 84
# Round 85
# Round 86
# Round 87
# Round 88
# Round 89
# Round 90
# Round 91
# Round 92
# Round 93
# Round 94
# Round 95
# Round 96
# Round 97
# Round 98
# Round 99
# Round 100
# Round 101
# Round 102
# Round 103
# Round 104
# Round 105
# Round 106
# Round 107
# Round 108
# WAR!
# Round 109
# Round 110
# Round 111
# Round 112
# Round 113
# Round 114
# Round 115
# Round 116
# Round 117
# Round 118
# Round 119
# Round 120
# Round 121
# Round 122
# Round 123
# Round 124
# Round 125
# Round 126
# Round 127
# Round 128
# Round 129
# Round 130
# Round 131
# Round 132
# Round 133
# Round 134
# WAR!
# Round 135
# Round 136
# WAR!
# Round 137
# WAR!
# Round 138
# Round 139
# Round 140
# Round 141
# Round 142
# Round 143
# Round 144
# Round 145
# Round 146
# Round 147
# Round 148
# Round 149
# Round 150
# Round 151
# Round 152
# Round 153
# Round 154
# Round 155
# Round 156
# Round 157
# Round 158
# Round 159
# Round 160
# Round 161
# Round 162
# Round 163
# Round 164
# Round 165
# Round 166
# Round 167
# Round 168
# Round 169
# Round 170
# Round 171
# Round 172
# Round 173
# Round 174
# Round 175
# Round 176
# Round 177
# Round 178
# Round 179
# Round 180
# Round 181
# Round 182
# Round 183
# Round 184
# Round 185
# Round 186
# Round 187
# Round 188
# Round 189
# Round 190
# Round 191
# Round 192
# Round 193
# Round 194
# Round 195
# Round 196
# Round 197
# Round 198
# Round 199
# Round 200
# Round 201
# Round 202
# Round 203
# Round 204
# Round 205
# Round 206
# Round 207
# Round 208
# Round 209
# Round 210
# Round 211
# Round 212
# Round 213
# Round 214
# Round 215
# Round 216
# Round 217
# Round 218
# Round 219
# Round 220
# Round 221
# Round 222
# Round 223
# WAR!
# Round 224
# Round 225
# Round 226
# Round 227
# Round 228
# Round 229
# Round 230
# Round 231
# Round 232
# Round 233
# Round 234
# Round 235
# Round 236
# Round 237
# Round 238
# Round 239
# Round 240
# Round 241
# Round 242
# Round 243
# Round 244
# Round 245
# Round 246
# Round 247
# Round 248
# Round 249
# Round 250
# Round 251
# Round 252
# Round 253
# Round 254
# Round 255
# Round 256
# Round 257
# WAR!
# Round 258
# Round 259
# Round 260
# Round 261
# Round 262
# Round 263
# Round 264
# Round 265
# Round 266
# Round 267
# Round 268
# Round 269
# Round 270
# Round 271
# Round 272
# Round 273
# Round 274
# Round 275
# Round 276
# Round 277
# Round 278
# Round 279
# Round 280
# Round 281
# Round 282
# Round 283
# Round 284
# Round 285
# Round 286
# Round 287
# Round 288
# Round 289
# Round 290
# Round 291
# Round 292
# Round 293
# Round 294
# Round 295
# Round 296
# Round 297
# Round 298
# Round 299
# Round 300
# Round 301
# Round 302
# Round 303
# Round 304
# Round 305
# Round 306
# Round 307
# WAR!
# Round 308
# Round 309
# Round 310
# Round 311
# Round 312
# Round 313
# Round 314
# Round 315
# WAR!
# Round 316
# Round 317
# Round 318
# Round 319
# Round 320
# Round 321
# Round 322
# Round 323
# Round 324
# Round 325
# Round 326
# Round 327
# Round 328
# Round 329
# Round 330
# Round 331
# Round 332
# Round 333
# Round 334
# Round 335
# Round 336
# Round 337
# Round 338
# Round 339
# Round 340
# Round 341
# Round 342
# Round 343
# Round 344
# Round 345
# Round 346
# Round 347
# Round 348
# Round 349
# WAR!
# Round 350
# WAR!
# Player Two unable to play war! Game Over at War
# Player One Wins! Player One Loses!

# %%
len(player_one.all_cards)
# Out:
# 27

# %%
len(player_two.all_cards)
# Out:
# 25

# %%
print(player_one_cards[-1])
# Out:
# Ace of Diamonds

# %%
print(player_two_cards[-1])
# Out:
# Four of Hearts

# %% [markdown]
# ## Great Work!
#
# Other links that may interest you:
# * https://www.reddit.com/r/learnpython/comments/7ay83p/war_card_game/
# * https://codereview.stackexchange.com/questions/131174/war-card-game-using-classes
# * https://gist.github.com/damianesteban/6896120
# * https://lethain.com/war-card-game-in-python/
# * https://hectorpefo.github.io/2017-09-13-Card-Wars/
# * https://www.wimpyprogrammer.com/the-statistics-of-war-the-card-game
