# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Opening and Reading Files
#
# So far we've discussed how to open files manually, one by one. Let's explore how we can open files programatically.

# %% [markdown]
# _____

# %% [markdown]
# ### Review: Understanding File Paths

# %%
pwd #current file path in the format of your os
# Out:
# '/Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets'

# %% [markdown]
# ### Create Practice File
#
# We will begin by creating a practice text file that we will be using for demonstration.

# %%
f = open('/Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/open and read files and folders exercise.txt','w+')
f.write('Line 1 of string to write.')
f.close()

# %% [markdown]
# ### Getting Directories
#
# Python has a built-in [os module](https://docs.python.org/3/library/os.html) that allows us to use operating system dependent functionality.
#
# You can get the current directory:

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets'

# %% [markdown]
# ### Listing Files in a Directory
#
# You can also use the os module to list directories.

# %%
# In your current directory
os.listdir()
# Out:
# [' Section 13 - Iterators and Generators Homework.ipynb',
#  ' Section 13 - Python Generators.ipynb',
#  '.DS_Store',
#  '.ipynb_checkpoints',
#  '04-Comparison operators worksheet.ipynb',
#  '05-Python statements worksheet.ipynb',
#  '06-Function Practice Exercises.ipynb',
#  '06-Methods and Functions.ipynb',
#  '08-Functions and Methods Homework.ipynb',
#  '09-Objects and Data Structures Assessment Test.ipynb',
#  'course_source_code',
#  'course_source_code.zip',
#  'file_for_io.txt',
#  'myfile.txt',
#  'new_append.txt',
#  'new_overwrite.txt',
#  'open and read files and folders exercise.txt',
#  'README.md',
#  'Section 10 - Errors and Exceptions Handling Homework.ipynb',
#  'Section 10 - Errors and Exceptions Handling.ipynb',
#  'Section 10- UnitTesting',
#  'Section 11 - Milestone Project - 2 - Assignment.ipynb',
#  'Section 11 - Milestone Project - 2-Warmup-Project.ipynb',
#  'Section 12 - Python Decorators.ipynb',
#  'Section 14 - Advanced Python Modules - Collections.ipynb',
#  'Section 14 - Advanced Python Modules_2.ipynb',
#  'Section 7 - Milestone Project - 1.ipynb',
#  'Section 8 - Object Oriented Programming - Homework.ipynb',
#  'Section 8 - Object Oriented Programming Challenge.ipynb',
#  'Section 8 - Object Oriented Programming.ipynb',
#  'Section 9 - Modules and Packages.ipynb',
#  'section10ErrorsAndExceptions',
#  'section3-object_data_structure_basics.ipynb',
#  'section9ModulesandPackages',
#  'test_files2',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'write.txt']

# %%
# In any directory you pass
os.listdir("/Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets")
# Out:
# [' Section 13 - Iterators and Generators Homework.ipynb',
#  ' Section 13 - Python Generators.ipynb',
#  '.DS_Store',
#  '.ipynb_checkpoints',
#  '04-Comparison operators worksheet.ipynb',
#  '05-Python statements worksheet.ipynb',
#  '06-Function Practice Exercises.ipynb',
#  '06-Methods and Functions.ipynb',
#  '08-Functions and Methods Homework.ipynb',
#  '09-Objects and Data Structures Assessment Test.ipynb',
#  'course_source_code',
#  'course_source_code.zip',
#  'file_for_io.txt',
#  'myfile.txt',
#  'new_append.txt',
#  'new_overwrite.txt',
#  'open and read files and folders exercise.txt',
#  'README.md',
#  'Section 10 - Errors and Exceptions Handling Homework.ipynb',
#  'Section 10 - Errors and Exceptions Handling.ipynb',
#  'Section 10- UnitTesting',
#  'Section 11 - Milestone Project - 2 - Assignment.ipynb',
#  'Section 11 - Milestone Project - 2-Warmup-Project.ipynb',
#  'Section 12 - Python Decorators.ipynb',
#  'Section 14 - Advanced Python Modules - Collections.ipynb',
#  'Section 14 - Advanced Python Modules_2.ipynb',
#  'Section 7 - Milestone Project - 1.ipynb',
#  'Section 8 - Object Oriented Programming - Homework.ipynb',
#  'Section 8 - Object Oriented Programming Challenge.ipynb',
#  'Section 8 - Object Oriented Programming.ipynb',
#  'Section 9 - Modules and Packages.ipynb',
#  'section10ErrorsAndExceptions',
#  'section3-object_data_structure_basics.ipynb',
#  'section9ModulesandPackages',
#  'test_files2',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'write.txt']

# %% [markdown]
# ### Moving Files
#
# You can use the built-in **shutil** module to to move files to different locations. Keep in mind, there are permission restrictions, for example if you are logged in a User A, you won't be able to make changes to the top level Users folder without the proper permissions, [more info](https://stackoverflow.com/questions/23253439/shutil-movescr-dst-gets-me-ioerror-errno-13-permission-denied-and-3-more-e)

# %%
import shutil
shutil.move('/Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/test_files','/Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/test_files2/')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-10-531abd1c6cd8> in <module>()
#       1 import shutil
# ----> 2 shutil.move('/Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/test_files','/Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/test_files2/')
#
# /anaconda3/lib/python3.6/shutil.py in move(src, dst, copy_function)
#     540         real_dst = os.path.join(dst, _basename(src))
#     541         if os.path.exists(real_dst):
# --> 542             raise Error("Destination path '%s' already exists" % real_dst)
#     543     try:
#     544         os.rename(src, real_dst)
#
# Error: Destination path '/Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/test_files2/test_files' already exists

# %%
os.listdir()
# Out:
# [' Section 13 - Iterators and Generators Homework.ipynb',
#  ' Section 13 - Python Generators.ipynb',
#  '.DS_Store',
#  '.ipynb_checkpoints',
#  '04-Comparison operators worksheet.ipynb',
#  '05-Python statements worksheet.ipynb',
#  '06-Function Practice Exercises.ipynb',
#  '06-Methods and Functions.ipynb',
#  '08-Functions and Methods Homework.ipynb',
#  '09-Objects and Data Structures Assessment Test.ipynb',
#  'course_source_code',
#  'course_source_code.zip',
#  'file_for_io.txt',
#  'myfile.txt',
#  'new_append.txt',
#  'new_overwrite.txt',
#  'open and read files and folders exercise.txt',
#  'README.md',
#  'Section 10 - Errors and Exceptions Handling Homework.ipynb',
#  'Section 10 - Errors and Exceptions Handling.ipynb',
#  'Section 10- UnitTesting',
#  'Section 11 - Milestone Project - 2 - Assignment.ipynb',
#  'Section 11 - Milestone Project - 2-Warmup-Project.ipynb',
#  'Section 12 - Python Decorators.ipynb',
#  'Section 14 - Advanced Python Modules - Collections.ipynb',
#  'Section 14 - Advanced Python Modules_2.ipynb',
#  'Section 7 - Milestone Project - 1.ipynb',
#  'Section 8 - Object Oriented Programming - Homework.ipynb',
#  'Section 8 - Object Oriented Programming Challenge.ipynb',
#  'Section 8 - Object Oriented Programming.ipynb',
#  'Section 9 - Modules and Packages.ipynb',
#  'section10ErrorsAndExceptions',
#  'section3-object_data_structure_basics.ipynb',
#  'section9ModulesandPackages',
#  'test_files2',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'write.txt']

# %% [markdown]
# ### Deleting Files
# ____
# **NOTE: The os module provides 3 methods for deleting files:**
# * os.unlink(path) which deletes a file at the path your provide
# * os.rmdir(path) which deletes a folder (folder must be empty) at the path your provide
# * shutil.rmtree(path) this is the most dangerous, as it will remove all files and folders contained in the path.
# **All of these methods can not be reversed! Which means if you make a mistake you won't be able to recover the file. Instead we will use the send2trash module. A safer alternative that sends deleted files to the trash bin instead of permanent removal.**
# ___
#
# Install the send2trash module with:
#
#     pip install send2trash
#
# at your command line.

# %%
import send2trash

# %%
os.listdir()
# Out:
# [' Section 13 - Iterators and Generators Homework.ipynb',
#  ' Section 13 - Python Generators.ipynb',
#  '.DS_Store',
#  '.ipynb_checkpoints',
#  '04-Comparison operators worksheet.ipynb',
#  '05-Python statements worksheet.ipynb',
#  '06-Function Practice Exercises.ipynb',
#  '06-Methods and Functions.ipynb',
#  '08-Functions and Methods Homework.ipynb',
#  '09-Objects and Data Structures Assessment Test.ipynb',
#  'course_source_code',
#  'course_source_code.zip',
#  'file_for_io.txt',
#  'myfile.txt',
#  'new_append.txt',
#  'new_overwrite.txt',
#  'open and read files and folders exercise.txt',
#  'README.md',
#  'Section 10 - Errors and Exceptions Handling Homework.ipynb',
#  'Section 10 - Errors and Exceptions Handling.ipynb',
#  'Section 10- UnitTesting',
#  'Section 11 - Milestone Project - 2 - Assignment.ipynb',
#  'Section 11 - Milestone Project - 2-Warmup-Project.ipynb',
#  'Section 12 - Python Decorators.ipynb',
#  'Section 14 - Advanced Python Modules - Collections.ipynb',
#  'Section 14 - Advanced Python Modules_2.ipynb',
#  'Section 7 - Milestone Project - 1.ipynb',
#  'Section 8 - Object Oriented Programming - Homework.ipynb',
#  'Section 8 - Object Oriented Programming Challenge.ipynb',
#  'Section 8 - Object Oriented Programming.ipynb',
#  'Section 9 - Modules and Packages.ipynb',
#  'section10ErrorsAndExceptions',
#  'section3-object_data_structure_basics.ipynb',
#  'section9ModulesandPackages',
#  'test_files2',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'write.txt']

# %%
send2trash.send2trash('open and read files and folders exercise.txt')

# %%
os.listdir()
# Out:
# [' Section 13 - Iterators and Generators Homework.ipynb',
#  ' Section 13 - Python Generators.ipynb',
#  '.DS_Store',
#  '.ipynb_checkpoints',
#  '04-Comparison operators worksheet.ipynb',
#  '05-Python statements worksheet.ipynb',
#  '06-Function Practice Exercises.ipynb',
#  '06-Methods and Functions.ipynb',
#  '08-Functions and Methods Homework.ipynb',
#  '09-Objects and Data Structures Assessment Test.ipynb',
#  'course_source_code',
#  'course_source_code.zip',
#  'file_for_io.txt',
#  'myfile.txt',
#  'new_append.txt',
#  'new_overwrite.txt',
#  'README.md',
#  'Section 10 - Errors and Exceptions Handling Homework.ipynb',
#  'Section 10 - Errors and Exceptions Handling.ipynb',
#  'Section 10- UnitTesting',
#  'Section 11 - Milestone Project - 2 - Assignment.ipynb',
#  'Section 11 - Milestone Project - 2-Warmup-Project.ipynb',
#  'Section 12 - Python Decorators.ipynb',
#  'Section 14 - Advanced Python Modules - Collections.ipynb',
#  'Section 14 - Advanced Python Modules - Opening and Reading Files And Folders.ipynb',
#  'Section 7 - Milestone Project - 1.ipynb',
#  'Section 8 - Object Oriented Programming - Homework.ipynb',
#  'Section 8 - Object Oriented Programming Challenge.ipynb',
#  'Section 8 - Object Oriented Programming.ipynb',
#  'Section 9 - Modules and Packages.ipynb',
#  'section10ErrorsAndExceptions',
#  'section3-object_data_structure_basics.ipynb',
#  'section9ModulesandPackages',
#  'test_files2',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'write.txt']

# %% [markdown]
# ### Walking through a directory
#
# Often you will just need to "walk" through a directory, that is visit every file or folder and check to see if a file is in the directory, and then perhaps do something with that file. Usually recursively walking through every file and folder in a directory would be quite tricky to program, but luckily the os module has a direct method call for this called os.walk(). Let's explore how it works.

# %%
os.getcwd()
# Out:
# '/Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets'

# %%
os.listdir()
# Out:
# [' Section 13 - Iterators and Generators Homework.ipynb',
#  ' Section 13 - Python Generators.ipynb',
#  '.DS_Store',
#  '.ipynb_checkpoints',
#  '04-Comparison operators worksheet.ipynb',
#  '05-Python statements worksheet.ipynb',
#  '06-Function Practice Exercises.ipynb',
#  '06-Methods and Functions.ipynb',
#  '08-Functions and Methods Homework.ipynb',
#  '09-Objects and Data Structures Assessment Test.ipynb',
#  'course_source_code',
#  'course_source_code.zip',
#  'file_for_io.txt',
#  'myfile.txt',
#  'new_append.txt',
#  'new_overwrite.txt',
#  'README.md',
#  'Section 10 - Errors and Exceptions Handling Homework.ipynb',
#  'Section 10 - Errors and Exceptions Handling.ipynb',
#  'Section 10- UnitTesting',
#  'Section 11 - Milestone Project - 2 - Assignment.ipynb',
#  'Section 11 - Milestone Project - 2-Warmup-Project.ipynb',
#  'Section 12 - Python Decorators.ipynb',
#  'Section 14 - Advanced Python Modules - Collections.ipynb',
#  'Section 14 - Advanced Python Modules - Opening and Reading Files And Folders.ipynb',
#  'Section 7 - Milestone Project - 1.ipynb',
#  'Section 8 - Object Oriented Programming - Homework.ipynb',
#  'Section 8 - Object Oriented Programming Challenge.ipynb',
#  'Section 8 - Object Oriented Programming.ipynb',
#  'Section 9 - Modules and Packages.ipynb',
#  'section10ErrorsAndExceptions',
#  'section3-object_data_structure_basics.ipynb',
#  'section9ModulesandPackages',
#  'test_files2',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'write.txt']

# %%
for folder, sub_folder, files in os.walk(os.getcwd()):
    print (f'currently in {folder}')
    print('\n')
    for sub in sub_folder:
        print(f'subfolder: {sub_folder}')
        
    print('\n')
    print('files are:')
    for f in files:
        print(f'\t{f}')
    print('\n')
# Out:
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets
#
#
# subfolder: ['.ipynb_checkpoints', 'course_source_code', 'Section 10- UnitTesting', 'section10ErrorsAndExceptions', 'section9ModulesandPackages', 'test_files2']
# subfolder: ['.ipynb_checkpoints', 'course_source_code', 'Section 10- UnitTesting', 'section10ErrorsAndExceptions', 'section9ModulesandPackages', 'test_files2']
# subfolder: ['.ipynb_checkpoints', 'course_source_code', 'Section 10- UnitTesting', 'section10ErrorsAndExceptions', 'section9ModulesandPackages', 'test_files2']
# subfolder: ['.ipynb_checkpoints', 'course_source_code', 'Section 10- UnitTesting', 'section10ErrorsAndExceptions', 'section9ModulesandPackages', 'test_files2']
# subfolder: ['.ipynb_checkpoints', 'course_source_code', 'Section 10- UnitTesting', 'section10ErrorsAndExceptions', 'section9ModulesandPackages', 'test_files2']
# subfolder: ['.ipynb_checkpoints', 'course_source_code', 'Section 10- UnitTesting', 'section10ErrorsAndExceptions', 'section9ModulesandPackages', 'test_files2']
#
#
# files are:
# 	 Section 13 - Iterators and Generators Homework.ipynb
# 	 Section 13 - Python Generators.ipynb
# 	.DS_Store
# 	04-Comparison operators worksheet.ipynb
# 	05-Python statements worksheet.ipynb
# 	06-Function Practice Exercises.ipynb
# 	06-Methods and Functions.ipynb
# 	08-Functions and Methods Homework.ipynb
# 	09-Objects and Data Structures Assessment Test.ipynb
# 	course_source_code.zip
# 	file_for_io.txt
# 	myfile.txt
# 	new_append.txt
# 	new_overwrite.txt
# 	README.md
# 	Section 10 - Errors and Exceptions Handling Homework.ipynb
# 	Section 10 - Errors and Exceptions Handling.ipynb
# 	Section 11 - Milestone Project - 2 - Assignment.ipynb
# 	Section 11 - Milestone Project - 2-Warmup-Project.ipynb
# 	Section 12 - Python Decorators.ipynb
# 	Section 14 - Advanced Python Modules - Collections.ipynb
# 	Section 14 - Advanced Python Modules - Opening and Reading Files And Folders.ipynb
# 	Section 7 - Milestone Project - 1.ipynb
# 	Section 8 - Object Oriented Programming - Homework.ipynb
# 	Section 8 - Object Oriented Programming Challenge.ipynb
# 	Section 8 - Object Oriented Programming.ipynb
# 	Section 9 - Modules and Packages.ipynb
# 	section3-object_data_structure_basics.ipynb
# 	Untitled.ipynb
# 	Untitled1.ipynb
# 	Untitled2.ipynb
# 	Untitled3.ipynb
# 	Untitled4.ipynb
# 	write.txt
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/.ipynb_checkpoints
#
#
#
#
# files are:
# 	 Section 13 - Iterators and Generators Homework-checkpoint.ipynb
# 	 Section 13 - Python Generators-checkpoint.ipynb
# 	04-Comparison operators worksheet-checkpoint.ipynb
# 	05-Python statements worksheet-checkpoint.ipynb
# 	06-Function Practice Exercises-checkpoint.ipynb
# 	06-Methods and Functions-checkpoint.ipynb
# 	08-Functions and Methods Homework-checkpoint.ipynb
# 	09-Objects and Data Structures Assessment Test-checkpoint.ipynb
# 	Section 10 - Errors and Exceptions Handling Homework-checkpoint.ipynb
# 	Section 10 - Errors and Exceptions Handling-checkpoint.ipynb
# 	Section 11 - Milestone Project - 2 - Assignment-checkpoint.ipynb
# 	Section 11 - Milestone Project - 2-Warmup-Project-checkpoint.ipynb
# 	Section 12 - Python Decorators-checkpoint.ipynb
# 	Section 14 - Advanced Python Modules - Collections-checkpoint.ipynb
# 	Section 14 - Advanced Python Modules - Opening and Reading Files And Folders-checkpoint.ipynb
# 	Section 7 - Milestone Project - 1-checkpoint.ipynb
# 	Section 8 - Object Oriented Programming - Homework-checkpoint.ipynb
# 	Section 8 - Object Oriented Programming Challenge-checkpoint.ipynb
# 	Section 8 - Object Oriented Programming-checkpoint.ipynb
# 	Section 9 - Modules and Packages-checkpoint.ipynb
# 	section3-object_data_structure_basics-checkpoint.ipynb
# 	Untitled-checkpoint.ipynb
# 	Untitled1-checkpoint.ipynb
# 	Untitled2-checkpoint.ipynb
# 	Untitled3-checkpoint.ipynb
# 	Untitled4-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code
#
#
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
# subfolder: ['.ipynb_checkpoints', '00-Python Object and Data Structure Basics', '01-Python Comparison Operators', '02-Python Statements', '03-Methods and Functions', '04-Milestone Project - 1', '05-Object Oriented Programming', '06-Modules and Packages', '07-Errors and Exception Handling', '08-Milestone Project - 2', '09-Built-in Functions', '10-Python Decorators', '11-Python Generators', '12-Advanced Python Modules', '13-Web-Scraping', '14-Working-with-Images', '15-PDFs-and-Spreadsheets', '16-Emailing-with-Python', '17-Advanced Python Objects and Data Structures', '18-Milestone Project - 3', '19-Bonus Material - Introduction to GUIs']
#
#
# files are:
# 	.DS_Store
# 	Jupyter (iPython) Notebooks Guide.ipynb
# 	Pierian_Data_Logo.png
# 	README.md
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/.ipynb_checkpoints
#
#
#
#
# files are:
# 	Untitled-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/00-Python Object and Data Structure Basics
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	01-Numbers.ipynb
# 	01-Variable Assignment.ipynb
# 	02-Strings.ipynb
# 	03-Print Formatting with Strings.ipynb
# 	04-Lists.ipynb
# 	05-Dictionaries.ipynb
# 	06-Tuples.ipynb
# 	07-Sets and Booleans.ipynb
# 	08-Files.ipynb
# 	09-Objects and Data Structures Assessment Test.ipynb
# 	10-Objects and Data Structures Assessment Test-Solution.ipynb
# 	test.txt
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/00-Python Object and Data Structure Basics/.ipynb_checkpoints
#
#
#
#
# files are:
# 	01-Numbers-checkpoint.ipynb
# 	01-Variable Assignment-checkpoint.ipynb
# 	02-Strings-checkpoint.ipynb
# 	03-Print Formatting with Strings-checkpoint.ipynb
# 	04-Lists-checkpoint.ipynb
# 	05-Dictionaries-checkpoint.ipynb
# 	06-Tuples-checkpoint.ipynb
# 	07-Sets and Booleans-checkpoint.ipynb
# 	08-Files-checkpoint.ipynb
# 	09-Objects and Data Structures Assessment Test-checkpoint.ipynb
# 	10-Objects and Data Structures Assessment Test-Solution-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/01-Python Comparison Operators
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	01-Comparison Operators.ipynb
# 	02-Chained Comparison Operators.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/01-Python Comparison Operators/.ipynb_checkpoints
#
#
#
#
# files are:
# 	01-Comparison Operators-checkpoint.ipynb
# 	02-Chained Comparison Operators-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/02-Python Statements
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	01-Introduction to Python Statements.ipynb
# 	02-if, elif, and else Statements.ipynb
# 	03-for Loops.ipynb
# 	04-while Loops.ipynb
# 	05-Useful-Operators.ipynb
# 	06-List Comprehensions.ipynb
# 	07-Statements Assessment Test.ipynb
# 	08-Statements Assessment Test - Solutions.ipynb
# 	09-Guessing Game Challenge.ipynb
# 	10-Guessing Game Challenge - Solution.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/02-Python Statements/.ipynb_checkpoints
#
#
#
#
# files are:
# 	01-Introduction to Python Statements-checkpoint.ipynb
# 	02-if, elif, and else Statements-checkpoint.ipynb
# 	03-for Loops-checkpoint.ipynb
# 	04-while Loops-checkpoint.ipynb
# 	05-range()-checkpoint.ipynb
# 	05-Useful-Operators-checkpoint.ipynb
# 	06-List Comprehensions-checkpoint.ipynb
# 	07-Statements Assessment Test-checkpoint.ipynb
# 	08-Statements Assessment Test - Solutions-checkpoint.ipynb
# 	09-Guessing Game Challenge-checkpoint.ipynb
# 	10-Guessing Game Challenge - Solution-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/03-Methods and Functions
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	01-Methods.ipynb
# 	02-Functions.ipynb
# 	03-Function Practice Exercises.ipynb
# 	04-Function Practice Exercises - Solutions.ipynb
# 	05-Lambda-Expressions-Map-and-Filter.ipynb
# 	06-Nested Statements and Scope.ipynb
# 	07-args and kwargs.ipynb
# 	08-Functions and Methods Homework.ipynb
# 	09-Functions and Methods Homework - Solutions.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/03-Methods and Functions/.ipynb_checkpoints
#
#
#
#
# files are:
# 	01-Methods-checkpoint.ipynb
# 	02-Functions-checkpoint.ipynb
# 	03-Function Practice Exercises-checkpoint.ipynb
# 	03-Lambda expressions-checkpoint.ipynb
# 	04-Function Practice Exercises - Solutions-checkpoint.ipynb
# 	04-Nested Statements and Scope-checkpoint.ipynb
# 	05-Functions and Methods Homework-checkpoint.ipynb
# 	05-Lambda-Expressions-Map-and-Filter-checkpoint.ipynb
# 	06-Functions and Methods Homework - Solutions-checkpoint.ipynb
# 	06-Nested Statements and Scope-checkpoint.ipynb
# 	07-args and kwargs-checkpoint.ipynb
# 	08-Function Practice Exercises-checkpoint.ipynb
# 	08-Functions and Methods Homework-checkpoint.ipynb
# 	09-Function Practice Exercises - Solutions-checkpoint.ipynb
# 	09-Functions and Methods Homework - Solutions-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/04-Milestone Project - 1
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	00-Warm-Up-Project-Exercises.ipynb
# 	01-Milestone Project 1 - Assignment.ipynb
# 	02-Milestone Project 1 - Walkthrough Steps Workbook.ipynb
# 	03-Milestone Project 1 - Complete Walkthrough Solution.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/04-Milestone Project - 1/.ipynb_checkpoints
#
#
#
#
# files are:
# 	00-Warm-Up-Project-Exercises-checkpoint.ipynb
# 	01-Milestone Project 1 - Assignment-checkpoint.ipynb
# 	02-Milestone Project 1 - Walkthrough Steps Workbook-checkpoint.ipynb
# 	03-Milestone Project 1 - Complete Walkthrough Solution-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/05-Object Oriented Programming
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	01-Object Oriented Programming.ipynb
# 	02-Object Oriented Programming Homework.ipynb
# 	03-Object Oriented Programming Homework - Solution.ipynb
# 	04-OOP Challenge.ipynb
# 	05-OOP Challenge - Solution.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/05-Object Oriented Programming/.ipynb_checkpoints
#
#
#
#
# files are:
# 	01-Object Oriented Programming-checkpoint.ipynb
# 	01-Object Oriented Programming-Copy1-checkpoint.ipynb
# 	02-Object Oriented Programming Homework-checkpoint.ipynb
# 	03-Object Oriented Programming Homework - Solution-checkpoint.ipynb
# 	04-OOP Challenge-checkpoint.ipynb
# 	05-OOP Challenge - Solution-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/06-Modules and Packages
#
#
# subfolder: ['.ipynb_checkpoints', '00-Modules_and_Packages', '01-Name_and_Main']
# subfolder: ['.ipynb_checkpoints', '00-Modules_and_Packages', '01-Name_and_Main']
# subfolder: ['.ipynb_checkpoints', '00-Modules_and_Packages', '01-Name_and_Main']
#
#
# files are:
# 	Useful_Info_Notebook.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/06-Modules and Packages/.ipynb_checkpoints
#
#
#
#
# files are:
# 	01-Modules and Packages-checkpoint.ipynb
# 	Useful_Info_Notebook-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/06-Modules and Packages/00-Modules_and_Packages
#
#
# subfolder: ['MyMainPackage']
#
#
# files are:
# 	mymodule.py
# 	myprogram.py
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/06-Modules and Packages/00-Modules_and_Packages/MyMainPackage
#
#
# subfolder: ['__pycache__', 'SubPackage']
# subfolder: ['__pycache__', 'SubPackage']
#
#
# files are:
# 	__init__.py
# 	some_main_script.py
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/06-Modules and Packages/00-Modules_and_Packages/MyMainPackage/__pycache__
#
#
#
#
# files are:
# 	__init__.cpython-36.pyc
# 	some_main_script.cpython-36.pyc
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/06-Modules and Packages/00-Modules_and_Packages/MyMainPackage/SubPackage
#
#
# subfolder: ['__pycache__']
#
#
# files are:
# 	__init__.py
# 	mysubscript.py
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/06-Modules and Packages/00-Modules_and_Packages/MyMainPackage/SubPackage/__pycache__
#
#
#
#
# files are:
# 	__init__.cpython-36.pyc
# 	mysubscript.cpython-36.pyc
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/06-Modules and Packages/01-Name_and_Main
#
#
#
#
# files are:
# 	Explanation.txt
# 	one.py
# 	two.py
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/07-Errors and Exception Handling
#
#
# subfolder: ['.ipynb_checkpoints', '__pycache__']
# subfolder: ['.ipynb_checkpoints', '__pycache__']
#
#
# files are:
# 	01-Errors and Exceptions Handling.ipynb
# 	02-Errors and Exceptions Homework.ipynb
# 	03-Errors and Exceptions Homework - Solution.ipynb
# 	04-Unit Testing.ipynb
# 	cap.py
# 	simple1.py
# 	simple2.py
# 	test_cap.py
# 	testfile
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/07-Errors and Exception Handling/.ipynb_checkpoints
#
#
#
#
# files are:
# 	01-Errors and Exceptions Handling-checkpoint.ipynb
# 	02-Errors and Exceptions Homework-checkpoint.ipynb
# 	03-Errors and Exceptions Homework - Solution-checkpoint.ipynb
# 	04-Unit Testing-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/07-Errors and Exception Handling/__pycache__
#
#
#
#
# files are:
# 	cap.cpython-36.pyc
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/08-Milestone Project - 2
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	00-Milestone-2-Warmup-Project.ipynb
# 	01-Milestone Project 2 - Assignment.ipynb
# 	02-Milestone Project 2 - Walkthrough Steps Workbook.ipynb
# 	03-Milestone Project 2 - Complete Walkthrough Solution.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/08-Milestone Project - 2/.ipynb_checkpoints
#
#
#
#
# files are:
# 	00-Milestone-2-Warmup-Project-checkpoint.ipynb
# 	01-Milestone Project 2 - Assignment-checkpoint.ipynb
# 	02-Milestone Project 2 - Walkthrough Steps Workbook-checkpoint.ipynb
# 	03-Milestone Project 2 - Complete Walkthrough Solution-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/09-Built-in Functions
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	01-Map.ipynb
# 	02-Reduce.ipynb
# 	03-Filter.ipynb
# 	04-Zip.ipynb
# 	05-Enumerate.ipynb
# 	06-all() and any().ipynb
# 	07-Complex.ipynb
# 	08-Built-in Functions Assessment Test.ipynb
# 	09-Built-in Functions Assessment Test - Solution.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/09-Built-in Functions/.ipynb_checkpoints
#
#
#
#
# files are:
# 	01-Map-checkpoint.ipynb
# 	02-Reduce-checkpoint.ipynb
# 	03-Filter-checkpoint.ipynb
# 	04-Zip-checkpoint.ipynb
# 	05-Enumerate-checkpoint.ipynb
# 	06-all() and any()-checkpoint.ipynb
# 	07-Complex-checkpoint.ipynb
# 	08-Built-in Functions Assessment Test-checkpoint.ipynb
# 	09-Built-in Functions Assessment Test - Solution-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/10-Python Decorators
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	01-Decorators.ipynb
# 	02-Decorators Homework.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/10-Python Decorators/.ipynb_checkpoints
#
#
#
#
# files are:
# 	01-Decorators-checkpoint.ipynb
# 	02-Decorators Homework-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/11-Python Generators
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	01-Iterators and Generators.ipynb
# 	02-Iterators and Generators Homework.ipynb
# 	03-Iterators and Generators Homework - Solution.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/11-Python Generators/.ipynb_checkpoints
#
#
#
#
# files are:
# 	01-Iterators and Generators-checkpoint.ipynb
# 	02-Iterators and Generators Homework-checkpoint.ipynb
# 	03-Iterators and Generators Homework - Solution-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules
#
#
# subfolder: ['.ipynb_checkpoints', '08-Advanced-Python-Module-Exercise', 'Example_Top_Level']
# subfolder: ['.ipynb_checkpoints', '08-Advanced-Python-Module-Exercise', 'Example_Top_Level']
# subfolder: ['.ipynb_checkpoints', '08-Advanced-Python-Module-Exercise', 'Example_Top_Level']
#
#
# files are:
# 	.DS_Store
# 	00-Collections-Module.ipynb
# 	01-Opening-and-Reading-Files-Folders.ipynb
# 	02-Datetime-Module.ipynb
# 	03-Math-and-Random-Module.ipynb
# 	04-Python Debugger (pdb).ipynb
# 	05-Overview-of-Regular-Expressions.ipynb
# 	06-Timing your code - timeit.ipynb
# 	07-Unzipping-and-Zipping-Files.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/.ipynb_checkpoints
#
#
#
#
# files are:
# 	00-Collections-Module-checkpoint.ipynb
# 	01-Datetime-Module-checkpoint.ipynb
# 	01-Opening-and-Reading-Files-Folders-checkpoint.ipynb
# 	02-Datetime-Module-checkpoint.ipynb
# 	02-Math-and-Random-Module-checkpoint.ipynb
# 	03-Math-and-Random-Module-checkpoint.ipynb
# 	03-Python Debugger (pdb)-checkpoint.ipynb
# 	04-Python Debugger (pdb)-checkpoint.ipynb
# 	04-Timing your code - timeit-checkpoint.ipynb
# 	05-Overview-of-Regular-Expressions-checkpoint.ipynb
# 	06-Timing your code - timeit-checkpoint.ipynb
# 	06-Unzipping-and-Zipping-Files-checkpoint.ipynb
# 	07-OS-Module-checkpoint.ipynb
# 	07-Unzipping-and-Zipping-Files-checkpoint.ipynb
# 	09-Advanced-Modules-Exercise-Solutions-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise
#
#
# subfolder: ['.ipynb_checkpoints', 'extracted_content']
# subfolder: ['.ipynb_checkpoints', 'extracted_content']
#
#
# files are:
# 	07-Advanced-Modules-Exercise-Puzzle.ipynb
# 	08-Advanced-Modules-Exercise-Solutions.ipynb
# 	unzip_me_for_instructions.zip
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/.ipynb_checkpoints
#
#
#
#
# files are:
# 	07-Advanced-Modules-Exercise-Puzzle-checkpoint.ipynb
# 	08-Advanced-Modules-Exercise-Solutions-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/extracted_content
#
#
# subfolder: ['Five', 'Four', 'One', 'Three', 'Two']
# subfolder: ['Five', 'Four', 'One', 'Three', 'Two']
# subfolder: ['Five', 'Four', 'One', 'Three', 'Two']
# subfolder: ['Five', 'Four', 'One', 'Three', 'Two']
# subfolder: ['Five', 'Four', 'One', 'Three', 'Two']
#
#
# files are:
# 	Instructions.txt
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/extracted_content/Five
#
#
#
#
# files are:
# 	AEITMYIRQLP.txt
# 	APJKSRITGGX.txt
# 	AQKATDFGXTS.txt
# 	ARLKFCWIAJE.txt
# 	AXJGVPVEFAS.txt
# 	BNUQEHCFRTG.txt
# 	BSKJDRNEZQM.txt
# 	BTYWAHLHKBM.txt
# 	BUGKBZWRRVI.txt
# 	BVBURZZCAPR.txt
# 	CAHBEVSVDDN.txt
# 	COMGMZBJAYE.txt
# 	CRFSDGYFSHA.txt
# 	CSCLFZCDYYC.txt
# 	CXBVCTRBBIE.txt
# 	DDLASODUVPX.txt
# 	DHZBAAYEADM.txt
# 	DQPZQLBCJYP.txt
# 	DYOPIIVMZOO.txt
# 	DZUWWXYIAEL.txt
# 	EAAOEPSAWMQ.txt
# 	EIPWXMQZJKU.txt
# 	ESIZWBHMGDP.txt
# 	ETCUEXWNBCF.txt
# 	EYTCGIOYWIW.txt
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/extracted_content/Four
#
#
#
#
# files are:
# 	ECIOBYCDVFI.txt
# 	EMTGPSXQEJX.txt
# 	EPRNUHRSESC.txt
# 	ESDIZXHYCVY.txt
# 	EXVQSVBQQQH.txt
# 	QCTCKDIBBVG.txt
# 	QCWCFLKNZMN.txt
# 	QDDETWBHJYC.txt
# 	QTDYYIFPHAU.txt
# 	QVNJULGXNUM.txt
# 	REAXWSOIQDY.txt
# 	ROICPTWKXDX.txt
# 	RSXOTNGKBML.txt
# 	RXDARIDGKBF.txt
# 	RYNXFYXMKHG.txt
# 	TAKNAVDMZKV.txt
# 	THPNEGKTJWI.txt
# 	TJFMLJODVAD.txt
# 	TKCZSFQNJTX.txt
# 	TWUOYFCCYBQ.txt
# 	WFSKPTXPFCH.txt
# 	WHTOHQUWXIN.txt
# 	WNJISWPEBRS.txt
# 	WXDJDOGZEHN.txt
# 	WYDLGSGGXKV.txt
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/extracted_content/One
#
#
#
#
# files are:
# 	HDOHZHFSTTK.txt
# 	HFUTPPAXDIS.txt
# 	HMNZTLIFGPD.txt
# 	HRQFTHKVJTL.txt
# 	HVUTZEVMSBW.txt
# 	JDLRVFCXYLU.txt
# 	JEHBLZPUPSP.txt
# 	JLTXKIGCWDL.txt
# 	JQUOBKFUACN.txt
# 	JTHSNBNPQSE.txt
# 	KCXGNQCZBLO.txt
# 	KFIUZFERLET.txt
# 	KMMLGJOWLGI.txt
# 	KNBSKDREHQU.txt
# 	KTXDHIOKAUI.txt
# 	LDGOCUQJNNS.txt
# 	LFEATJAAYDC.txt
# 	LHODFIKVTQA.txt
# 	LIFDHOFKWOI.txt
# 	LPNDVDXPZIG.txt
# 	PDJMSMNKIRM.txt
# 	PHWAVPEKAER.txt
# 	PLYCGPVEAWO.txt
# 	PQNVCVJINAR.txt
# 	PTOBBCJYURJ.txt
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/extracted_content/Three
#
#
#
#
# files are:
# 	VAQIJTDOFUJ.txt
# 	VCFJCGJFBIH.txt
# 	VSXFSTABZDY.txt
# 	VVHFVZUNLOO.txt
# 	VVKGWLRMHLU.txt
# 	XAJMCPEWFNI.txt
# 	XFHJOTNPEJG.txt
# 	XHZPVUQTXIO.txt
# 	XJCWENFFGHB.txt
# 	XVMPVSVYKFR.txt
# 	YCESZHJDBXH.txt
# 	YDQFMWXOUMW.txt
# 	YQBIUHSUEVW.txt
# 	YQRNCMNFFHW.txt
# 	YYIZGBTQHZP.txt
# 	ZEZKKRBIZEB.txt
# 	ZKQJXAYKPVD.txt
# 	ZOWVXWPOGWP.txt
# 	ZXEZRQXZNPG.txt
# 	ZXIBJMPROKW.txt
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/08-Advanced-Python-Module-Exercise/extracted_content/Two
#
#
#
#
# files are:
# 	GKQBQRCTNNK.txt
# 	GMMQQUBMJNR.txt
# 	GQTJJORZBXY.txt
# 	GTOTCIWMDBY.txt
# 	GXYSEPAFRTP.txt
# 	HARDNJGDRBC.txt
# 	HEORIXOTANT.txt
# 	HMUTDOVNYTV.txt
# 	HMZXPBOPRAE.txt
# 	HTOHSTYXTCO.txt
# 	LCJZYDHBFRM.txt
# 	LSQSTGPIGIY.txt
# 	LULTNYAQEJG.txt
# 	LVMBINRBJXL.txt
# 	LYZEQCVYNEZ.txt
# 	OHZOUOSFJQC.txt
# 	OIHMLGMWTHL.txt
# 	OKWFOOYTXFU.txt
# 	OMWIMVRCMYM.txt
# 	OYMAGXAGWHJ.txt
# 	SIKFPPLCJDN.txt
# 	SJMJLDGPBSJ.txt
# 	SOFUJYXTIMK.txt
# 	SPDZYGDHEWO.txt
# 	SWOFXREEHWA.txt
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/Example_Top_Level
#
#
# subfolder: ['Mid-Example-One']
#
#
# files are:
# 	Mid-Example.txt
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/Example_Top_Level/Mid-Example-One
#
#
# subfolder: ['Bottom-Level-One', 'Bottom-Level-Two']
# subfolder: ['Bottom-Level-One', 'Bottom-Level-Two']
#
#
# files are:
# 	Mid-Level-Doc.txt
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/Example_Top_Level/Mid-Example-One/Bottom-Level-One
#
#
#
#
# files are:
# 	One_Text.txt
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/Example_Top_Level/Mid-Example-One/Bottom-Level-Two
#
#
#
#
# files are:
# 	Bottom-Text-Two.txt
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/13-Web-Scraping
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	00-Guide-to-Web-Scraping.ipynb
# 	01-Web-Scraping-Exercises.ipynb
# 	02-Web-Scraping-Exercise-Solutions.ipynb
# 	my_new_file_name.jpg
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/13-Web-Scraping/.ipynb_checkpoints
#
#
#
#
# files are:
# 	00-Guide-to-Web-Scraping-checkpoint.ipynb
# 	01-Web-Scraping-Exercises-checkpoint.ipynb
# 	02-Web-Scraping-Exercise-Solutions-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/14-Working-with-Images
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	00-Overview-of-Working-with-Images.ipynb
# 	01-Image-Exercise.ipynb
# 	02-Image-Exercise-Solution.ipynb
# 	blue_color.png
# 	example.jpg
# 	mask.png
# 	pencils.jpg
# 	purple.png
# 	red_color.jpg
# 	word_matrix.png
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/14-Working-with-Images/.ipynb_checkpoints
#
#
#
#
# files are:
# 	00-Overview-of-Working-with-Images-checkpoint.ipynb
# 	01-Image-Exercise-checkpoint.ipynb
# 	02-Image-Exercise-Solution-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/15-PDFs-and-Spreadsheets
#
#
# subfolder: ['.ipynb_checkpoints', 'Exercise_Files']
# subfolder: ['.ipynb_checkpoints', 'Exercise_Files']
#
#
# files are:
# 	00-Working-with-CSV-Files.ipynb
# 	01-Working-with-PDFs.ipynb
# 	02-PDFs-Spreadsheets-Puzzle.ipynb
# 	03-PDFs-Spreadsheets-Puzzle-Solution.ipynb
# 	example.csv
# 	makeup_new.csv
# 	Some_BrandNew_Doc.pdf
# 	Some_New_Doc.pdf
# 	Some_new_file.pdf
# 	to_save_file.csv
# 	Working_Business_Proposal.pdf
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/15-PDFs-and-Spreadsheets/.ipynb_checkpoints
#
#
#
#
# files are:
# 	00-Working-with-CSV-Files-checkpoint.ipynb
# 	01-Working-with-PDFs-checkpoint.ipynb
# 	02-PDFs-Spreadsheets-Puzzle-checkpoint.ipynb
# 	03-PDFs-Spreadsheets-Puzzle-Solution-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/15-PDFs-and-Spreadsheets/Exercise_Files
#
#
#
#
# files are:
# 	find_the_link.csv
# 	Find_the_Phone_Number.pdf
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/16-Emailing-with-Python
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	00-Overview-of-Sending-Emails.ipynb
# 	01-Overview-of-Received-Emails.ipynb
# 	02-Exercise-Ideas.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/16-Emailing-with-Python/.ipynb_checkpoints
#
#
#
#
# files are:
# 	00-Overview-of-Sending-Emails-checkpoint.ipynb
# 	01-Overview-of-Received-Emails-checkpoint.ipynb
# 	02-Exercise-Ideas-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/17-Advanced Python Objects and Data Structures
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	01-Advanced Numbers.ipynb
# 	02-Advanced Strings.ipynb
# 	03-Advanced Sets.ipynb
# 	04-Advanced Dictionaries.ipynb
# 	05-Advanced Lists.ipynb
# 	06-Advanced Python Objects Test.ipynb
# 	07-Advanced Python Objects Test - Solutions.ipynb
# 	08-BONUS - With Statement Context Managers.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/17-Advanced Python Objects and Data Structures/.ipynb_checkpoints
#
#
#
#
# files are:
# 	01-Advanced Numbers-checkpoint.ipynb
# 	02-Advanced Strings-checkpoint.ipynb
# 	03-Advanced Sets-checkpoint.ipynb
# 	04-Advanced Dictionaries-checkpoint.ipynb
# 	05-Advanced Lists-checkpoint.ipynb
# 	06-Advanced Python Objects Test-checkpoint.ipynb
# 	07-Advanced Python Objects Test - Solutions-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/18-Milestone Project - 3
#
#
# subfolder: ['.ipynb_checkpoints', 'Projects-Solutions']
# subfolder: ['.ipynb_checkpoints', 'Projects-Solutions']
#
#
# files are:
# 	01-Final Capstone Project.ipynb
# 	02-Final Capstone Project Ideas.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/18-Milestone Project - 3/.ipynb_checkpoints
#
#
#
#
# files are:
# 	01-Final Capstone Project-checkpoint.ipynb
# 	02-Final Capstone Project Ideas-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/18-Milestone Project - 3/Projects-Solutions
#
#
#
#
# files are:
# 	Solution Links.md
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/19-Bonus Material - Introduction to GUIs
#
#
# subfolder: ['.ipynb_checkpoints']
#
#
# files are:
# 	01-Interact.ipynb
# 	02-Widget Basics.ipynb
# 	03-Widget List.ipynb
# 	04-Widget Events.ipynb
# 	05-Widget Styling.ipynb
# 	06-Custom Widget.ipynb
# 	07-Advanced Widget List.ipynb
# 	08-Advanced Widget Styling with Layout.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/19-Bonus Material - Introduction to GUIs/.ipynb_checkpoints
#
#
#
#
# files are:
# 	01-Interact-checkpoint.ipynb
# 	02-Widget Basics-checkpoint.ipynb
# 	03-Widget List-checkpoint.ipynb
# 	04-Widget Events-checkpoint.ipynb
# 	05-Widget Styling-checkpoint.ipynb
# 	06-Custom Widget-checkpoint.ipynb
# 	07-Advanced Widget List-checkpoint.ipynb
# 	08-Advanced Widget Styling with Layout-checkpoint.ipynb
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/Section 10- UnitTesting
#
#
# subfolder: ['__pycache__']
#
#
# files are:
# 	cap.py
# 	test.cap.py
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/Section 10- UnitTesting/__pycache__
#
#
#
#
# files are:
# 	cap.cpython-36.pyc
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/section10ErrorsAndExceptions
#
#
#
#
# files are:
# 	__init__
# 	simple1.py
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/section9ModulesandPackages
#
#
# subfolder: ['__pycache__', 'utils']
# subfolder: ['__pycache__', 'utils']
#
#
# files are:
# 	__init__.py
# 	check_if_run_directly.py
# 	moduleToImport.py
# 	section9ModulesandPackages.py
# 	two.py
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/section9ModulesandPackages/__pycache__
#
#
#
#
# files are:
# 	check_if_run_directly.cpython-36.pyc
# 	moduleToImport.cpython-36.pyc
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/section9ModulesandPackages/utils
#
#
# subfolder: ['__pycache__', 'sub_package']
# subfolder: ['__pycache__', 'sub_package']
#
#
# files are:
# 	__init__.py
# 	util.py
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/section9ModulesandPackages/utils/__pycache__
#
#
#
#
# files are:
# 	__init__.cpython-36.pyc
# 	util.cpython-36.pyc
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/section9ModulesandPackages/utils/sub_package
#
#
# subfolder: ['__pycache__']
#
#
# files are:
# 	__init__.py
# 	sub_util.py
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/section9ModulesandPackages/utils/sub_package/__pycache__
#
#
#
#
# files are:
# 	__init__.cpython-36.pyc
# 	sub_util.cpython-36.pyc
#
#
# currently in /Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/test_files2
#
#
#
#
# files are:
# 	test_files

# %%
for folder , sub_folders , files in os.walk("Example_Top_Level"):
    
    print("Currently looking at folder: "+ folder)
    print('\n')
    print("THE SUBFOLDERS ARE: ")
    for sub_fold in sub_folders:
        print("\t Subfolder: "+sub_fold )
    
    print('\n')
    
    print("THE FILES ARE: ")
    for f in files:
        print("\t File: "+f)
    print('\n')
    
    # Now look at subfolders

# %% [markdown]
# ___
# Excellent, you should now be aware of how to work with a computer's files and folders in whichever directory they are in. Remember that the os module works for any oeprating system that supports Python, which means these commands will work across Linux,MacOs, or Windows without need for adjustment.

# %%
shutil.copyfile("/Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/course_source_code/12-Advanced Python Modules/02-Datetime-Module.ipynb","/Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/Section 14 - Advanced Python Modules - Datetime-Module.ipynb")
# Out:
# '/Users/simiyub/Development/code/python/learn/complete-python-bootcamp-worksheets/Section 14 - Advanced Python Modules - Datetime-Module.ipynb'
