# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Warmup Project Exercise

# %% [markdown]
# ## Simple War Game
#
# Before we launch in to the OOP Milestone 2 Project, let's walk through together on using OOP for a more robust and complex application, such as a game. We will use Python OOP to simulate a simplified version of the game war. Two players will each start off with half the deck, then they each remove a card, compare which card has the highest value, and the player with the higher card wins both cards. In the event of a time

# %% [markdown]
# ## Single Card Class
#
# ### Creating a Card Class with outside variables
#
# Here we will use some outside variables that we know don't change regardless of the situation, such as a deck of cards. Regardless of what round,match, or game we're playing, we'll still need the same deck of cards.

# %%
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

class Card():
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank
        self.value = values[self.rank]

    def __str__(self):
        return self.rank + " of "+self.suit

# %%
print(Card("Hearts", "Two"))
# Out:
# Two of Hearts

# %%
print(two_hearts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c2e5e6111ded> in <module>()
# ----> 1 print(two_hearts)
#
# NameError: name 'two_hearts' is not defined

# %%
suits
# Out:
# ('Hearts', 'Diamonds', 'Spades', 'Clubs')

# %%
ranks
# Out:
# ('Two',
#  'Three',
#  'Four',
#  'Five',
#  'Six',
#  'Seven',
#  'Eight',
#  'Nine',
#  'Ten',
#  'Jack',
#  'Queen',
#  'King',
#  'Ace')

# %%
two_hearts = Card(suits[0],ranks[0])

# %% [markdown]
# ## Deck Class
#
# ### Using a class within another class
#
# We just created a single card, but how can we create an entire Deck of cards? Let's explore doing this with a class that utilizes the Card class.

# %% [markdown]
# A Deck will be made up of multiple Cards. Which mean's we will actually use the Card class within the \_\_init__ of the Deck class.

# %%
import random
class Deck:

    def __init__(self):
        self.all_cards = [ Card(suit=suit, rank=rank) for rank in ranks for suit in suits]
                
    def shuffle(self):
        random.shuffle(self.all_cards)

    def has_cards(self):
        return len(self.all_cards) >0
    
    def card_count(self):
        return len(self.all_cards)  
    
    def deal_one(self):
        
        if self.has_cards():
            self.shuffle()
            return self.all_cards.pop()
        else:
            print("no more cards to deal")
    def __str__(self):
        return [card for card in self.all_cards]

# %% [markdown]
# ### Create a Deck

# %%
my_deck = Deck()

# %%
len(my_deck.all_cards)
# Out:
# 52

# %%
my_deck.all_cards[0]

# %%
print(my_deck.all_cards[0])
# Out:
# Two of Hearts

# %%
my_deck.shuffle()

# %%
print(my_deck.all_cards[0])
# Out:
# Jack of Hearts

# %%
my_card = my_deck.deal_one()

# %%
print(my_card)
# Out:
# Four of Hearts

# %%
len(my_deck.all_cards)
# Out:
# 51

# %% [markdown]
# # Player Class
#
# Let's create a Player Class, a player should be able to hold instances of Cards, they should also be able to remove and add them from their hand. We want the Player class to be flexible enough to add one card, or many cards so we'll use a simple if check to keep it all in the same method.

# %% [markdown]
# We'll keep this all in mind as we create the methods for the Player class.
#
# ### Player Class

# %%
class Player:
    import random 
    def __init__(self,name):
        self.name = name
        # A new player has no cards
        self.all_cards = [] 
        
    def remove_cards(self, cards=1):
        removed = []
        if self.card_count()>=cards:
            random.shuffle(self.all_cards)
            for count in range(cards):
                removed.append(self.all_cards.pop(0))
        #if self.has_cards():
        return removed

        #else:
         #   print(f"{self.name} has run out of cards")
    
    def add_cards(self,new_cards):
        self.all_cards.extend( new_cards if isinstance(new_cards, list) else [new_cards])
    
    def card_count(self):
        return len(self.all_cards)
    
    def has_cards(self):
        return len(self.all_cards) > 0   
    
    
    
    def __str__(self):
        
        cards = "card" if self.card_count() == 1 else "cards"
        
        return f"{self.name} has {len(self.all_cards)} {cards}"

# %%
jose = Player("Jose")

# %%
jose

# %%
print(jose)
# Out:
# Jose has 0 cards

# %%
two_hearts

# %%
jose.add_cards(two_hearts)

# %%
print(jose)
# Out:
# Jose has 1 card

# %%
jose.add_cards([two_hearts,two_hearts,two_hearts])

# %%
print(jose)
# Out:
# Jose has 4 cards

# %% [markdown]
# ## War Game Logic

# %%
#War game
class Game():
    def __init__(self,player1Name, player2Name):
        self.player1 = Player(player1Name)
        self.player2 = Player(player2Name)
        self.deck = Deck()
        self.deck.shuffle()
        
    def split_deck(self):
        print(f'{self.deck.card_count()} to be dealt')
        while self.deck.has_cards():
            self.player1.add_cards(self.deck.deal_one())
            self.player2.add_cards(self.deck.deal_one())
        print(f"cards: player 1 has cards: {self.player1.card_count()} and player 2 has cards: { self.player2.card_count()}")            
        return self.player1.card_count() == self.player2.card_count() == 26
        
    def winner(self):
        '''determine winning player'''
        win=None
        if not self.player2.has_cards():
            win = self.player1.name
        elif not self.player1.has_cards():
            win = self.player2.name
        return win
    
    def take_all(self):
        '''give the winner all cards and reset lists for new cards'''
        win = self.player1_play_cards+self.player2_play_cards
        self.player1_play_cards.clear()
        self.player2_play_cards.clear()
        print(f'Cards won {len(win)} :{win}')
        return win
        

    def play_round(self):
        '''play a round'''
        if not (self.players_have_cards):
            print(f'{self.player1} has no cards.')
            print(f'{self.player2} has no cards.')            
            return          
        
        self.tied = self.tie_count>0
        
        if not self.tied:
            self.player1_play_cards = self.player1.remove_cards()
            self.player2_play_cards = self.player2.remove_cards()

        
        self.player1_card = self.player1_play_cards[-1]
        self.player2_card = self.player2_play_cards[-1]
        print(f'cards drawn {self.player1.name}: {self.player1_card} & {self.player2.name}:{self.player2_card}')        
        
        if(self.player1_card.value>self.player2_card.value):
            print(f"{self.player1.name} won round {self.game_round}")            
            self.player1.add_cards(self.take_all())            
            self.game_round +=1
            self.tie_count = 0
            return self.player1

        elif(self.player2_card.value>self.player1_card.value):
            print(f"{self.player2.name} won round {self.game_round}")                
            self.player2.add_cards(self.take_all())
            self.game_round +=1
            self.tie_count = 0
            return self.player2
            
        else:
            self.tie_count += 1            
            self.game_round +=1
            self.cards_to_draw=4
            print(f"round {self.game_round}, tie {self.tie_count} :{self.player1_card}, {self.player2_card}")
            self.player_2_can_fight=self.player2.card_count() >= self.cards_to_draw
            self.player_1_can_fight=self.player1.card_count() >= self.cards_to_draw
            self.can_fight =  self.player_1_can_fight and self.player_2_can_fight
            
            if self.can_fight:                
                self.player1_cards = self.player1.remove_cards(self.cards_to_draw)
                self.player2_cards = self.player2.remove_cards(self.cards_to_draw)
                self.player1_play_cards.extend(self.player1_cards)
                self.player2_play_cards.extend(self.player2_cards)                

                print(f'cards drawn {self.player1.name}: {self.player1_cards} & {self.player2.name}:{self.player2_cards}')
                
                self.play_round()
            else:
                if not self.player_1_can_fight:
                    self.player2.add_cards(self.player1_play_cards+self.player2_play_cards)
                    loser = self.player1
                else:
                    self.player1.add_cards(self.player1_play_cards+self.player2_play_cards)
                    loser = self.player2
                
                print(f"{loser} can't fight.")
        
            
    def play(self):
        #while len(self.deck.all_cards)>0:
         #   if(self.winner(self.player1,self.player2)==None):
          #      self.play_round()
        #len(self.player1.all_cards) > 0      
        self.players_have_cards = self.split_deck()
        self.no_winner = (self.winner()==None)
        self.game_round = 0
        print(self.players_have_cards)
        
        while (self.players_have_cards and self.no_winner):
            print(f"Level 1 cards @ round {self.game_round}: player 1 has cards: {self.player1.card_count()} and player 2 has cards: { self.player2.card_count()}")            
            self.player1_play_cards = []
            self.player2_play_cards = []
            self.tie_count = 0              
            self.play_round()
            
            self.no_winner = (self.winner()==None)               
            self.players_have_cards = self.player2.has_cards() and self.player1.has_cards()
                #players_have_cards = (self.player2.has_cards() and self.player1.has_cards())
                #no_winner = (self.winner()==None)               
        if not self.player1.has_cards():
            print(f" winner was {self.player2}")
        elif not self.player2.has_cards():
            print(f" winner was {self.player1}")
        else:
            print(f"game ended with {self.player1.name} with {self.player1.card_count()} cards and {self.player2.name} with {self.player2.card_count()} cards")
            print(f"{self.deck}")
            
    
    def __str__(self):
        details = f"{self.deck.card_count()} cards left.\nPlayer 1 has {self.player1.card_count()}\nPlayer 2 has {self.player2.card_count()}"
        return details

# %%
game = Game("bramwell", "simiyu")

# %%
print(game)
# Out:
# 52 cards left.
# Player 1 has 0
# Player 2 has 0

# %%
game.play()
# Out:
# 52 to be dealt
# cards: player 1 has cards: 26 and player 2 has cards: 26
# True
# Level 1 cards @ round 0: player 1 has cards: 26 and player 2 has cards: 26
# cards drawn bramwell: Two of Spades & simiyu:Ace of Hearts
# simiyu won round 0
# Cards won 2 :[<__main__.Card object at 0x10bec8ef0>, <__main__.Card object at 0x10bf01e10>]
# Level 1 cards @ round 1: player 1 has cards: 25 and player 2 has cards: 27
# cards drawn bramwell: Eight of Hearts & simiyu:Six of Spades
# bramwell won round 1
# Cards won 2 :[<__main__.Card object at 0x10bed3358>, <__main__.Card object at 0x10bed3438>]
# Level 1 cards @ round 2: player 1 has cards: 26 and player 2 has cards: 26
# cards drawn bramwell: Three of Spades & simiyu:Two of Diamonds
# bramwell won round 2
# Cards won 2 :[<__main__.Card object at 0x10bec8f98>, <__main__.Card object at 0x10bec8a20>]
# Level 1 cards @ round 3: player 1 has cards: 27 and player 2 has cards: 25
# cards drawn bramwell: Eight of Hearts & simiyu:Five of Diamonds
# bramwell won round 3
# Cards won 2 :[<__main__.Card object at 0x10bed3358>, <__main__.Card object at 0x10bed3208>]
# Level 1 cards @ round 4: player 1 has cards: 28 and player 2 has cards: 24
# cards drawn bramwell: Two of Hearts & simiyu:Nine of Diamonds
# simiyu won round 4
# Cards won 2 :[<__main__.Card object at 0x10bec8da0>, <__main__.Card object at 0x10bed3128>]
# Level 1 cards @ round 5: player 1 has cards: 27 and player 2 has cards: 25
# cards drawn bramwell: Ten of Hearts & simiyu:King of Diamonds
# simiyu won round 5
# Cards won 2 :[<__main__.Card object at 0x10bf010b8>, <__main__.Card object at 0x10bf01588>]
# Level 1 cards @ round 6: player 1 has cards: 26 and player 2 has cards: 26
# cards drawn bramwell: Three of Clubs & simiyu:Three of Diamonds
# round 7, tie 1 :Three of Clubs, Three of Diamonds
# cards drawn bramwell: [<__main__.Card object at 0x10bec8e10>, <__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bed3320>, <__main__.Card object at 0x10bf015f8>] & simiyu:[<__main__.Card object at 0x10bec8748>, <__main__.Card object at 0x10bed36a0>, <__main__.Card object at 0x10bed3160>, <__main__.Card object at 0x10bed3470>]
# cards drawn bramwell: Jack of Diamonds & simiyu:Seven of Clubs
# bramwell won round 7
# Cards won 10 :[<__main__.Card object at 0x10bec8c18>, <__main__.Card object at 0x10bec8e10>, <__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bed3320>, <__main__.Card object at 0x10bf015f8>, <__main__.Card object at 0x10bec8630>, <__main__.Card object at 0x10bec8748>, <__main__.Card object at 0x10bed36a0>, <__main__.Card object at 0x10bed3160>, <__main__.Card object at 0x10bed3470>]
# Level 1 cards @ round 8: player 1 has cards: 31 and player 2 has cards: 21
# cards drawn bramwell: Jack of Clubs & simiyu:Ace of Clubs
# simiyu won round 8
# Cards won 2 :[<__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 9: player 1 has cards: 30 and player 2 has cards: 22
# cards drawn bramwell: Two of Clubs & simiyu:Ten of Hearts
# simiyu won round 9
# Cards won 2 :[<__main__.Card object at 0x10bec8e10>, <__main__.Card object at 0x10bf010b8>]
# Level 1 cards @ round 10: player 1 has cards: 29 and player 2 has cards: 23
# cards drawn bramwell: Queen of Hearts & simiyu:Eight of Clubs
# bramwell won round 10
# Cards won 2 :[<__main__.Card object at 0x10bf01780>, <__main__.Card object at 0x10bed3630>]
# Level 1 cards @ round 11: player 1 has cards: 30 and player 2 has cards: 22
# cards drawn bramwell: Three of Hearts & simiyu:Seven of Spades
# simiyu won round 11
# Cards won 2 :[<__main__.Card object at 0x10bec8748>, <__main__.Card object at 0x10bed31d0>]
# Level 1 cards @ round 12: player 1 has cards: 29 and player 2 has cards: 23
# cards drawn bramwell: Three of Spades & simiyu:Ace of Hearts
# simiyu won round 12
# Cards won 2 :[<__main__.Card object at 0x10bec8f98>, <__main__.Card object at 0x10bf01e10>]
# Level 1 cards @ round 13: player 1 has cards: 28 and player 2 has cards: 24
# cards drawn bramwell: Six of Spades & simiyu:Jack of Clubs
# simiyu won round 13
# Cards won 2 :[<__main__.Card object at 0x10bed3438>, <__main__.Card object at 0x10bf01ef0>]
# Level 1 cards @ round 14: player 1 has cards: 27 and player 2 has cards: 25
# cards drawn bramwell: Five of Diamonds & simiyu:Two of Hearts
# bramwell won round 14
# Cards won 2 :[<__main__.Card object at 0x10bed3208>, <__main__.Card object at 0x10bec8da0>]
# Level 1 cards @ round 15: player 1 has cards: 28 and player 2 has cards: 24
# cards drawn bramwell: Ace of Diamonds & simiyu:Eight of Diamonds
# bramwell won round 15
# Cards won 2 :[<__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bed30f0>]
# Level 1 cards @ round 16: player 1 has cards: 29 and player 2 has cards: 23
# cards drawn bramwell: Seven of Clubs & simiyu:Ace of Clubs
# simiyu won round 16
# Cards won 2 :[<__main__.Card object at 0x10bed3470>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 17: player 1 has cards: 28 and player 2 has cards: 24
# cards drawn bramwell: Nine of Hearts & simiyu:Ace of Hearts
# simiyu won round 17
# Cards won 2 :[<__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bf01e10>]
# Level 1 cards @ round 18: player 1 has cards: 27 and player 2 has cards: 25
# cards drawn bramwell: Nine of Clubs & simiyu:King of Spades
# simiyu won round 18
# Cards won 2 :[<__main__.Card object at 0x10bf01438>, <__main__.Card object at 0x10bf017b8>]
# Level 1 cards @ round 19: player 1 has cards: 26 and player 2 has cards: 26
# cards drawn bramwell: King of Clubs & simiyu:Seven of Hearts
# bramwell won round 19
# Cards won 2 :[<__main__.Card object at 0x10bf011d0>, <__main__.Card object at 0x10bed35c0>]
# Level 1 cards @ round 20: player 1 has cards: 27 and player 2 has cards: 25
# cards drawn bramwell: Jack of Spades & simiyu:Two of Spades
# bramwell won round 20
# Cards won 2 :[<__main__.Card object at 0x10bf01cc0>, <__main__.Card object at 0x10bec8ef0>]
# Level 1 cards @ round 21: player 1 has cards: 28 and player 2 has cards: 24
# cards drawn bramwell: Eight of Clubs & simiyu:Five of Clubs
# bramwell won round 21
# Cards won 2 :[<__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bed32b0>]
# Level 1 cards @ round 22: player 1 has cards: 29 and player 2 has cards: 23
# cards drawn bramwell: Queen of Spades & simiyu:Ten of Clubs
# bramwell won round 22
# Cards won 2 :[<__main__.Card object at 0x10bf01c50>, <__main__.Card object at 0x10bf01320>]
# Level 1 cards @ round 23: player 1 has cards: 30 and player 2 has cards: 22
# cards drawn bramwell: Two of Hearts & simiyu:Ace of Hearts
# simiyu won round 23
# Cards won 2 :[<__main__.Card object at 0x10bec8da0>, <__main__.Card object at 0x10bf01e10>]
# Level 1 cards @ round 24: player 1 has cards: 29 and player 2 has cards: 23
# cards drawn bramwell: Three of Diamonds & simiyu:Three of Spades
# round 25, tie 1 :Three of Diamonds, Three of Spades
# cards drawn bramwell: [<__main__.Card object at 0x10bf01a90>, <__main__.Card object at 0x10bed30f0>, <__main__.Card object at 0x10bed3518>, <__main__.Card object at 0x10bf01c50>] & simiyu:[<__main__.Card object at 0x10bec8e10>, <__main__.Card object at 0x10bf01ac8>, <__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bed3470>]
# cards drawn bramwell: Queen of Spades & simiyu:Seven of Clubs
# bramwell won round 25
# Cards won 10 :[<__main__.Card object at 0x10bec8630>, <__main__.Card object at 0x10bf01a90>, <__main__.Card object at 0x10bed30f0>, <__main__.Card object at 0x10bed3518>, <__main__.Card object at 0x10bf01c50>, <__main__.Card object at 0x10bec8f98>, <__main__.Card object at 0x10bec8e10>, <__main__.Card object at 0x10bf01ac8>, <__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bed3470>]
# Level 1 cards @ round 26: player 1 has cards: 34 and player 2 has cards: 18
# cards drawn bramwell: Three of Diamonds & simiyu:Five of Spades
# simiyu won round 26
# Cards won 2 :[<__main__.Card object at 0x10bec8630>, <__main__.Card object at 0x10bed3550>]
# Level 1 cards @ round 27: player 1 has cards: 33 and player 2 has cards: 19
# cards drawn bramwell: Queen of Spades & simiyu:Four of Diamonds
# bramwell won round 27
# Cards won 2 :[<__main__.Card object at 0x10bf01c50>, <__main__.Card object at 0x10bed3240>]
# Level 1 cards @ round 28: player 1 has cards: 34 and player 2 has cards: 18
# cards drawn bramwell: Jack of Diamonds & simiyu:Ace of Hearts
# simiyu won round 28
# Cards won 2 :[<__main__.Card object at 0x10bf015f8>, <__main__.Card object at 0x10bf01e10>]
# Level 1 cards @ round 29: player 1 has cards: 33 and player 2 has cards: 19
# cards drawn bramwell: Five of Clubs & simiyu:Seven of Spades
# simiyu won round 29
# Cards won 2 :[<__main__.Card object at 0x10bed32b0>, <__main__.Card object at 0x10bed31d0>]
# Level 1 cards @ round 30: player 1 has cards: 32 and player 2 has cards: 20
# cards drawn bramwell: Seven of Diamonds & simiyu:Four of Spades
# bramwell won round 30
# Cards won 2 :[<__main__.Card object at 0x10bed36a0>, <__main__.Card object at 0x10bed3710>]
# Level 1 cards @ round 31: player 1 has cards: 33 and player 2 has cards: 19
# cards drawn bramwell: Seven of Hearts & simiyu:Ace of Clubs
# simiyu won round 31
# Cards won 2 :[<__main__.Card object at 0x10bed35c0>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 32: player 1 has cards: 32 and player 2 has cards: 20
# cards drawn bramwell: Seven of Diamonds & simiyu:Three of Hearts
# bramwell won round 32
# Cards won 2 :[<__main__.Card object at 0x10bed36a0>, <__main__.Card object at 0x10bec8748>]
# Level 1 cards @ round 33: player 1 has cards: 33 and player 2 has cards: 19
# cards drawn bramwell: Two of Clubs & simiyu:Jack of Clubs
# simiyu won round 33
# Cards won 2 :[<__main__.Card object at 0x10bec8e10>, <__main__.Card object at 0x10bf01ef0>]
# Level 1 cards @ round 34: player 1 has cards: 32 and player 2 has cards: 20
# cards drawn bramwell: Nine of Spades & simiyu:Seven of Spades
# bramwell won round 34
# Cards won 2 :[<__main__.Card object at 0x10bf01e48>, <__main__.Card object at 0x10bed31d0>]
# Level 1 cards @ round 35: player 1 has cards: 33 and player 2 has cards: 19
# cards drawn bramwell: Eight of Diamonds & simiyu:Two of Clubs
# bramwell won round 35
# Cards won 2 :[<__main__.Card object at 0x10bed30f0>, <__main__.Card object at 0x10bec8e10>]
# Level 1 cards @ round 36: player 1 has cards: 34 and player 2 has cards: 18
# cards drawn bramwell: Three of Hearts & simiyu:Eight of Spades
# simiyu won round 36
# Cards won 2 :[<__main__.Card object at 0x10bec8748>, <__main__.Card object at 0x10bed3198>]
# Level 1 cards @ round 37: player 1 has cards: 33 and player 2 has cards: 19
# cards drawn bramwell: Five of Hearts & simiyu:Five of Spades
# round 38, tie 1 :Five of Hearts, Five of Spades
# cards drawn bramwell: [<__main__.Card object at 0x10bed3710>, <__main__.Card object at 0x10bec8e10>, <__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bed3160>] & simiyu:[<__main__.Card object at 0x10bf01668>, <__main__.Card object at 0x10bf010b8>, <__main__.Card object at 0x10bf015f8>, <__main__.Card object at 0x10bed3128>]
# cards drawn bramwell: Four of Hearts & simiyu:Nine of Diamonds
# simiyu won round 38
# Cards won 10 :[<__main__.Card object at 0x10bed3278>, <__main__.Card object at 0x10bed3710>, <__main__.Card object at 0x10bec8e10>, <__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bed3160>, <__main__.Card object at 0x10bed3550>, <__main__.Card object at 0x10bf01668>, <__main__.Card object at 0x10bf010b8>, <__main__.Card object at 0x10bf015f8>, <__main__.Card object at 0x10bed3128>]
# Level 1 cards @ round 39: player 1 has cards: 28 and player 2 has cards: 24
# cards drawn bramwell: Six of Clubs & simiyu:Three of Diamonds
# bramwell won round 39
# Cards won 2 :[<__main__.Card object at 0x10bed3588>, <__main__.Card object at 0x10bec8630>]
# Level 1 cards @ round 40: player 1 has cards: 29 and player 2 has cards: 23
# cards drawn bramwell: Queen of Hearts & simiyu:King of Spades
# simiyu won round 40
# Cards won 2 :[<__main__.Card object at 0x10bf01780>, <__main__.Card object at 0x10bf017b8>]
# Level 1 cards @ round 41: player 1 has cards: 28 and player 2 has cards: 24
# cards drawn bramwell: Two of Diamonds & simiyu:Three of Hearts
# simiyu won round 41
# Cards won 2 :[<__main__.Card object at 0x10bec8a20>, <__main__.Card object at 0x10bec8748>]
# Level 1 cards @ round 42: player 1 has cards: 27 and player 2 has cards: 25
# cards drawn bramwell: Two of Spades & simiyu:Ace of Hearts
# simiyu won round 42
# Cards won 2 :[<__main__.Card object at 0x10bec8ef0>, <__main__.Card object at 0x10bf01e10>]
# Level 1 cards @ round 43: player 1 has cards: 26 and player 2 has cards: 26
# cards drawn bramwell: Eight of Hearts & simiyu:Jack of Diamonds
# simiyu won round 43
# Cards won 2 :[<__main__.Card object at 0x10bed3358>, <__main__.Card object at 0x10bf015f8>]
# Level 1 cards @ round 44: player 1 has cards: 25 and player 2 has cards: 27
# cards drawn bramwell: Eight of Clubs & simiyu:Two of Spades
# bramwell won round 44
# Cards won 2 :[<__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bec8ef0>]
# Level 1 cards @ round 45: player 1 has cards: 26 and player 2 has cards: 26
# cards drawn bramwell: Three of Diamonds & simiyu:Jack of Clubs
# simiyu won round 45
# Cards won 2 :[<__main__.Card object at 0x10bec8630>, <__main__.Card object at 0x10bf01ef0>]
# Level 1 cards @ round 46: player 1 has cards: 25 and player 2 has cards: 27
# cards drawn bramwell: King of Hearts & simiyu:Two of Diamonds
# bramwell won round 46
# Cards won 2 :[<__main__.Card object at 0x10bf01400>, <__main__.Card object at 0x10bec8a20>]
# Level 1 cards @ round 47: player 1 has cards: 26 and player 2 has cards: 26
# cards drawn bramwell: Queen of Spades & simiyu:Five of Hearts
# bramwell won round 47
# Cards won 2 :[<__main__.Card object at 0x10bf01c50>, <__main__.Card object at 0x10bed3278>]
# Level 1 cards @ round 48: player 1 has cards: 27 and player 2 has cards: 25
# cards drawn bramwell: Queen of Clubs & simiyu:Three of Hearts
# bramwell won round 48
# Cards won 2 :[<__main__.Card object at 0x10bf014e0>, <__main__.Card object at 0x10bec8748>]
# Level 1 cards @ round 49: player 1 has cards: 28 and player 2 has cards: 24
# cards drawn bramwell: King of Clubs & simiyu:Nine of Clubs
# bramwell won round 49
# Cards won 2 :[<__main__.Card object at 0x10bf011d0>, <__main__.Card object at 0x10bf01438>]
# Level 1 cards @ round 50: player 1 has cards: 29 and player 2 has cards: 23
# cards drawn bramwell: Five of Diamonds & simiyu:Six of Spades
# simiyu won round 50
# Cards won 2 :[<__main__.Card object at 0x10bed3208>, <__main__.Card object at 0x10bed3438>]
# Level 1 cards @ round 51: player 1 has cards: 28 and player 2 has cards: 24
# cards drawn bramwell: Queen of Clubs & simiyu:Three of Diamonds
# bramwell won round 51
# Cards won 2 :[<__main__.Card object at 0x10bf014e0>, <__main__.Card object at 0x10bec8630>]
# Level 1 cards @ round 52: player 1 has cards: 29 and player 2 has cards: 23
# cards drawn bramwell: Ten of Clubs & simiyu:Seven of Hearts
# bramwell won round 52
# Cards won 2 :[<__main__.Card object at 0x10bf01320>, <__main__.Card object at 0x10bed35c0>]
# Level 1 cards @ round 53: player 1 has cards: 30 and player 2 has cards: 22
# cards drawn bramwell: Ten of Spades & simiyu:Ten of Diamonds
# round 54, tie 1 :Ten of Spades, Ten of Diamonds
# cards drawn bramwell: [<__main__.Card object at 0x10bf014a8>, <__main__.Card object at 0x10bed3588>, <__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bec8c18>] & simiyu:[<__main__.Card object at 0x10bec8e10>, <__main__.Card object at 0x10bed3550>, <__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bf01668>]
# cards drawn bramwell: Three of Clubs & simiyu:Ace of Clubs
# simiyu won round 54
# Cards won 10 :[<__main__.Card object at 0x10bf01ac8>, <__main__.Card object at 0x10bf014a8>, <__main__.Card object at 0x10bed3588>, <__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bec8c18>, <__main__.Card object at 0x10bf012e8>, <__main__.Card object at 0x10bec8e10>, <__main__.Card object at 0x10bed3550>, <__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 55: player 1 has cards: 25 and player 2 has cards: 27
# cards drawn bramwell: Ten of Clubs & simiyu:Eight of Clubs
# bramwell won round 55
# Cards won 2 :[<__main__.Card object at 0x10bf01320>, <__main__.Card object at 0x10bed3630>]
# Level 1 cards @ round 56: player 1 has cards: 26 and player 2 has cards: 26
# cards drawn bramwell: Four of Diamonds & simiyu:Ace of Clubs
# simiyu won round 56
# Cards won 2 :[<__main__.Card object at 0x10bed3240>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 57: player 1 has cards: 25 and player 2 has cards: 27
# cards drawn bramwell: Nine of Spades & simiyu:Five of Diamonds
# bramwell won round 57
# Cards won 2 :[<__main__.Card object at 0x10bf01e48>, <__main__.Card object at 0x10bed3208>]
# Level 1 cards @ round 58: player 1 has cards: 26 and player 2 has cards: 26
# cards drawn bramwell: Ten of Clubs & simiyu:Four of Clubs
# bramwell won round 58
# Cards won 2 :[<__main__.Card object at 0x10bf01320>, <__main__.Card object at 0x10bed30b8>]
# Level 1 cards @ round 59: player 1 has cards: 27 and player 2 has cards: 25
# cards drawn bramwell: Eight of Diamonds & simiyu:Six of Clubs
# bramwell won round 59
# Cards won 2 :[<__main__.Card object at 0x10bed30f0>, <__main__.Card object at 0x10bed3588>]
# Level 1 cards @ round 60: player 1 has cards: 28 and player 2 has cards: 24
# cards drawn bramwell: Jack of Spades & simiyu:Four of Spades
# bramwell won round 60
# Cards won 2 :[<__main__.Card object at 0x10bf01cc0>, <__main__.Card object at 0x10bed3710>]
# Level 1 cards @ round 61: player 1 has cards: 29 and player 2 has cards: 23
# cards drawn bramwell: Seven of Spades & simiyu:King of Spades
# simiyu won round 61
# Cards won 2 :[<__main__.Card object at 0x10bed31d0>, <__main__.Card object at 0x10bf017b8>]
# Level 1 cards @ round 62: player 1 has cards: 28 and player 2 has cards: 24
# cards drawn bramwell: Jack of Hearts & simiyu:Two of Clubs
# bramwell won round 62
# Cards won 2 :[<__main__.Card object at 0x10bf018d0>, <__main__.Card object at 0x10bec8e10>]
# Level 1 cards @ round 63: player 1 has cards: 29 and player 2 has cards: 23
# cards drawn bramwell: Seven of Hearts & simiyu:Jack of Diamonds
# simiyu won round 63
# Cards won 2 :[<__main__.Card object at 0x10bed35c0>, <__main__.Card object at 0x10bf015f8>]
# Level 1 cards @ round 64: player 1 has cards: 28 and player 2 has cards: 24
# cards drawn bramwell: King of Hearts & simiyu:Nine of Hearts
# bramwell won round 64
# Cards won 2 :[<__main__.Card object at 0x10bf01400>, <__main__.Card object at 0x10bed3400>]
# Level 1 cards @ round 65: player 1 has cards: 29 and player 2 has cards: 23
# cards drawn bramwell: King of Hearts & simiyu:Four of Diamonds
# bramwell won round 65
# Cards won 2 :[<__main__.Card object at 0x10bf01400>, <__main__.Card object at 0x10bed3240>]
# Level 1 cards @ round 66: player 1 has cards: 30 and player 2 has cards: 22
# cards drawn bramwell: King of Hearts & simiyu:Seven of Hearts
# bramwell won round 66
# Cards won 2 :[<__main__.Card object at 0x10bf01400>, <__main__.Card object at 0x10bed35c0>]
# Level 1 cards @ round 67: player 1 has cards: 31 and player 2 has cards: 21
# cards drawn bramwell: Nine of Hearts & simiyu:Four of Hearts
# bramwell won round 67
# Cards won 2 :[<__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bed3160>]
# Level 1 cards @ round 68: player 1 has cards: 32 and player 2 has cards: 20
# cards drawn bramwell: Jack of Hearts & simiyu:Ace of Clubs
# simiyu won round 68
# Cards won 2 :[<__main__.Card object at 0x10bf018d0>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 69: player 1 has cards: 31 and player 2 has cards: 21
# cards drawn bramwell: Six of Diamonds & simiyu:Six of Spades
# round 70, tie 1 :Six of Diamonds, Six of Spades
# cards drawn bramwell: [<__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bed3240>, <__main__.Card object at 0x10bed3278>] & simiyu:[<__main__.Card object at 0x10bec8da0>, <__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bf012e8>, <__main__.Card object at 0x10bec8c18>]
# cards drawn bramwell: Five of Hearts & simiyu:Three of Clubs
# bramwell won round 70
# Cards won 10 :[<__main__.Card object at 0x10bed3518>, <__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bed3240>, <__main__.Card object at 0x10bed3278>, <__main__.Card object at 0x10bed3438>, <__main__.Card object at 0x10bec8da0>, <__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bf012e8>, <__main__.Card object at 0x10bec8c18>]
# Level 1 cards @ round 71: player 1 has cards: 36 and player 2 has cards: 16
# cards drawn bramwell: Nine of Hearts & simiyu:Jack of Hearts
# simiyu won round 71
# Cards won 2 :[<__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bf018d0>]
# Level 1 cards @ round 72: player 1 has cards: 35 and player 2 has cards: 17
# cards drawn bramwell: Ten of Diamonds & simiyu:Ace of Clubs
# simiyu won round 72
# Cards won 2 :[<__main__.Card object at 0x10bf012e8>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 73: player 1 has cards: 34 and player 2 has cards: 18
# cards drawn bramwell: Four of Diamonds & simiyu:Five of Clubs
# simiyu won round 73
# Cards won 2 :[<__main__.Card object at 0x10bed3240>, <__main__.Card object at 0x10bed32b0>]
# Level 1 cards @ round 74: player 1 has cards: 33 and player 2 has cards: 19
# cards drawn bramwell: Two of Clubs & simiyu:Five of Spades
# simiyu won round 74
# Cards won 2 :[<__main__.Card object at 0x10bec8e10>, <__main__.Card object at 0x10bed3550>]
# Level 1 cards @ round 75: player 1 has cards: 32 and player 2 has cards: 20
# cards drawn bramwell: Six of Clubs & simiyu:King of Spades
# simiyu won round 75
# Cards won 2 :[<__main__.Card object at 0x10bed3588>, <__main__.Card object at 0x10bf017b8>]
# Level 1 cards @ round 76: player 1 has cards: 31 and player 2 has cards: 21
# cards drawn bramwell: Three of Diamonds & simiyu:Queen of Diamonds
# simiyu won round 76
# Cards won 2 :[<__main__.Card object at 0x10bec8630>, <__main__.Card object at 0x10bf014a8>]
# Level 1 cards @ round 77: player 1 has cards: 30 and player 2 has cards: 22
# cards drawn bramwell: Six of Spades & simiyu:Ten of Diamonds
# simiyu won round 77
# Cards won 2 :[<__main__.Card object at 0x10bed3438>, <__main__.Card object at 0x10bf012e8>]
# Level 1 cards @ round 78: player 1 has cards: 29 and player 2 has cards: 23
# cards drawn bramwell: Two of Diamonds & simiyu:Nine of Hearts
# simiyu won round 78
# Cards won 2 :[<__main__.Card object at 0x10bec8a20>, <__main__.Card object at 0x10bed3400>]
# Level 1 cards @ round 79: player 1 has cards: 28 and player 2 has cards: 24
# cards drawn bramwell: Nine of Clubs & simiyu:Ten of Diamonds
# simiyu won round 79
# Cards won 2 :[<__main__.Card object at 0x10bf01438>, <__main__.Card object at 0x10bf012e8>]
# Level 1 cards @ round 80: player 1 has cards: 27 and player 2 has cards: 25
# cards drawn bramwell: Three of Clubs & simiyu:Eight of Spades
# simiyu won round 80
# Cards won 2 :[<__main__.Card object at 0x10bec8c18>, <__main__.Card object at 0x10bed3198>]
# Level 1 cards @ round 81: player 1 has cards: 26 and player 2 has cards: 26
# cards drawn bramwell: Nine of Spades & simiyu:Seven of Spades
# bramwell won round 81
# Cards won 2 :[<__main__.Card object at 0x10bf01e48>, <__main__.Card object at 0x10bed31d0>]
# Level 1 cards @ round 82: player 1 has cards: 27 and player 2 has cards: 25
# cards drawn bramwell: Four of Spades & simiyu:Nine of Hearts
# simiyu won round 82
# Cards won 2 :[<__main__.Card object at 0x10bed3710>, <__main__.Card object at 0x10bed3400>]
# Level 1 cards @ round 83: player 1 has cards: 26 and player 2 has cards: 26
# cards drawn bramwell: Six of Diamonds & simiyu:Nine of Diamonds
# simiyu won round 83
# Cards won 2 :[<__main__.Card object at 0x10bed3518>, <__main__.Card object at 0x10bed3128>]
# Level 1 cards @ round 84: player 1 has cards: 25 and player 2 has cards: 27
# cards drawn bramwell: Three of Hearts & simiyu:Jack of Diamonds
# simiyu won round 84
# Cards won 2 :[<__main__.Card object at 0x10bec8748>, <__main__.Card object at 0x10bf015f8>]
# Level 1 cards @ round 85: player 1 has cards: 24 and player 2 has cards: 28
# cards drawn bramwell: Jack of Spades & simiyu:Jack of Diamonds
# round 86, tie 1 :Jack of Spades, Jack of Diamonds
# cards drawn bramwell: [<__main__.Card object at 0x10bf011d0>, <__main__.Card object at 0x10bec8ef0>, <__main__.Card object at 0x10bed31d0>, <__main__.Card object at 0x10bed3160>] & simiyu:[<__main__.Card object at 0x10bf01e10>, <__main__.Card object at 0x10bf018d0>, <__main__.Card object at 0x10bf010b8>, <__main__.Card object at 0x10bf01ac8>]
# cards drawn bramwell: Four of Hearts & simiyu:Ten of Spades
# simiyu won round 86
# Cards won 10 :[<__main__.Card object at 0x10bf01cc0>, <__main__.Card object at 0x10bf011d0>, <__main__.Card object at 0x10bec8ef0>, <__main__.Card object at 0x10bed31d0>, <__main__.Card object at 0x10bed3160>, <__main__.Card object at 0x10bf015f8>, <__main__.Card object at 0x10bf01e10>, <__main__.Card object at 0x10bf018d0>, <__main__.Card object at 0x10bf010b8>, <__main__.Card object at 0x10bf01ac8>]
# Level 1 cards @ round 87: player 1 has cards: 19 and player 2 has cards: 33
# cards drawn bramwell: Seven of Diamonds & simiyu:Five of Clubs
# bramwell won round 87
# Cards won 2 :[<__main__.Card object at 0x10bed36a0>, <__main__.Card object at 0x10bed32b0>]
# Level 1 cards @ round 88: player 1 has cards: 20 and player 2 has cards: 32
# cards drawn bramwell: Two of Hearts & simiyu:Ten of Spades
# simiyu won round 88
# Cards won 2 :[<__main__.Card object at 0x10bec8da0>, <__main__.Card object at 0x10bf01ac8>]
# Level 1 cards @ round 89: player 1 has cards: 19 and player 2 has cards: 33
# cards drawn bramwell: Five of Hearts & simiyu:Nine of Clubs
# simiyu won round 89
# Cards won 2 :[<__main__.Card object at 0x10bed3278>, <__main__.Card object at 0x10bf01438>]
# Level 1 cards @ round 90: player 1 has cards: 18 and player 2 has cards: 34
# cards drawn bramwell: Five of Clubs & simiyu:Four of Spades
# bramwell won round 90
# Cards won 2 :[<__main__.Card object at 0x10bed32b0>, <__main__.Card object at 0x10bed3710>]
# Level 1 cards @ round 91: player 1 has cards: 19 and player 2 has cards: 33
# cards drawn bramwell: Four of Spades & simiyu:Three of Clubs
# bramwell won round 91
# Cards won 2 :[<__main__.Card object at 0x10bed3710>, <__main__.Card object at 0x10bec8c18>]
# Level 1 cards @ round 92: player 1 has cards: 20 and player 2 has cards: 32
# cards drawn bramwell: Seven of Hearts & simiyu:Six of Spades
# bramwell won round 92
# Cards won 2 :[<__main__.Card object at 0x10bed35c0>, <__main__.Card object at 0x10bed3438>]
# Level 1 cards @ round 93: player 1 has cards: 21 and player 2 has cards: 31
# cards drawn bramwell: Five of Diamonds & simiyu:Ace of Clubs
# simiyu won round 93
# Cards won 2 :[<__main__.Card object at 0x10bed3208>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 94: player 1 has cards: 20 and player 2 has cards: 32
# cards drawn bramwell: Ten of Clubs & simiyu:Ten of Spades
# round 95, tie 1 :Ten of Clubs, Ten of Spades
# cards drawn bramwell: [<__main__.Card object at 0x10bed32b0>, <__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bf01c50>, <__main__.Card object at 0x10bf014e0>] & simiyu:[<__main__.Card object at 0x10bed3160>, <__main__.Card object at 0x10bed31d0>, <__main__.Card object at 0x10bf011d0>, <__main__.Card object at 0x10bed3198>]
# cards drawn bramwell: Queen of Clubs & simiyu:Eight of Spades
# bramwell won round 95
# Cards won 10 :[<__main__.Card object at 0x10bf01320>, <__main__.Card object at 0x10bed32b0>, <__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bf01c50>, <__main__.Card object at 0x10bf014e0>, <__main__.Card object at 0x10bf01ac8>, <__main__.Card object at 0x10bed3160>, <__main__.Card object at 0x10bed31d0>, <__main__.Card object at 0x10bf011d0>, <__main__.Card object at 0x10bed3198>]
# Level 1 cards @ round 96: player 1 has cards: 25 and player 2 has cards: 27
# cards drawn bramwell: King of Hearts & simiyu:Two of Clubs
# bramwell won round 96
# Cards won 2 :[<__main__.Card object at 0x10bf01400>, <__main__.Card object at 0x10bec8e10>]
# Level 1 cards @ round 97: player 1 has cards: 26 and player 2 has cards: 26
# cards drawn bramwell: Eight of Spades & simiyu:Nine of Hearts
# simiyu won round 97
# Cards won 2 :[<__main__.Card object at 0x10bed3198>, <__main__.Card object at 0x10bed3400>]
# Level 1 cards @ round 98: player 1 has cards: 25 and player 2 has cards: 27
# cards drawn bramwell: Four of Hearts & simiyu:Ace of Hearts
# simiyu won round 98
# Cards won 2 :[<__main__.Card object at 0x10bed3160>, <__main__.Card object at 0x10bf01e10>]
# Level 1 cards @ round 99: player 1 has cards: 24 and player 2 has cards: 28
# cards drawn bramwell: Nine of Spades & simiyu:Jack of Hearts
# simiyu won round 99
# Cards won 2 :[<__main__.Card object at 0x10bf01e48>, <__main__.Card object at 0x10bf018d0>]
# Level 1 cards @ round 100: player 1 has cards: 23 and player 2 has cards: 29
# cards drawn bramwell: Three of Clubs & simiyu:Eight of Spades
# simiyu won round 100
# Cards won 2 :[<__main__.Card object at 0x10bec8c18>, <__main__.Card object at 0x10bed3198>]
# Level 1 cards @ round 101: player 1 has cards: 22 and player 2 has cards: 30
# cards drawn bramwell: Eight of Clubs & simiyu:Two of Spades
# bramwell won round 101
# Cards won 2 :[<__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bec8ef0>]
# Level 1 cards @ round 102: player 1 has cards: 23 and player 2 has cards: 29
# cards drawn bramwell: Six of Spades & simiyu:Two of Diamonds
# bramwell won round 102
# Cards won 2 :[<__main__.Card object at 0x10bed3438>, <__main__.Card object at 0x10bec8a20>]
# Level 1 cards @ round 103: player 1 has cards: 24 and player 2 has cards: 28
# cards drawn bramwell: Six of Hearts & simiyu:Queen of Diamonds
# simiyu won round 103
# Cards won 2 :[<__main__.Card object at 0x10bed3320>, <__main__.Card object at 0x10bf014a8>]
# Level 1 cards @ round 104: player 1 has cards: 23 and player 2 has cards: 29
# cards drawn bramwell: Ace of Diamonds & simiyu:King of Diamonds
# bramwell won round 104
# Cards won 2 :[<__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bf01588>]
# Level 1 cards @ round 105: player 1 has cards: 24 and player 2 has cards: 28
# cards drawn bramwell: Queen of Spades & simiyu:Three of Hearts
# bramwell won round 105
# Cards won 2 :[<__main__.Card object at 0x10bf01c50>, <__main__.Card object at 0x10bec8748>]
# Level 1 cards @ round 106: player 1 has cards: 25 and player 2 has cards: 27
# cards drawn bramwell: Queen of Clubs & simiyu:Ace of Clubs
# simiyu won round 106
# Cards won 2 :[<__main__.Card object at 0x10bf014e0>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 107: player 1 has cards: 24 and player 2 has cards: 28
# cards drawn bramwell: Seven of Spades & simiyu:Nine of Clubs
# simiyu won round 107
# Cards won 2 :[<__main__.Card object at 0x10bed31d0>, <__main__.Card object at 0x10bf01438>]
# Level 1 cards @ round 108: player 1 has cards: 23 and player 2 has cards: 29
# cards drawn bramwell: Two of Spades & simiyu:King of Spades
# simiyu won round 108
# Cards won 2 :[<__main__.Card object at 0x10bec8ef0>, <__main__.Card object at 0x10bf017b8>]
# Level 1 cards @ round 109: player 1 has cards: 22 and player 2 has cards: 30
# cards drawn bramwell: Ten of Spades & simiyu:Six of Hearts
# bramwell won round 109
# Cards won 2 :[<__main__.Card object at 0x10bf01ac8>, <__main__.Card object at 0x10bed3320>]
# Level 1 cards @ round 110: player 1 has cards: 23 and player 2 has cards: 29
# cards drawn bramwell: Two of Clubs & simiyu:Four of Diamonds
# simiyu won round 110
# Cards won 2 :[<__main__.Card object at 0x10bec8e10>, <__main__.Card object at 0x10bed3240>]
# Level 1 cards @ round 111: player 1 has cards: 22 and player 2 has cards: 30
# cards drawn bramwell: Ten of Spades & simiyu:Queen of Diamonds
# simiyu won round 111
# Cards won 2 :[<__main__.Card object at 0x10bf01ac8>, <__main__.Card object at 0x10bf014a8>]
# Level 1 cards @ round 112: player 1 has cards: 21 and player 2 has cards: 31
# cards drawn bramwell: Seven of Diamonds & simiyu:Five of Spades
# bramwell won round 112
# Cards won 2 :[<__main__.Card object at 0x10bed36a0>, <__main__.Card object at 0x10bed3550>]
# Level 1 cards @ round 113: player 1 has cards: 22 and player 2 has cards: 30
# cards drawn bramwell: King of Diamonds & simiyu:Eight of Hearts
# bramwell won round 113
# Cards won 2 :[<__main__.Card object at 0x10bf01588>, <__main__.Card object at 0x10bed3358>]
# Level 1 cards @ round 114: player 1 has cards: 23 and player 2 has cards: 29
# cards drawn bramwell: King of Diamonds & simiyu:Jack of Hearts
# bramwell won round 114
# Cards won 2 :[<__main__.Card object at 0x10bf01588>, <__main__.Card object at 0x10bf018d0>]
# Level 1 cards @ round 115: player 1 has cards: 24 and player 2 has cards: 28
# cards drawn bramwell: Seven of Clubs & simiyu:Nine of Spades
# simiyu won round 115
# Cards won 2 :[<__main__.Card object at 0x10bed3470>, <__main__.Card object at 0x10bf01e48>]
# Level 1 cards @ round 116: player 1 has cards: 23 and player 2 has cards: 29
# cards drawn bramwell: Two of Diamonds & simiyu:Ten of Hearts
# simiyu won round 116
# Cards won 2 :[<__main__.Card object at 0x10bec8a20>, <__main__.Card object at 0x10bf010b8>]
# Level 1 cards @ round 117: player 1 has cards: 22 and player 2 has cards: 30
# cards drawn bramwell: Jack of Clubs & simiyu:Three of Diamonds
# bramwell won round 117
# Cards won 2 :[<__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bec8630>]
# Level 1 cards @ round 118: player 1 has cards: 23 and player 2 has cards: 29
# cards drawn bramwell: Five of Spades & simiyu:Queen of Hearts
# simiyu won round 118
# Cards won 2 :[<__main__.Card object at 0x10bed3550>, <__main__.Card object at 0x10bf01780>]
# Level 1 cards @ round 119: player 1 has cards: 22 and player 2 has cards: 30
# cards drawn bramwell: Four of Spades & simiyu:Five of Spades
# simiyu won round 119
# Cards won 2 :[<__main__.Card object at 0x10bed3710>, <__main__.Card object at 0x10bed3550>]
# Level 1 cards @ round 120: player 1 has cards: 21 and player 2 has cards: 31
# cards drawn bramwell: Eight of Hearts & simiyu:King of Spades
# simiyu won round 120
# Cards won 2 :[<__main__.Card object at 0x10bed3358>, <__main__.Card object at 0x10bf017b8>]
# Level 1 cards @ round 121: player 1 has cards: 20 and player 2 has cards: 32
# cards drawn bramwell: Jack of Hearts & simiyu:Six of Clubs
# bramwell won round 121
# Cards won 2 :[<__main__.Card object at 0x10bf018d0>, <__main__.Card object at 0x10bed3588>]
# Level 1 cards @ round 122: player 1 has cards: 21 and player 2 has cards: 31
# cards drawn bramwell: Eight of Clubs & simiyu:Five of Diamonds
# bramwell won round 122
# Cards won 2 :[<__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bed3208>]
# Level 1 cards @ round 123: player 1 has cards: 22 and player 2 has cards: 30
# cards drawn bramwell: Three of Hearts & simiyu:Five of Spades
# simiyu won round 123
# Cards won 2 :[<__main__.Card object at 0x10bec8748>, <__main__.Card object at 0x10bed3550>]
# Level 1 cards @ round 124: player 1 has cards: 21 and player 2 has cards: 31
# cards drawn bramwell: Six of Hearts & simiyu:Four of Hearts
# bramwell won round 124
# Cards won 2 :[<__main__.Card object at 0x10bed3320>, <__main__.Card object at 0x10bed3160>]
# Level 1 cards @ round 125: player 1 has cards: 22 and player 2 has cards: 30
# cards drawn bramwell: Eight of Clubs & simiyu:Ace of Clubs
# simiyu won round 125
# Cards won 2 :[<__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 126: player 1 has cards: 21 and player 2 has cards: 31
# cards drawn bramwell: Four of Clubs & simiyu:Ace of Clubs
# simiyu won round 126
# Cards won 2 :[<__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 127: player 1 has cards: 20 and player 2 has cards: 32
# cards drawn bramwell: Five of Clubs & simiyu:Five of Spades
# round 128, tie 1 :Five of Clubs, Five of Spades
# cards drawn bramwell: [<__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bf01320>, <__main__.Card object at 0x10bf011d0>, <__main__.Card object at 0x10bed3438>] & simiyu:[<__main__.Card object at 0x10bf01e10>, <__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bf01438>]
# cards drawn bramwell: Six of Spades & simiyu:Nine of Clubs
# simiyu won round 128
# Cards won 10 :[<__main__.Card object at 0x10bed32b0>, <__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bf01320>, <__main__.Card object at 0x10bf011d0>, <__main__.Card object at 0x10bed3438>, <__main__.Card object at 0x10bed3550>, <__main__.Card object at 0x10bf01e10>, <__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bf01438>]
# Level 1 cards @ round 129: player 1 has cards: 15 and player 2 has cards: 37
# cards drawn bramwell: Seven of Diamonds & simiyu:Nine of Hearts
# simiyu won round 129
# Cards won 2 :[<__main__.Card object at 0x10bed36a0>, <__main__.Card object at 0x10bed3400>]
# Level 1 cards @ round 130: player 1 has cards: 14 and player 2 has cards: 38
# cards drawn bramwell: Six of Clubs & simiyu:Two of Spades
# bramwell won round 130
# Cards won 2 :[<__main__.Card object at 0x10bed3588>, <__main__.Card object at 0x10bec8ef0>]
# Level 1 cards @ round 131: player 1 has cards: 15 and player 2 has cards: 37
# cards drawn bramwell: Five of Diamonds & simiyu:Queen of Diamonds
# simiyu won round 131
# Cards won 2 :[<__main__.Card object at 0x10bed3208>, <__main__.Card object at 0x10bf014a8>]
# Level 1 cards @ round 132: player 1 has cards: 14 and player 2 has cards: 38
# cards drawn bramwell: Ace of Spades & simiyu:Nine of Hearts
# bramwell won round 132
# Cards won 2 :[<__main__.Card object at 0x10bf01a90>, <__main__.Card object at 0x10bed3400>]
# Level 1 cards @ round 133: player 1 has cards: 15 and player 2 has cards: 37
# cards drawn bramwell: Queen of Spades & simiyu:Four of Diamonds
# bramwell won round 133
# Cards won 2 :[<__main__.Card object at 0x10bf01c50>, <__main__.Card object at 0x10bed3240>]
# Level 1 cards @ round 134: player 1 has cards: 16 and player 2 has cards: 36
# cards drawn bramwell: Four of Hearts & simiyu:Three of Hearts
# bramwell won round 134
# Cards won 2 :[<__main__.Card object at 0x10bed3160>, <__main__.Card object at 0x10bec8748>]
# Level 1 cards @ round 135: player 1 has cards: 17 and player 2 has cards: 35
# cards drawn bramwell: Seven of Hearts & simiyu:Seven of Spades
# round 136, tie 1 :Seven of Hearts, Seven of Spades
# cards drawn bramwell: [<__main__.Card object at 0x10bed3240>, <__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bf01588>] & simiyu:[<__main__.Card object at 0x10bf01780>, <__main__.Card object at 0x10bf011d0>, <__main__.Card object at 0x10bec8c18>, <__main__.Card object at 0x10bed3550>]
# cards drawn bramwell: King of Diamonds & simiyu:Five of Spades
# bramwell won round 136
# Cards won 10 :[<__main__.Card object at 0x10bed35c0>, <__main__.Card object at 0x10bed3240>, <__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bf01588>, <__main__.Card object at 0x10bed31d0>, <__main__.Card object at 0x10bf01780>, <__main__.Card object at 0x10bf011d0>, <__main__.Card object at 0x10bec8c18>, <__main__.Card object at 0x10bed3550>]
# Level 1 cards @ round 137: player 1 has cards: 22 and player 2 has cards: 30
# cards drawn bramwell: Two of Spades & simiyu:Ten of Diamonds
# simiyu won round 137
# Cards won 2 :[<__main__.Card object at 0x10bec8ef0>, <__main__.Card object at 0x10bf012e8>]
# Level 1 cards @ round 138: player 1 has cards: 21 and player 2 has cards: 31
# cards drawn bramwell: Six of Clubs & simiyu:Nine of Diamonds
# simiyu won round 138
# Cards won 2 :[<__main__.Card object at 0x10bed3588>, <__main__.Card object at 0x10bed3128>]
# Level 1 cards @ round 139: player 1 has cards: 20 and player 2 has cards: 32
# cards drawn bramwell: Jack of Hearts & simiyu:Jack of Diamonds
# round 140, tie 1 :Jack of Hearts, Jack of Diamonds
# cards drawn bramwell: [<__main__.Card object at 0x10bed3320>, <__main__.Card object at 0x10bf01c50>, <__main__.Card object at 0x10bed3550>, <__main__.Card object at 0x10bed31d0>] & simiyu:[<__main__.Card object at 0x10bf010b8>, <__main__.Card object at 0x10bed32b0>, <__main__.Card object at 0x10bed3438>, <__main__.Card object at 0x10bed3630>]
# cards drawn bramwell: Seven of Spades & simiyu:Eight of Clubs
# simiyu won round 140
# Cards won 10 :[<__main__.Card object at 0x10bf018d0>, <__main__.Card object at 0x10bed3320>, <__main__.Card object at 0x10bf01c50>, <__main__.Card object at 0x10bed3550>, <__main__.Card object at 0x10bed31d0>, <__main__.Card object at 0x10bf015f8>, <__main__.Card object at 0x10bf010b8>, <__main__.Card object at 0x10bed32b0>, <__main__.Card object at 0x10bed3438>, <__main__.Card object at 0x10bed3630>]
# Level 1 cards @ round 141: player 1 has cards: 15 and player 2 has cards: 37
# cards drawn bramwell: King of Diamonds & simiyu:Eight of Hearts
# bramwell won round 141
# Cards won 2 :[<__main__.Card object at 0x10bf01588>, <__main__.Card object at 0x10bed3358>]
# Level 1 cards @ round 142: player 1 has cards: 16 and player 2 has cards: 36
# cards drawn bramwell: Four of Diamonds & simiyu:Ten of Clubs
# simiyu won round 142
# Cards won 2 :[<__main__.Card object at 0x10bed3240>, <__main__.Card object at 0x10bf01320>]
# Level 1 cards @ round 143: player 1 has cards: 15 and player 2 has cards: 37
# cards drawn bramwell: Nine of Hearts & simiyu:Two of Diamonds
# bramwell won round 143
# Cards won 2 :[<__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bec8a20>]
# Level 1 cards @ round 144: player 1 has cards: 16 and player 2 has cards: 36
# cards drawn bramwell: Four of Hearts & simiyu:Two of Hearts
# bramwell won round 144
# Cards won 2 :[<__main__.Card object at 0x10bed3160>, <__main__.Card object at 0x10bec8da0>]
# Level 1 cards @ round 145: player 1 has cards: 17 and player 2 has cards: 35
# cards drawn bramwell: Queen of Hearts & simiyu:Jack of Hearts
# bramwell won round 145
# Cards won 2 :[<__main__.Card object at 0x10bf01780>, <__main__.Card object at 0x10bf018d0>]
# Level 1 cards @ round 146: player 1 has cards: 18 and player 2 has cards: 34
# cards drawn bramwell: Three of Diamonds & simiyu:Six of Hearts
# simiyu won round 146
# Cards won 2 :[<__main__.Card object at 0x10bec8630>, <__main__.Card object at 0x10bed3320>]
# Level 1 cards @ round 147: player 1 has cards: 17 and player 2 has cards: 35
# cards drawn bramwell: Three of Spades & simiyu:Seven of Diamonds
# simiyu won round 147
# Cards won 2 :[<__main__.Card object at 0x10bec8f98>, <__main__.Card object at 0x10bed36a0>]
# Level 1 cards @ round 148: player 1 has cards: 16 and player 2 has cards: 36
# cards drawn bramwell: Queen of Hearts & simiyu:Four of Diamonds
# bramwell won round 148
# Cards won 2 :[<__main__.Card object at 0x10bf01780>, <__main__.Card object at 0x10bed3240>]
# Level 1 cards @ round 149: player 1 has cards: 17 and player 2 has cards: 35
# cards drawn bramwell: Eight of Diamonds & simiyu:Five of Diamonds
# bramwell won round 149
# Cards won 2 :[<__main__.Card object at 0x10bed30f0>, <__main__.Card object at 0x10bed3208>]
# Level 1 cards @ round 150: player 1 has cards: 18 and player 2 has cards: 34
# cards drawn bramwell: King of Clubs & simiyu:Ten of Clubs
# bramwell won round 150
# Cards won 2 :[<__main__.Card object at 0x10bf011d0>, <__main__.Card object at 0x10bf01320>]
# Level 1 cards @ round 151: player 1 has cards: 19 and player 2 has cards: 33
# cards drawn bramwell: Ace of Spades & simiyu:Seven of Spades
# bramwell won round 151
# Cards won 2 :[<__main__.Card object at 0x10bf01a90>, <__main__.Card object at 0x10bed31d0>]
# Level 1 cards @ round 152: player 1 has cards: 20 and player 2 has cards: 32
# cards drawn bramwell: Three of Hearts & simiyu:King of Spades
# simiyu won round 152
# Cards won 2 :[<__main__.Card object at 0x10bec8748>, <__main__.Card object at 0x10bf017b8>]
# Level 1 cards @ round 153: player 1 has cards: 19 and player 2 has cards: 33
# cards drawn bramwell: Ace of Spades & simiyu:Seven of Diamonds
# bramwell won round 153
# Cards won 2 :[<__main__.Card object at 0x10bf01a90>, <__main__.Card object at 0x10bed36a0>]
# Level 1 cards @ round 154: player 1 has cards: 20 and player 2 has cards: 32
# cards drawn bramwell: Five of Diamonds & simiyu:Nine of Clubs
# simiyu won round 154
# Cards won 2 :[<__main__.Card object at 0x10bed3208>, <__main__.Card object at 0x10bf01438>]
# Level 1 cards @ round 155: player 1 has cards: 19 and player 2 has cards: 33
# cards drawn bramwell: Nine of Hearts & simiyu:Ace of Clubs
# simiyu won round 155
# Cards won 2 :[<__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 156: player 1 has cards: 18 and player 2 has cards: 34
# cards drawn bramwell: King of Clubs & simiyu:Ace of Hearts
# simiyu won round 156
# Cards won 2 :[<__main__.Card object at 0x10bf011d0>, <__main__.Card object at 0x10bf01e10>]
# Level 1 cards @ round 157: player 1 has cards: 17 and player 2 has cards: 35
# cards drawn bramwell: Seven of Hearts & simiyu:Nine of Hearts
# simiyu won round 157
# Cards won 2 :[<__main__.Card object at 0x10bed35c0>, <__main__.Card object at 0x10bed3400>]
# Level 1 cards @ round 158: player 1 has cards: 16 and player 2 has cards: 36
# cards drawn bramwell: King of Hearts & simiyu:Nine of Diamonds
# bramwell won round 158
# Cards won 2 :[<__main__.Card object at 0x10bf01400>, <__main__.Card object at 0x10bed3128>]
# Level 1 cards @ round 159: player 1 has cards: 17 and player 2 has cards: 35
# cards drawn bramwell: Seven of Spades & simiyu:Eight of Clubs
# simiyu won round 159
# Cards won 2 :[<__main__.Card object at 0x10bed31d0>, <__main__.Card object at 0x10bed3630>]
# Level 1 cards @ round 160: player 1 has cards: 16 and player 2 has cards: 36
# cards drawn bramwell: Queen of Hearts & simiyu:Five of Hearts
# bramwell won round 160
# Cards won 2 :[<__main__.Card object at 0x10bf01780>, <__main__.Card object at 0x10bed3278>]
# Level 1 cards @ round 161: player 1 has cards: 17 and player 2 has cards: 35
# cards drawn bramwell: Seven of Diamonds & simiyu:Ten of Spades
# simiyu won round 161
# Cards won 2 :[<__main__.Card object at 0x10bed36a0>, <__main__.Card object at 0x10bf01ac8>]
# Level 1 cards @ round 162: player 1 has cards: 16 and player 2 has cards: 36
# cards drawn bramwell: Jack of Hearts & simiyu:Queen of Spades
# simiyu won round 162
# Cards won 2 :[<__main__.Card object at 0x10bf018d0>, <__main__.Card object at 0x10bf01c50>]
# Level 1 cards @ round 163: player 1 has cards: 15 and player 2 has cards: 37
# cards drawn bramwell: Five of Hearts & simiyu:Jack of Clubs
# simiyu won round 163
# Cards won 2 :[<__main__.Card object at 0x10bed3278>, <__main__.Card object at 0x10bf01ef0>]
# Level 1 cards @ round 164: player 1 has cards: 14 and player 2 has cards: 38
# cards drawn bramwell: Ace of Spades & simiyu:Ace of Clubs
# round 165, tie 1 :Ace of Spades, Ace of Clubs
# cards drawn bramwell: [<__main__.Card object at 0x10bed3358>, <__main__.Card object at 0x10bec8da0>, <__main__.Card object at 0x10bf01588>, <__main__.Card object at 0x10bec8c18>] & simiyu:[<__main__.Card object at 0x10bf01cc0>, <__main__.Card object at 0x10bec8748>, <__main__.Card object at 0x10bed3198>, <__main__.Card object at 0x10bed36a0>]
# cards drawn bramwell: Three of Clubs & simiyu:Seven of Diamonds
# simiyu won round 165
# Cards won 10 :[<__main__.Card object at 0x10bf01a90>, <__main__.Card object at 0x10bed3358>, <__main__.Card object at 0x10bec8da0>, <__main__.Card object at 0x10bf01588>, <__main__.Card object at 0x10bec8c18>, <__main__.Card object at 0x10bf01668>, <__main__.Card object at 0x10bf01cc0>, <__main__.Card object at 0x10bec8748>, <__main__.Card object at 0x10bed3198>, <__main__.Card object at 0x10bed36a0>]
# Level 1 cards @ round 166: player 1 has cards: 9 and player 2 has cards: 43
# cards drawn bramwell: Ace of Diamonds & simiyu:Five of Spades
# bramwell won round 166
# Cards won 2 :[<__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bed3550>]
# Level 1 cards @ round 167: player 1 has cards: 10 and player 2 has cards: 42
# cards drawn bramwell: Queen of Hearts & simiyu:Queen of Spades
# round 168, tie 1 :Queen of Hearts, Queen of Spades
# ...
# Cards won 2 :[<__main__.Card object at 0x10bed31d0>, <__main__.Card object at 0x10bec8c18>]
# Level 1 cards @ round 260: player 1 has cards: 6 and player 2 has cards: 46
# cards drawn bramwell: Two of Spades & simiyu:Four of Clubs
# simiyu won round 260
# Cards won 2 :[<__main__.Card object at 0x10bec8ef0>, <__main__.Card object at 0x10bed30b8>]
# Level 1 cards @ round 261: player 1 has cards: 5 and player 2 has cards: 47
# cards drawn bramwell: Jack of Clubs & simiyu:Six of Hearts
# bramwell won round 261
# Cards won 2 :[<__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bed3320>]
# Level 1 cards @ round 262: player 1 has cards: 6 and player 2 has cards: 46
# cards drawn bramwell: Seven of Spades & simiyu:Jack of Diamonds
# simiyu won round 262
# Cards won 2 :[<__main__.Card object at 0x10bed31d0>, <__main__.Card object at 0x10bf015f8>]
# Level 1 cards @ round 263: player 1 has cards: 5 and player 2 has cards: 47
# cards drawn bramwell: Three of Spades & simiyu:King of Clubs
# simiyu won round 263
# Cards won 2 :[<__main__.Card object at 0x10bec8f98>, <__main__.Card object at 0x10bf011d0>]
# Level 1 cards @ round 264: player 1 has cards: 4 and player 2 has cards: 48
# cards drawn bramwell: Ten of Diamonds & simiyu:Seven of Clubs
# bramwell won round 264
# Cards won 2 :[<__main__.Card object at 0x10bf012e8>, <__main__.Card object at 0x10bed3470>]
# Level 1 cards @ round 265: player 1 has cards: 5 and player 2 has cards: 47
# cards drawn bramwell: Seven of Clubs & simiyu:Four of Hearts
# bramwell won round 265
# Cards won 2 :[<__main__.Card object at 0x10bed3470>, <__main__.Card object at 0x10bed3160>]
# Level 1 cards @ round 266: player 1 has cards: 6 and player 2 has cards: 46
# cards drawn bramwell: Ten of Diamonds & simiyu:Four of Clubs
# bramwell won round 266
# Cards won 2 :[<__main__.Card object at 0x10bf012e8>, <__main__.Card object at 0x10bed30b8>]
# Level 1 cards @ round 267: player 1 has cards: 7 and player 2 has cards: 45
# cards drawn bramwell: Jack of Clubs & simiyu:Five of Spades
# bramwell won round 267
# Cards won 2 :[<__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bed3550>]
# Level 1 cards @ round 268: player 1 has cards: 8 and player 2 has cards: 44
# cards drawn bramwell: Ten of Diamonds & simiyu:Ten of Spades
# round 269, tie 1 :Ten of Diamonds, Ten of Spades
# cards drawn bramwell: [<__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bed3550>, <__main__.Card object at 0x10bed3470>] & simiyu:[<__main__.Card object at 0x10bf017b8>, <__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bed3710>]
# cards drawn bramwell: Seven of Clubs & simiyu:Four of Spades
# bramwell won round 269
# Cards won 10 :[<__main__.Card object at 0x10bf012e8>, <__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bed3550>, <__main__.Card object at 0x10bed3470>, <__main__.Card object at 0x10bf01ac8>, <__main__.Card object at 0x10bf017b8>, <__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bed3710>]
# Level 1 cards @ round 270: player 1 has cards: 13 and player 2 has cards: 39
# cards drawn bramwell: King of Spades & simiyu:Three of Spades
# bramwell won round 270
# Cards won 2 :[<__main__.Card object at 0x10bf017b8>, <__main__.Card object at 0x10bec8f98>]
# Level 1 cards @ round 271: player 1 has cards: 14 and player 2 has cards: 38
# cards drawn bramwell: Five of Spades & simiyu:King of Hearts
# simiyu won round 271
# Cards won 2 :[<__main__.Card object at 0x10bed3550>, <__main__.Card object at 0x10bf01400>]
# Level 1 cards @ round 272: player 1 has cards: 13 and player 2 has cards: 39
# cards drawn bramwell: Six of Hearts & simiyu:King of Hearts
# simiyu won round 272
# Cards won 2 :[<__main__.Card object at 0x10bed3320>, <__main__.Card object at 0x10bf01400>]
# Level 1 cards @ round 273: player 1 has cards: 12 and player 2 has cards: 40
# cards drawn bramwell: Ten of Diamonds & simiyu:Queen of Spades
# simiyu won round 273
# Cards won 2 :[<__main__.Card object at 0x10bf012e8>, <__main__.Card object at 0x10bf01c50>]
# Level 1 cards @ round 274: player 1 has cards: 11 and player 2 has cards: 41
# cards drawn bramwell: Seven of Clubs & simiyu:Queen of Diamonds
# simiyu won round 274
# Cards won 2 :[<__main__.Card object at 0x10bed3470>, <__main__.Card object at 0x10bf014a8>]
# Level 1 cards @ round 275: player 1 has cards: 10 and player 2 has cards: 42
# cards drawn bramwell: Ace of Diamonds & simiyu:Three of Hearts
# bramwell won round 275
# Cards won 2 :[<__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bec8748>]
# Level 1 cards @ round 276: player 1 has cards: 11 and player 2 has cards: 41
# cards drawn bramwell: Ten of Spades & simiyu:Ten of Diamonds
# round 277, tie 1 :Ten of Spades, Ten of Diamonds
# cards drawn bramwell: [<__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bec8f98>, <__main__.Card object at 0x10bec8748>] & simiyu:[<__main__.Card object at 0x10bf01400>, <__main__.Card object at 0x10bed36a0>, <__main__.Card object at 0x10bf01320>, <__main__.Card object at 0x10bec8630>]
# cards drawn bramwell: Three of Hearts & simiyu:Three of Diamonds
# round 278, tie 2 :Three of Hearts, Three of Diamonds
# cards drawn bramwell: [<__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bec8c18>, <__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bed3160>] & simiyu:[<__main__.Card object at 0x10bed3240>, <__main__.Card object at 0x10bed3438>, <__main__.Card object at 0x10bed3208>, <__main__.Card object at 0x10bed3470>]
# cards drawn bramwell: Four of Hearts & simiyu:Seven of Clubs
# simiyu won round 278
# Cards won 18 :[<__main__.Card object at 0x10bf01ac8>, <__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bf01a20>, <__main__.Card object at 0x10bec8f98>, <__main__.Card object at 0x10bec8748>, <__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bec8c18>, <__main__.Card object at 0x10bf01ef0>, <__main__.Card object at 0x10bed3160>, <__main__.Card object at 0x10bf012e8>, <__main__.Card object at 0x10bf01400>, <__main__.Card object at 0x10bed36a0>, <__main__.Card object at 0x10bf01320>, <__main__.Card object at 0x10bec8630>, <__main__.Card object at 0x10bed3240>, <__main__.Card object at 0x10bed3438>, <__main__.Card object at 0x10bed3208>, <__main__.Card object at 0x10bed3470>]
# Level 1 cards @ round 279: player 1 has cards: 2 and player 2 has cards: 50
# cards drawn bramwell: Four of Spades & simiyu:Three of Spades
# bramwell won round 279
# Cards won 2 :[<__main__.Card object at 0x10bed3710>, <__main__.Card object at 0x10bec8f98>]
# Level 1 cards @ round 280: player 1 has cards: 3 and player 2 has cards: 49
# cards drawn bramwell: Four of Spades & simiyu:Queen of Spades
# simiyu won round 280
# Cards won 2 :[<__main__.Card object at 0x10bed3710>, <__main__.Card object at 0x10bf01c50>]
# Level 1 cards @ round 281: player 1 has cards: 2 and player 2 has cards: 50
# cards drawn bramwell: King of Spades & simiyu:Eight of Clubs
# bramwell won round 281
# Cards won 2 :[<__main__.Card object at 0x10bf017b8>, <__main__.Card object at 0x10bed3630>]
# Level 1 cards @ round 282: player 1 has cards: 3 and player 2 has cards: 49
# cards drawn bramwell: Eight of Clubs & simiyu:Four of Clubs
# bramwell won round 282
# Cards won 2 :[<__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bed30b8>]
# Level 1 cards @ round 283: player 1 has cards: 4 and player 2 has cards: 48
# cards drawn bramwell: Three of Spades & simiyu:Five of Hearts
# simiyu won round 283
# Cards won 2 :[<__main__.Card object at 0x10bec8f98>, <__main__.Card object at 0x10bed3278>]
# Level 1 cards @ round 284: player 1 has cards: 3 and player 2 has cards: 49
# cards drawn bramwell: Four of Clubs & simiyu:Five of Diamonds
# simiyu won round 284
# Cards won 2 :[<__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bed3208>]
# Level 1 cards @ round 285: player 1 has cards: 2 and player 2 has cards: 50
# cards drawn bramwell: Eight of Clubs & simiyu:Five of Spades
# bramwell won round 285
# Cards won 2 :[<__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bed3550>]
# Level 1 cards @ round 286: player 1 has cards: 3 and player 2 has cards: 49
# cards drawn bramwell: Five of Spades & simiyu:Queen of Hearts
# simiyu won round 286
# Cards won 2 :[<__main__.Card object at 0x10bed3550>, <__main__.Card object at 0x10bf01780>]
# Level 1 cards @ round 287: player 1 has cards: 2 and player 2 has cards: 50
# cards drawn bramwell: King of Spades & simiyu:Ten of Spades
# bramwell won round 287
# Cards won 2 :[<__main__.Card object at 0x10bf017b8>, <__main__.Card object at 0x10bf01ac8>]
# Level 1 cards @ round 288: player 1 has cards: 3 and player 2 has cards: 49
# cards drawn bramwell: King of Spades & simiyu:Six of Clubs
# bramwell won round 288
# Cards won 2 :[<__main__.Card object at 0x10bf017b8>, <__main__.Card object at 0x10bed3588>]
# Level 1 cards @ round 289: player 1 has cards: 4 and player 2 has cards: 48
# cards drawn bramwell: Six of Clubs & simiyu:Eight of Diamonds
# simiyu won round 289
# Cards won 2 :[<__main__.Card object at 0x10bed3588>, <__main__.Card object at 0x10bed30f0>]
# Level 1 cards @ round 290: player 1 has cards: 3 and player 2 has cards: 49
# cards drawn bramwell: King of Spades & simiyu:Queen of Clubs
# bramwell won round 290
# Cards won 2 :[<__main__.Card object at 0x10bf017b8>, <__main__.Card object at 0x10bf014e0>]
# Level 1 cards @ round 291: player 1 has cards: 4 and player 2 has cards: 48
# cards drawn bramwell: Queen of Clubs & simiyu:Nine of Hearts
# bramwell won round 291
# Cards won 2 :[<__main__.Card object at 0x10bf014e0>, <__main__.Card object at 0x10bed3400>]
# Level 1 cards @ round 292: player 1 has cards: 5 and player 2 has cards: 47
# cards drawn bramwell: King of Spades & simiyu:Two of Clubs
# bramwell won round 292
# Cards won 2 :[<__main__.Card object at 0x10bf017b8>, <__main__.Card object at 0x10bec8e10>]
# Level 1 cards @ round 293: player 1 has cards: 6 and player 2 has cards: 46
# cards drawn bramwell: King of Spades & simiyu:Seven of Clubs
# bramwell won round 293
# Cards won 2 :[<__main__.Card object at 0x10bf017b8>, <__main__.Card object at 0x10bed3470>]
# Level 1 cards @ round 294: player 1 has cards: 7 and player 2 has cards: 45
# cards drawn bramwell: Eight of Clubs & simiyu:Five of Diamonds
# bramwell won round 294
# Cards won 2 :[<__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bed3208>]
# Level 1 cards @ round 295: player 1 has cards: 8 and player 2 has cards: 44
# cards drawn bramwell: Seven of Clubs & simiyu:Jack of Hearts
# simiyu won round 295
# Cards won 2 :[<__main__.Card object at 0x10bed3470>, <__main__.Card object at 0x10bf018d0>]
# Level 1 cards @ round 296: player 1 has cards: 7 and player 2 has cards: 45
# cards drawn bramwell: Two of Clubs & simiyu:King of Diamonds
# simiyu won round 296
# Cards won 2 :[<__main__.Card object at 0x10bec8e10>, <__main__.Card object at 0x10bf01588>]
# Level 1 cards @ round 297: player 1 has cards: 6 and player 2 has cards: 46
# cards drawn bramwell: Eight of Clubs & simiyu:Ace of Clubs
# simiyu won round 297
# Cards won 2 :[<__main__.Card object at 0x10bed3630>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 298: player 1 has cards: 5 and player 2 has cards: 47
# cards drawn bramwell: Queen of Clubs & simiyu:Seven of Spades
# bramwell won round 298
# Cards won 2 :[<__main__.Card object at 0x10bf014e0>, <__main__.Card object at 0x10bed31d0>]
# Level 1 cards @ round 299: player 1 has cards: 6 and player 2 has cards: 46
# cards drawn bramwell: Five of Diamonds & simiyu:Four of Clubs
# bramwell won round 299
# Cards won 2 :[<__main__.Card object at 0x10bed3208>, <__main__.Card object at 0x10bed30b8>]
# Level 1 cards @ round 300: player 1 has cards: 7 and player 2 has cards: 45
# cards drawn bramwell: Four of Clubs & simiyu:Three of Diamonds
# bramwell won round 300
# Cards won 2 :[<__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bec8630>]
# Level 1 cards @ round 301: player 1 has cards: 8 and player 2 has cards: 44
# cards drawn bramwell: Five of Diamonds & simiyu:Three of Clubs
# bramwell won round 301
# Cards won 2 :[<__main__.Card object at 0x10bed3208>, <__main__.Card object at 0x10bec8c18>]
# Level 1 cards @ round 302: player 1 has cards: 9 and player 2 has cards: 43
# cards drawn bramwell: Four of Clubs & simiyu:Jack of Spades
# simiyu won round 302
# Cards won 2 :[<__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bf01cc0>]
# Level 1 cards @ round 303: player 1 has cards: 8 and player 2 has cards: 44
# cards drawn bramwell: King of Spades & simiyu:Eight of Diamonds
# bramwell won round 303
# Cards won 2 :[<__main__.Card object at 0x10bf017b8>, <__main__.Card object at 0x10bed30f0>]
# Level 1 cards @ round 304: player 1 has cards: 9 and player 2 has cards: 43
# cards drawn bramwell: Seven of Spades & simiyu:Eight of Hearts
# simiyu won round 304
# Cards won 2 :[<__main__.Card object at 0x10bed31d0>, <__main__.Card object at 0x10bed3358>]
# Level 1 cards @ round 305: player 1 has cards: 8 and player 2 has cards: 44
# cards drawn bramwell: Queen of Clubs & simiyu:Ace of Clubs
# simiyu won round 305
# Cards won 2 :[<__main__.Card object at 0x10bf014e0>, <__main__.Card object at 0x10bf01668>]
# Level 1 cards @ round 306: player 1 has cards: 7 and player 2 has cards: 45
# cards drawn bramwell: Nine of Hearts & simiyu:Queen of Hearts
# simiyu won round 306
# Cards won 2 :[<__main__.Card object at 0x10bed3400>, <__main__.Card object at 0x10bf01780>]
# Level 1 cards @ round 307: player 1 has cards: 6 and player 2 has cards: 46
# cards drawn bramwell: Three of Clubs & simiyu:Jack of Clubs
# simiyu won round 307
# Cards won 2 :[<__main__.Card object at 0x10bec8c18>, <__main__.Card object at 0x10bf01ef0>]
# Level 1 cards @ round 308: player 1 has cards: 5 and player 2 has cards: 47
# cards drawn bramwell: Five of Diamonds & simiyu:Two of Spades
# bramwell won round 308
# Cards won 2 :[<__main__.Card object at 0x10bed3208>, <__main__.Card object at 0x10bec8ef0>]
# Level 1 cards @ round 309: player 1 has cards: 6 and player 2 has cards: 46
# cards drawn bramwell: Two of Spades & simiyu:Seven of Diamonds
# simiyu won round 309
# Cards won 2 :[<__main__.Card object at 0x10bec8ef0>, <__main__.Card object at 0x10bed36a0>]
# Level 1 cards @ round 310: player 1 has cards: 5 and player 2 has cards: 47
# cards drawn bramwell: Ten of Spades & simiyu:Four of Clubs
# bramwell won round 310
# Cards won 2 :[<__main__.Card object at 0x10bf01ac8>, <__main__.Card object at 0x10bed30b8>]
# Level 1 cards @ round 311: player 1 has cards: 6 and player 2 has cards: 46
# cards drawn bramwell: Ten of Spades & simiyu:King of Diamonds
# simiyu won round 311
# Cards won 2 :[<__main__.Card object at 0x10bf01ac8>, <__main__.Card object at 0x10bf01588>]
# Level 1 cards @ round 312: player 1 has cards: 5 and player 2 has cards: 47
# cards drawn bramwell: Five of Diamonds & simiyu:Jack of Hearts
# simiyu won round 312
# Cards won 2 :[<__main__.Card object at 0x10bed3208>, <__main__.Card object at 0x10bf018d0>]
# Level 1 cards @ round 313: player 1 has cards: 4 and player 2 has cards: 48
# cards drawn bramwell: Four of Clubs & simiyu:Seven of Hearts
# simiyu won round 313
# Cards won 2 :[<__main__.Card object at 0x10bed30b8>, <__main__.Card object at 0x10bed35c0>]
# Level 1 cards @ round 314: player 1 has cards: 3 and player 2 has cards: 49
# cards drawn bramwell: Three of Diamonds & simiyu:Queen of Hearts
# simiyu won round 314
# Cards won 2 :[<__main__.Card object at 0x10bec8630>, <__main__.Card object at 0x10bf01780>]
# Level 1 cards @ round 315: player 1 has cards: 2 and player 2 has cards: 50
# cards drawn bramwell: King of Spades & simiyu:King of Hearts
# round 316, tie 1 :King of Spades, King of Hearts
# bramwell has 1 card can't fight.
# Level 1 cards @ round 316: player 1 has cards: 1 and player 2 has cards: 51
# cards drawn bramwell: Eight of Diamonds & simiyu:Nine of Spades
# simiyu won round 316
# Cards won 2 :[<__main__.Card object at 0x10bed30f0>, <__main__.Card object at 0x10bf01e48>]
#  winner was simiyu has 52 cards

# %%
player_one = Player("One")

# %%
player_two = Player("Two")

# %% [markdown]
# ## Setup New Game

# %%
new_deck = Deck()

# %%
new_deck.shuffle()

# %% [markdown]
# ### Split the Deck between players

# %%
len(new_deck.all_cards)/2
# Out:
# 26.0

# %%
for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())

# %%
len(new_deck.all_cards)
# Out:
# 0

# %%
len(player_one.all_cards)
# Out:
# 26

# %%
len(player_two.all_cards)
# Out:
# 26

# %% [markdown]
# ## Play the Game

# %%
import pdb

# %%
game_on = True

# %%
round_num = 0
while game_on:
    
    round_num += 1
    print(f"Round {round_num}")
    
    # Check to see if a player is out of cards:
    if len(player_one.all_cards) == 0:
        print("Player One out of cards! Game Over")
        print("Player Two Wins!")
        game_on = False
        break
        
    if len(player_two.all_cards) == 0:
        print("Player Two out of cards! Game Over")
        print("Player One Wins!")
        game_on = False
        break
    
    # Otherwise, the game is still on!
    
    # Start a new round and reset current cards "on the table"
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
    
    at_war = True

    while at_war:


        if player_one_cards[-1].value > player_two_cards[-1].value:

            # Player One gets the cards
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            
            
            # No Longer at "war" , time for next round
            at_war = False
        
        # Player Two Has higher Card
        elif player_one_cards[-1].value < player_two_cards[-1].value:

            # Player Two gets the cards
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            
            # No Longer at "war" , time for next round
            at_war = False

        else:
            print('WAR!')
            # This occurs when the cards are equal.
            # We'll grab another card each and continue the current war.
            
            # First check to see if player has enough cards
            
            # Check to see if a player is out of cards:
            if len(player_one.all_cards) < 5:
                print("Player One unable to play war! Game Over at War")
                print("Player Two Wins! Player One Loses!")
                game_on = False
                break

            elif len(player_two.all_cards) < 5:
                print("Player Two unable to play war! Game Over at War")
                print("Player One Wins! Player One Loses!")
                game_on = False
                break
            # Otherwise, we're still at war, so we'll add the next cards
            else:
                for num in range(5):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# Round 10
# Round 11
# Round 12
# Round 13
# Round 14
# Round 15
# Round 16
# Round 17
# Round 18
# Round 19
# Round 20
# Round 21
# Round 22
# Round 23
# Round 24
# Round 25
# Round 26
# Round 27
# Player One out of cards! Game Over

# %%
x = False

# %%
print(not x)
# Out:
# True

# %% [markdown]
# ## Game Setup in One Cell

# %%
player_one = Player("One")
player_two = Player("Two")

new_deck = Deck()
new_deck.shuffle()

for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())
    
game_on = True

# %%
round_num = 0
while game_on:
    
    round_num += 1
    print(f"Round {round_num}")
    
    # Check to see if a player is out of cards:
    if len(player_one.all_cards) == 0:
        print("Player One out of cards! Game Over")
        print("Player Two Wins!")
        game_on = False
        break
        
    if len(player_two.all_cards) == 0:
        print("Player Two out of cards! Game Over")
        print("Player One Wins!")
        game_on = False
        break
    
    # Otherwise, the game is still on!
    
    # Start a new round and reset current cards "on the table"
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
    
    at_war = True

    while at_war:


        if player_one_cards[-1].value > player_two_cards[-1].value:

            # Player One gets the cards
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            
            
            # No Longer at "war" , time for next round
            at_war = False
        
        # Player Two Has higher Card
        elif player_one_cards[-1].value < player_two_cards[-1].value:

            # Player Two gets the cards
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            
            # No Longer at "war" , time for next round
            at_war = False

        else:
            print('WAR!')
            # This occurs when the cards are equal.
            # We'll grab another card each and continue the current war.
            
            # First check to see if player has enough cards
            
            # Check to see if a player is out of cards:
            if len(player_one.all_cards) < 5:
                print("Player One unable to play war! Game Over at War")
                print("Player Two Wins! Player One Loses!")
                game_on = False
                break

            elif len(player_two.all_cards) < 5:
                print("Player Two unable to play war! Game Over at War")
                print("Player One Wins! Player One Loses!")
                game_on = False
                break
            # Otherwise, we're still at war, so we'll add the next cards
            else:
                for num in range(5):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Round 1
# Round 2
# WAR!
# Round 3
# WAR!
# WAR!
# Round 4
# WAR!
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# Round 10
# Round 11
# Round 12
# Round 13
# WAR!
# Round 14
# Round 15
# WAR!
# Round 16
# Round 17
# Round 18
# Round 19
# Round 20
# Round 21
# Round 22
# Round 23
# Round 24
# Round 25
# Round 26
# Round 27
# Round 28
# Round 29
# WAR!
# Round 30
# Round 31
# Round 32
# WAR!
# Round 33
# Round 34
# Round 35
# Round 36
# Round 37
# Round 38
# Round 39
# Round 40
# Round 41
# Round 42
# WAR!
# WAR!
# Round 43
# Round 44
# Round 45
# Round 46
# Round 47
# Round 48
# Round 49
# Round 50
# Round 51
# Round 52
# Round 53
# Round 54
# Round 55
# Round 56
# Round 57
# Round 58
# Round 59
# Round 60
# Round 61
# Round 62
# Round 63
# Round 64
# Round 65
# Round 66
# Round 67
# Round 68
# Round 69
# Round 70
# Round 71
# Round 72
# Round 73
# Round 74
# Round 75
# Round 76
# Round 77
# Round 78
# Round 79
# Round 80
# Round 81
# Round 82
# Round 83
# Round 84
# Round 85
# Round 86
# Round 87
# Round 88
# Round 89
# Round 90
# Round 91
# Round 92
# Round 93
# Round 94
# Round 95
# Round 96
# Round 97
# Round 98
# Round 99
# Round 100
# Round 101
# Round 102
# Round 103
# Round 104
# Round 105
# Round 106
# Round 107
# Round 108
# WAR!
# Round 109
# Round 110
# Round 111
# Round 112
# Round 113
# Round 114
# Round 115
# Round 116
# Round 117
# Round 118
# Round 119
# Round 120
# Round 121
# Round 122
# Round 123
# Round 124
# Round 125
# Round 126
# Round 127
# Round 128
# Round 129
# Round 130
# Round 131
# Round 132
# Round 133
# Round 134
# WAR!
# Round 135
# Round 136
# WAR!
# Round 137
# WAR!
# Round 138
# Round 139
# Round 140
# Round 141
# Round 142
# Round 143
# Round 144
# Round 145
# Round 146
# Round 147
# Round 148
# Round 149
# Round 150
# Round 151
# Round 152
# Round 153
# Round 154
# Round 155
# Round 156
# Round 157
# Round 158
# Round 159
# Round 160
# Round 161
# Round 162
# Round 163
# Round 164
# Round 165
# Round 166
# Round 167
# Round 168
# Round 169
# Round 170
# Round 171
# Round 172
# Round 173
# Round 174
# Round 175
# Round 176
# Round 177
# Round 178
# Round 179
# Round 180
# Round 181
# Round 182
# Round 183
# Round 184
# Round 185
# Round 186
# Round 187
# Round 188
# Round 189
# Round 190
# Round 191
# Round 192
# Round 193
# Round 194
# Round 195
# Round 196
# Round 197
# Round 198
# Round 199
# Round 200
# Round 201
# Round 202
# Round 203
# Round 204
# Round 205
# Round 206
# Round 207
# Round 208
# Round 209
# Round 210
# Round 211
# Round 212
# Round 213
# Round 214
# Round 215
# Round 216
# Round 217
# Round 218
# Round 219
# Round 220
# Round 221
# Round 222
# Round 223
# WAR!
# Round 224
# Round 225
# Round 226
# Round 227
# Round 228
# Round 229
# Round 230
# Round 231
# Round 232
# Round 233
# Round 234
# Round 235
# Round 236
# Round 237
# Round 238
# Round 239
# Round 240
# Round 241
# Round 242
# Round 243
# Round 244
# Round 245
# Round 246
# Round 247
# Round 248
# Round 249
# Round 250
# Round 251
# Round 252
# Round 253
# Round 254
# Round 255
# Round 256
# Round 257
# WAR!
# Round 258
# Round 259
# Round 260
# Round 261
# Round 262
# Round 263
# Round 264
# Round 265
# Round 266
# Round 267
# Round 268
# Round 269
# Round 270
# Round 271
# Round 272
# Round 273
# Round 274
# Round 275
# Round 276
# Round 277
# Round 278
# Round 279
# Round 280
# Round 281
# Round 282
# Round 283
# Round 284
# Round 285
# Round 286
# Round 287
# Round 288
# Round 289
# Round 290
# Round 291
# Round 292
# Round 293
# Round 294
# Round 295
# Round 296
# Round 297
# Round 298
# Round 299
# Round 300
# Round 301
# Round 302
# Round 303
# Round 304
# Round 305
# Round 306
# Round 307
# WAR!
# Round 308
# Round 309
# Round 310
# Round 311
# Round 312
# Round 313
# Round 314
# Round 315
# WAR!
# Round 316
# Round 317
# Round 318
# Round 319
# Round 320
# Round 321
# Round 322
# Round 323
# Round 324
# Round 325
# Round 326
# Round 327
# Round 328
# Round 329
# Round 330
# Round 331
# Round 332
# Round 333
# Round 334
# Round 335
# Round 336
# Round 337
# Round 338
# Round 339
# Round 340
# Round 341
# Round 342
# Round 343
# Round 344
# Round 345
# Round 346
# Round 347
# Round 348
# Round 349
# WAR!
# Round 350
# WAR!
# Player Two unable to play war! Game Over at War
# Player One Wins! Player One Loses!

# %%
len(player_one.all_cards)
# Out:
# 27

# %%
len(player_two.all_cards)
# Out:
# 25

# %%
print(player_one_cards[-1])
# Out:
# Ace of Diamonds

# %%
print(player_two_cards[-1])
# Out:
# Four of Hearts

# %% [markdown]
# ## Great Work!
#
# Other links that may interest you:
# * https://www.reddit.com/r/learnpython/comments/7ay83p/war_card_game/
# * https://codereview.stackexchange.com/questions/131174/war-card-game-using-classes
# * https://gist.github.com/damianesteban/6896120
# * https://lethain.com/war-card-game-in-python/
# * https://hectorpefo.github.io/2017-09-13-Card-Wars/
# * https://www.wimpyprogrammer.com/the-statistics-of-war-the-card-game
